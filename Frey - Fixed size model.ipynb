# %%
import numpy as np
import pandas as pd
from mypy.explib.frey2014 import frey2014
import model_fixed.model_fixed_per as model_fp
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
subjdata = frey2014.sampledata_by_subject()

# %%
ret = model_fp.fit_subject_across_gambles(subjdata[39])

# %%
SUBJ = np.sort(subjdata.keys())

# %%
fitresults = pd.DataFrame(index=SUBJ, columns=['T', 's', 'nllh', 'bic', 'success'])

# %%
for sid in SUBJ:
    print sid
    ret = model_fp.fit_subject_across_gambles(subjdata[sid])
    fitresults.loc[sid] = [ret['bf_par']['target'], ret['bf_par']['s'], ret['nllh'], ret['bic'], ret['success']]
# Out:
# 1
# best fitting target size:
#  6
# bic: 489.203927462
#   status: 0
#     nfev: 38
#  success: True
#      fun: 241.17373273855273
#        x: array([ 2.2166726])
#  message: 'Optimization terminated successfully.'
#      nit: 19
# 2
# best fitting target size:
#  163
# bic: 1307.21388451
#   status: 0
#     nfev: 38
#  success: True
#      fun: 650.03949682801772
#        x: array([ 0.01029564])
#  message: 'Optimization terminated successfully.'
#      nit: 19
# 3
# best fitting target size:
#  21
# bic: 1345.96875509
#   status: 0
#     nfev: 32
#  success: True
#      fun: 669.22561711742662
#        x: array([ 0.16079557])
#  message: 'Optimization terminated successfully.'
#      nit: 16
# 4
# best fitting target size:
#  9
# bic: 1060.48006751
#   status: 0
#     nfev: 28
#  success: True
#      fun: 526.66350793773188
#        x: array([ 0.50397835])
#  message: 'Optimization terminated successfully.'
#      nit: 14
# 5
# best fitting target size:
#  34
# ...

# %%
fitresults
# Out:
#        T           s      nllh       bic success
# 1      6    2.216708  241.1737  489.1114    True
# 2    164  0.01022906  649.9879  1307.045    True
# 3     21   0.1607514  669.2256  1345.922    True
# 4      9   0.5039473  526.6635  1060.412    True
# 5     34  0.07737497  725.6963  1458.872    True
# 6    NaN         NaN       NaN       NaN     NaN
# 7    NaN         NaN       NaN       NaN     NaN
# 8    NaN         NaN       NaN       NaN     NaN
# 9    NaN         NaN       NaN       NaN     NaN
# 12     6    2.216683  241.1737  489.1114    True
# 13   NaN         NaN       NaN       NaN     NaN
# 15   NaN         NaN       NaN       NaN     NaN
# 16   NaN         NaN       NaN       NaN     NaN
# 17   NaN         NaN       NaN       NaN     NaN
# 18   NaN         NaN       NaN       NaN     NaN
# 20   NaN         NaN       NaN       NaN     NaN
# 21   NaN         NaN       NaN       NaN     NaN
# 22   NaN         NaN       NaN       NaN     NaN
# ...
