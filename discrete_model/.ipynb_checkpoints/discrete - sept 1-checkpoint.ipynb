# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np
from scipy import linalg
from numpy.linalg import matrix_power
import pandas as pd
from scipy.optimize import minimize

from model import *
from helpers import add_problem_labels, plot_model
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # The basic model
#
# ### The state space
#
# The state space is defined as discrete levels of evidence between two decision thresholds, $\theta$ and $-\theta$. Given a function that specifies the probability of transitioning up or down (more on that below), Diederich (1997) shows how to compute the choice probabilities $p(choice=A)$ and $p(choice=B)$, as well as the probability of stopping at a particular time conditioned on which alternative is chosen, $p(t|choice)$.
#
# For example, for $\theta=5$ we have a state space ranging from -5 to 5. The plot on the left below shows the probability of occupying these states over time. Note that the initial state vector $Z$ is peaked at the unbiased middle point of the state space. The middle curve shows the probability of making each choice given at each timestep, whereas the right curve shows the probability of stopping at each timestep given the chosen option (in this case, they distribution of stopping times is the same).

# %%
result = run(pars = {'theta': 5.,
                     'delta': -0.1,
                     'z_temp': 0.5})
plot_model(result)

# %% [markdown]
# Increasing the threshold $\theta$ means that more evidence is required to make a decision. The state space increases in size (i.e., more steps have to be traversed), and the curves are pushed foward in time.

# %%
result = run(pars = {'theta': 10,
                     'delta': -0.1,
                     'z_temp': 0.5})
plot_model(result)

# %% [markdown]
# The vector $Z$ specifies the the probability distribution over starting states, which is generally assumed to be unbiased. For example, could assume that the process starts at the midpoint with probability of 1. Alternatively, could assume a uniform distribution over starting positions. In my version I wanted something that could vary between those two extremes, so the probability of a starting position is based on its distance from the midpoint, then passed through a softmax function controlled by a temperature parameter $z_{temp}$. When $z_{temp}$ is low (as above) the starting position is highly likely to be in the center. As $z_{temp}$ increases, starting positions further away from the center are increasingly likely.
#
# For example, if $z_{temp}$ is high there will be a higher proportion of fast decisions (since people are more likely to start close to a threshold). This can allow for fast errors. As seen in the plot below on the right, if an incorrect choice is made,  it is most likely to occur early on due to the wide disperson of starting states.

# %%
result = run(pars = {'theta': 10.,
                     'delta': -0.1,
                     'z_temp': 10})
plot_model(result)

# %% [markdown]
# Note that in the results above, both the step size between states and between timepoints is assumed to be 1. However, a main point of Diederich (1997) is that this discrete model can be used to approximate a time-continuous process. Decreasing the stepsize $dv$ will increase the size of the state space and the quality of the approximation to a continuous process, but doesn't have an effect on the relative response and sample size probabilities (assuming we evaluate them at the same points in time).
#
# For example, in the plots below $dv=.25$, such that a unit of time corresponds to 4 steps in the Markov chain. Note that the relative probabilities shown in the plots to the right are the same as in the plots above.
#
# For discrete sampling paradigms where the measure is the sample size (rather than continuous time), the model can thus be used assuming that each sample maps on to a step in the model. One nice property is that you can then incorporate finer grained process information (e.g., time spent looking at an outcome) within the same model and test for a better fit. (However, for now I will restrict it to the unit step case).

# %%
result = run(pars = {'theta': 10.,
                     'delta': -0.1,
                     'z_temp': 10,
                     'dv': .25})
plot_model(result)

# %% [markdown]
# ### Transition probabilities
#
# The model is formulated as a birth-death chain: with each step of the chain, the state can only 1) go down one step, 2) stay in the same state, or 3) go up one step. The transition probabilities specify the likelihood of each of these actions.
#
# $p_{down} = \frac{1}{2 \, \alpha} (1 - \frac{\delta - \gamma \cdot v}{\sigma}) \cdot \sqrt{\tau}$
#
# $p_{up} = \frac{1}{2 \, \alpha} (1 - \frac{\delta + \gamma \cdot v}{\sigma}) \cdot \sqrt{\tau}$
#
# $p_{stay} = 1 - \frac{1}{\alpha}$
#
#
# The drift coefficient ($\delta - \gamma \cdot v$) controls the direction and velocity, with $\delta$ indicating the difference between alternatives (i.e., the result of comparing the alternatives), $x$ is the current state of the process, and $\gamma$ is a free parameter that weights the current state.
#
# For now, the parameter we care most about is $\delta$ (and set $\gamma=0$). An increase in $\delta$ leads to faster decisions:

# %%
result = run(pars = {'theta': 10.,
                     'delta': -.5,
                     'z_temp': 1,
                     'dv': .25})
plot_model(result)

# %% [markdown]
# ## Fitting a single problem
#
# Using data from Frey et al. study comparing older and younger adults (see more details below).

# %%
data = pd.read_csv('../dfe_by_game.csv')
gamble_lab = data['gamble_lab'].unique()

# sort by problem type
gambles = data[data['partid']==1]
gambles_srt = gambles.sort(['domain', 'pairtype', 'session'])
gamble_lab_srt = gambles_srt['gamble_lab']

gdata = data[data['gamble_lab']=='S11G1']

# %%
tofit = {'old': [], 'yng': []}
ss_A = {}
ss_B = {}
max_t = {}
for grp in ['old', 'yng']:
    gdata_grp = gdata[gdata['group']==grp]
    for pair in gdata_grp[['decision', 'samplesize']].values:
        choice = 0 if pair[0]=='L' else 1
        samplesize = pair[1]
        tofit[grp].append([choice, samplesize])
    tofit[grp] = np.array(tofit[grp])

    ss_A[grp] = tofit[grp][np.where(tofit[grp][:,0]==0)[0],1]
    ss_B[grp] = tofit[grp][np.where(tofit[grp][:,0]==1)[0],1]
    max_t[grp] = np.max([np.max(ss_A[grp]), np.max(ss_B[grp])]) + 1

fig, ax = plt.subplots(1, 2, figsize=(20,4))
for i, grp in enumerate(['old', 'yng']):
    ax[i].hist(ss_A[grp], range(max_t[grp]), label='chose L')
    ax[i].hist(ss_B[grp], range(max_t[grp]), label='chose H')
    ax[i].set_title(grp)
    ax[i].set_xlabel('Sample size')
    ax[i].set_ylabel('# of participants')
    ax[i].legend()
plt.show()

# %%
# fitting theta, delta separately for each group
f = {}
for grp in ['old', 'yng']:
    pars = {'data': tofit[grp],
            'z_temp': 1,
            'max_T': max_t[grp],
            'fitting': ['theta', 'delta']}

    init = [np.random.randint(2, 10), 0.]
    f[grp] = minimize(loglik, init, (pars,), method='Nelder-Mead')

# given best-fit parameters, get predicted sample sizes
bf_pred = {}
for grp in ['old', 'yng']:
    bf_pred[grp] = run({'theta': f[grp]['x'][0],
                        'delta': f[grp]['x'][1],
                        'z_temp': 0.5,
                        'max_T': max_t[grp]})

# %%
tmax = np.max([max_t[grp] for grp in ['old', 'yng']])
fig, ax = plt.subplots(2, 2, figsize=(20,5))
for i, grp in enumerate(['old', 'yng']):
    ax[i][0].plot(bf_pred[grp]['T'], bf_pred[grp]['resp_prob_t'][:,0], label='A')
    ax[i][0].set_title('%s, chose L' % grp)
    axhA = ax[i][0].twinx()
    axhA.hist(ss_A[grp], bins=range(max_t[grp]), alpha=.7)
    ax[i][0].set_xlim([0, tmax])
    
    ax[i][1].plot(bf_pred[grp]['T'], bf_pred[grp]['resp_prob_t'][:,1], label='B')
    ax[i][1].set_title('%s, chose H' % grp)
    axhB = ax[i][1].twinx()
    axhB.hist(ss_B[grp], bins=range(max_t[grp]), alpha=.7)
    ax[i][1].set_xlim([0, tmax])
    
plt.show()

# %% [markdown]
# ## Fitting all 84 problems

# %% [markdown]
# Now want to look at all of the problems in the aging dataset. Summary of data:
#
# - Two groups of participants: (1) 35 younger adults, (2) 35 older adults
# - Each participant completed 3 sessions a day for 7 consecutive days
# - Each session included 4 decision problems, 2 in gain domain and 2 in loss domain
# - At end of each session, received feedback about total gains/losses
#
# Four sets of options:
#
# 1. low expected value, low variance (LL)
# 2. low expected value, high variance (LH)
# 3. high expected value, low variance (HL)
# 4. high expected value, high variance (HH)
#
# Decision problems involved pairing
#
# 1. HH vs. LL
# 2. HL vs. LH
#
# and were either in the gain or loss domain.

# %%
data_by_gamble = pd.read_csv('../dfe_by_gamble.csv')

def get_options(gid):
    gdata = data_by_gamble[data_by_gamble['gid']==gid]
    L = np.array([gdata[['L_x1', 'L_p1']].values, gdata[['L_x2', 'L_p2']].values, gdata[['L_x3', 'L_p3']].values]).reshape((3,2))
    H = np.array([gdata[['H_x1', 'H_p1']].values, gdata[['H_x2', 'H_p2']].values, gdata[['H_x3', 'H_p3']].values]).reshape((3,2))
    return [L, H]

# %%
cols = ['blue', 'red']
fig, ax = plt.subplots(figsize=(20,8))
for gind, gid in enumerate(gamble_lab_srt):
    for opt_ind, opt in enumerate(get_options(gid)):
        for x, p in opt:
            ax.plot(gind, x, '.', color=cols[opt_ind], markersize=(35*p), alpha=.4)
ax.set_xlim([-1, 85])
add_problem_labels(ax, -28, [-30, 30])
ax.set_xlabel('Problem')
ax.set_ylabel('Outcome')
ax.set_title('Outcomes for all problems (Red=H, Blue=L), with size of marker indicating probability')
plt.show()

# %% [markdown]
# There are a couple of interesting patterns in the results that should be reflected in the model fits. First, there was an interaction between domain and pair type on choice accuracy (proportion of people choosing the higher option, H).
#
# For gains, accuracy was higher for HL-LH problems (in which the H option had lower variance). For losses the pattern was reversed, with accuracy higher for HH-LL problems (in which the H option had high variance). This seems to have occurred because the gain gambles were reflected across zero to create the loss gambles, and as a result the rare, extreme outcomes (really, the lack thereof due to small samples) have different consequences on choices.

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax.plot(data_by_gamble['prop_H_all_old'].values, 'r-x', label='old')
ax.plot(data_by_gamble['prop_H_all_yng'].values, 'b-x', label='young')
add_problem_labels(ax, .1, [0,1])
ax.legend()
ax.set_xlim(-1, 85)
ax.set_xlabel('Problem')
ax.set_ylabel('Proportion choosing H')
ax.set_title('Observed accuracy (proportion of people choosing H option)')
plt.show()

# %% [markdown]
# Second, there was a qualitative difference in sample sizes between groups, with older adults drawing fewer samples across all problem types. Note that this difference was not significant based on either Renato's or my mixed effects modeling, but as can be seen below it is very consistent across problems.

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax.plot(data_by_gamble['ss_all_old'].values, 'r-+', label='old')
ax.plot(data_by_gamble['ss_all_yng'].values, 'b-+', label='young')
add_problem_labels(ax, 14, [0,50])
ax.legend()
ax.set_xlim(-1, 85)
ax.set_ylim(10, 45)
ax.set_xlabel('Problem')
ax.set_ylabel('Sample size')
ax.set_title('Observed mean sample size')
plt.show()

# %% [markdown]
# As a sanity check, the first goal was to fit the model separately for each problem to see if the best-fitting parameters match up with these patterns.
#
# For each problem, the following estimates a single drift parameter ($\delta$) and a threshold parameter for each group ($\theta_{yng}$ and $\theta_{old}$).

# %%
grid_fit_pars = {}
grid_fit_results = {}

# %%
for gid in gamble_lab:
    print gid
    gdata = data[data['gamble_lab']==gid]

    tofit = []
    for obs in gdata[['decision', 'samplesize', 'group']].values:
        choice = 0 if obs[0]=='L' else 1
        group = 0 if obs[2]=='old' else 1
        samplesize = obs[1]
        tofit.append([choice, samplesize, group])
    tofit = np.array(tofit)
    
    ss_A = tofit[np.where(tofit[:,0]==0)[0],1]
    ss_B = tofit[np.where(tofit[:,0]==1)[0],1]
    max_t = np.max([np.max(ss_A), np.max(ss_B)]) + 1
    
    pars = {'data': tofit,
            'max_T': max_t,
            'z_temp': 0.5,
            'fitting': ['delta', 'theta(0)', 'theta(1)'],
            'verbose': False}

    init = [np.random.random()-1, np.random.randint(2, 10), np.random.randint(2, 10)]
    grid_fit_pars[gid] = pars
    grid_fit_results[gid] = minimize(loglik_factor, init, (pars,), method='Powell')

# %%
gset = gamble_lab_srt
fig, ax = plt.subplots(2, 1, figsize=(20,6))
for i, grp in enumerate(['old', 'yng']):
    col = 'red' if grp=='old' else 'blue'
    bf_theta = np.round([grid_fit_results[gid]['x'][i+1] for gid in gset])
    ax[0].bar(range(len(bf_theta)), bf_theta, color=col, alpha=.5, label=grp)
    ax[0].set_ylim([0, 10])
    ax[0].set_xlim([0, 85])
    ax[0] = add_problem_labels(ax[0], 8, [0, 10])
ax[0].set_xlabel('Problem')
ax[0].set_ylabel('threshold')
ax[0].legend()

bf_delta = [grid_fit_results[gid]['x'][0] for gid in gset]
ax[1].bar(range(len(bf_delta)), bf_delta, color=col, alpha=.5)
ax[1].set_ylim([-.2, .3])
ax[1].set_xlim([0, 85])
ax[1] = add_problem_labels(ax[1], -.3, [-.35, .35])
ax[1].set_ylabel('Drift')
ax[1].set_xlabel('Problem')

plt.show()

# %% [markdown]
# The result looks sensible given the data being fit. First, the threshold for the young group is higher across problems, consistent with the larger sample sizes in that group. Second, the drift rate (here controlled only by $\delta$) is higher for those problems where people were more likely to choose the H option. For gain/HH-LL and loss/HL-LH problems, where accuracy was around chance, the drift rate is centered around zero.

# %% [markdown]
# ### Modeling drift rate with CPT weighting functions
#
# Next question is whether we can account for the results based on the structure of the gambles, rather than fitting parameters spearately for each problem. My first pass at this was to model the drift rate using the difference in expected utility a la CPT. Here there are a few additional parameters to consider:
#
# $\delta$: scaling factor (before this was the drift rate itself)
#
# $w_p$: probability weighting parameter
#
# $pow_{gain}$, $pow_{loss}$: value weighting parameters
#
# $w_{loss}$: loss-specific scaling parameter

# %%
from model_cpt import *
gset = gamble_lab_srt

# %%
fitdata = []
for gid in gset:
    gdata = data[data['gamble_lab']==gid]

    tofit = []
    for obs in gdata[['decision', 'samplesize', 'group']].values:
        choice = 0 if obs[0]=='L' else 1
        group = 0 if obs[2]=='old' else 1
        samplesize = obs[1]
        tofit.append([choice, samplesize, group])
    tofit = np.array(tofit)
    
    ss_A = tofit[np.where(tofit[:,0]==0)[0],1]
    ss_B = tofit[np.where(tofit[:,0]==1)[0],1]
    max_t = np.max([np.max(ss_A), np.max(ss_B)]) + 1
    
    fitdata.append({'gid': gid,
                    'options': get_options(gid),
                    'max_t': max_t,
                    'samplesize': tofit})

# %%
pars = {'data': fitdata,
        'z_temp': 1.,
        'fitting': ['delta', 'theta', 'pow_gain', 'pow_loss']}
loglik_across_gambles([0.25, 5., .5, .5], pars)
# Out:
# 28547.195162519634

# %%
init = [np.random.random(), 5, 1., 1.]
f = minimize(loglik_across_gambles, init, (pars,), method='Nelder-Mead')

# %%
f
# Out:
#   status: 0
#     nfev: 347
#  success: True
#      fun: 28364.954859915902
#        x: array([ 0.11004065,  5.3534211 ,  0.68240639,  0.6581272 ])
#  message: 'Optimization terminated successfully.'
#      nit: 196

# %%
p_resp = []
p_resp_L = []
p_resp_H = []
p_stop_L = []
p_stop_H = []
for i, fd in enumerate(fitdata):
    pred_pars = {'data': fd['samplesize'],
                 'z_temp': pars['z_temp'],
                 'max_T': fd['max_t'],
                 'options': fd['options']}
    for par_i, par_name in enumerate(pars['fitting']):
        pred_pars[par_name] = f['x'][par_i]
    result = run(pred_pars)
    p_resp.append(result['resp_prob'][1])
    p_resp_L.append(result['resp_prob_t'][:,0])
    p_resp_H.append(result['resp_prob_t'][:,1])
    p_stop_L.append(result['p_stop_t'][:,0])
    p_stop_H.append(result['p_stop_t'][:,1])

# %%
fig, ax = plt.subplots(figsize=(20,4))
ax.plot(np.array([data_by_gamble[data_by_gamble['gid']==gid]['prop_H_all'].values for gid in gamble_lab_srt]), '-x', label='observed')
ax.plot(p_resp, '-o', label='model')
#ax.plot([choice_prob(get_options(gid), cpt_pars) for gid in gamble_lab_srt], '-.', color='red')
ax.set_ylim([.1, .9])
ax.set_xlim([-1, 85])
add_problem_labels(ax, .2, [0, 10])
ax.legend()
plt.show()

# %% [markdown]
# ### Fitting probability weighting parameter

# %%
pars = {'data': fitdata,
        'z_temp': 1.,
        'fitting': ['delta', 'theta', 'w_p']}
loglik_across_gambles([0.1, 5, 1.], pars)
# Out:
# 28695.176518224234

# %%
init = [np.random.random(), 5., 1.]
f = minimize(loglik_across_gambles, init, (pars,), method='Nelder-Mead')

# %%
f
# Out:
#   status: 0
#     nfev: 172
#  success: True
#      fun: 29042.513180787733
#        x: array([ 0.05068504,  5.6611168 ,  1.57192352])
#  message: 'Optimization terminated successfully.'
#      nit: 92

# %%
p_resp = []
for i, fd in enumerate(fitdata):
    pred_pars = {'data': fd['samplesize'],
                 'z_temp': pars['z_temp'],
                 'max_T': fd['max_t'],
                 'options': fd['options']}
    for par_i, par_name in enumerate(pars['fitting']):
        pred_pars[par_name] = f['x'][par_i]
    result = run(pred_pars)
    p_resp.append(result['resp_prob'][1])

# %%
# compare to the same parameter set but with a higher threshold
p_resp_high_threshold = []
for i, fd in enumerate(fitdata):
    pred_pars = {'data': fd['samplesize'],
                 'z_temp': pars['z_temp'],
                 'max_T': fd['max_t'],
                 'options': fd['options']}
    for par_i, par_name in enumerate(pars['fitting']):
        pred_pars[par_name] = f['x'][par_i]
    pred_pars['theta'] = 20.
    result = run(pred_pars)
    p_resp_high_threshold.append(result['resp_prob'][1])

# %%
# compare to the same parameter set but with a higher threshold
p_resp_ident = []
for i, fd in enumerate(fitdata):
    pred_pars = {'data': fd['samplesize'],
                 'z_temp': pars['z_temp'],
                 'max_T': fd['max_t'],
                 'options': fd['options']}
    for par_i, par_name in enumerate(pars['fitting']):
        pred_pars[par_name] = f['x'][par_i]
    pred_pars['w_p'] = 1.
    result = run(pred_pars)
    p_resp_ident.append(result['resp_prob'][1])

# %%
ps = np.arange(0, 1, .01)
fig, ax = plt.subplots()
ax.plot(ps, [pweight(p, 1.) for p in ps], '--')
ax.plot(ps, [pweight(p, f['x'][2]) for p in ps], label='best-fitting w_p')
ax.set_aspect(1)
ax.set_xlabel('true')
ax.set_ylabel('weighted')
ax.set_title('Probability weighting fcn')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,4))
ax.plot(np.array([data_by_gamble[data_by_gamble['gid']==gid]['prop_H_all'].values for gid in gamble_lab_srt]), '-o', label='observed')
ax.plot(p_resp, '-x', label='best fit model')
ax.set_ylim([0, 1])
ax.set_xlim([-1, 85])
add_problem_labels(ax, .2, [0, 10])
ax.legend()
plt.show()

# %% [markdown]
# A couple of additional sanity checks. The following plot shows the proportion choosing H for the model with:
#
# 1. the best-fit values of $\theta$ and $w_p$
#
# 2. the best-fit $w_p$ but a higher threshold
#
# 3. the best-fit threshold but no probability distortion ($w_p=1$)

# %%
fig, ax = plt.subplots(figsize=(20,4))
ax.plot(p_resp, '-x', label='best fit model')
ax.plot(p_resp_high_threshold, '-x', alpha=.9, label='model, high threshold')
ax.plot(p_resp_ident, '-x', alpha=.9, label='model, w_p=1')
ax.set_ylim([0, 1])
ax.set_xlim([-1, 85])
add_problem_labels(ax, .2, [0, 10])
ax.legend()
plt.show()

# %% [markdown]
# ### Separately by group

# %%
pars = {'data': fitdata,
        'z_temp': 1.,
        'fitting': ['delta', 'theta(0)', 'theta(1)', 'w_p']}
print loglik_across_gambles_by_group([.1, 5, 5, 1.], pars)
# Out:
# 28695.1765182

# %%
init = [.1, 5, 5, 1.]
f = minimize(loglik_across_gambles_by_group, init, (pars,), method='Nelder-Mead')

# %%
f
# Out:
#   status: 0
#     nfev: 159
#  success: True
#      fun: 28398.10005979265
#        x: array([ 0.0431024 ,  4.60876523,  4.93382751,  1.58556569])
#  message: 'Optimization terminated successfully.'
#      nit: 86

# %%
p_resp = {'old': [], 'yng': []}
for grp_i, grp in enumerate(['old', 'yng']):
    for i, fd in enumerate(fitdata):
        pred_pars = {'data': fd['samplesize'],
                     'z_temp': pars['z_temp'],
                     'max_T': fd['max_t'],
                     'options': fd['options'],
                     'delta': f['x'][0],
                     'w_p': f['x'][3],
                     'theta': f['x'][grp_i+1]}
        result = run(pred_pars)
        p_resp[grp].append(result['resp_prob'][1])

# %%
fig, ax = plt.subplots(figsize=(20,4))
for grp in ['old', 'yng']:
    ax.plot(np.array([data_by_gamble[data_by_gamble['gid']==gid]['prop_H_all_%s' % grp].values for gid in gamble_lab_srt]), '-o', label='observed, %s' % grp)
    ax.plot(p_resp[grp], '-x', label='model, %s' % grp)
#ax.plot([choice_prob(get_options(gid), cpt_pars) for gid in gamble_lab_srt], '-.', color='red')
ax.set_ylim([.1, 1])
ax.set_xlim([-1, 85])
add_problem_labels(ax, .2, [0, 10])
ax.legend()
plt.show()

# %% [markdown]
# ## Using prelec function and pooled variance (in progress)

# %%
fitdata = []
for gid in gset:
    gdata = data[data['gamble_lab']==gid]

    tofit = []
    for obs in gdata[['decision', 'samplesize', 'group']].values:
        choice = 0 if obs[0]=='L' else 1
        group = 0 if obs[2]=='old' else 1
        samplesize = obs[1]
        tofit.append([choice, samplesize, group])
    tofit = np.array(tofit)
    
    ss_A = tofit[np.where(tofit[:,0]==0)[0],1]
    ss_B = tofit[np.where(tofit[:,0]==1)[0],1]
    max_t = np.max([np.max(ss_A), np.max(ss_B)]) + 1
    
    fitdata.append({'options': get_options(gid),
                    'max_t': max_t,
                    'samplesize': tofit})

# %%
result = run(pars = {'options': get_options('S10G4'),
                     'theta': 5.,
                     'delta': 1,
                     'prelec_gamma': 2.,
                     'z_temp': 1
                     })
plot_model(result)

# %%
pars = {'data': fitdata,
        'fitting': ['delta', 'theta', 'z_temp', 'prelec_elevation', 'prelec_gamma', 'pow_gain', 'pow_loss'],
        'bounds': [[-np.inf, np.inf],
                   [1, np.inf],
                   [0, np.inf],
                   [0, np.inf],
                   [0, np.inf],
                   [0, np.inf],
                   [0, np.inf]],
        'verbose': True}
loglik_across_gambles([1., 5., 1., 1., 1., 1., 1.], pars)
# Out:
# evaluating:
#   delta=1.0
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   pow_gain=1.0
#   pow_loss=1.0
#   llh: 28905.3150933
# 28905.315093258785

# %%
init = [np.random.random(), 5., 1., 1., 1., 1., 1.]
f = minimize(loglik_across_gambles, init, (pars,), method='Nelder-Mead')
# Out:
# evaluating:
#   delta=0.33003492985
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   pow_gain=1.0
#   pow_loss=1.0
#   llh: 28508.0799293
# evaluating:
#   delta=0.346536676343
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   pow_gain=1.0
#   pow_loss=1.0
#   llh: 28508.1905508
# evaluating:
#   delta=0.33003492985
#   theta=5.25
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   pow_gain=1.0
#   pow_loss=1.0
#   llh: 28508.0799293
# evaluating:
#   delta=0.33003492985
#   theta=5.0
#   z_temp=1.05
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   pow_gain=1.0
#   pow_loss=1.0
#   llh: 28511.474449
# evaluating:
#   delta=0.33003492985
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.05
#   prelec_gamma=1.0
#   pow_gain=1.0
#   pow_loss=1.0
#   llh: 28484.8488623
# evaluating:
#   delta=0.33003492985
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.05
#   pow_gain=1.0
#   pow_loss=1.0
#   llh: 28486.688853
# evaluating:
#   delta=0.33003492985
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   pow_gain=1.05
#   pow_loss=1.0
#   llh: 28534.1037076
# evaluating:
#   delta=0.33003492985
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   pow_gain=1.0
#   pow_loss=1.05
#   llh: 28525.1334722
# evaluating:
#   delta=0.334749714563
#   theta=5.07142857143
#   z_temp=1.01428571429
#   prelec_elevation=1.01428571429
#   prelec_gamma=1.01428571429
#   pow_gain=0.95
#   pow_loss=1.01428571429
#   llh: 28476.0542098
# evaluating:
#   delta=0.337107106919
#   theta=5.10714285714
#   z_temp=1.02142857143
#   prelec_elevation=1.02142857143
#   prelec_gamma=1.02142857143
#   pow_gain=0.9
#   pow_loss=1.02142857143
#   llh: 28451.5392894
# evaluating:
#   delta=0.336770336582
#   theta=5.10204081633
#   z_temp=1.02040816327
#   prelec_elevation=1.02040816327
#   prelec_gamma=1.02040816327
#   pow_gain=0.971428571429
#   pow_loss=0.95612244898
#   llh: 28464.8140378
# evaluating:
#   delta=0.338694738505
#   theta=5.13119533528
#   z_temp=0.96195335277
#   prelec_elevation=1.02623906706
#   prelec_gamma=1.02623906706
#   pow_gain=0.963265306122
#   pow_loss=0.993586005831
#   llh: 28464.0516624
# evaluating:
#   delta=0.319952438345
#   theta=5.16867971678
#   z_temp=1.00108288213
#   prelec_elevation=1.03373594336
#   prelec_gamma=1.03373594336
#   pow_gain=0.9527696793
#   pow_loss=0.991753436068
#   llh: 28456.9105624
# evaluating:
#   delta=0.333573472979
#   theta=4.89544535015
#   z_temp=1.00139227703
#   prelec_elevation=1.04337478432
#   prelec_gamma=1.04337478432
#   pow_gain=0.939275301958
#   pow_loss=0.989397274945
#   llh: 28442.4012939
# evaluating:
#   delta=0.335342744543
#   theta=4.71816802523
#   z_temp=1.00208841554
#   prelec_elevation=1.06506217647
#   prelec_gamma=1.06506217647
#   pow_gain=0.908912952936
#   pow_loss=0.984095912417
#   llh: 28417.7919822
# evaluating:
#   delta=0.335089991462
#   theta=5.06492192879
#   z_temp=1.00198896718
#   prelec_elevation=1.06196397759
#   prelec_gamma=1.06196397759
#   pow_gain=0.913250431368
#   pow_loss=0.984853249921
#   llh: 28420.9693528
# evaluating:
#   delta=0.33653429478
#   theta=5.0834710513
#   z_temp=1.00255724352
#   prelec_elevation=1.07966797119
#   prelec_gamma=1.01538225691
#   pow_gain=0.88846484033
#   pow_loss=0.980525607042
#   llh: 28418.7716922
# evaluating:
#   delta=0.338391256189
#   theta=5.1073199231
#   z_temp=1.00328788453
#   prelec_elevation=1.03814453439
#   prelec_gamma=1.06977718745
#   pow_gain=0.856597651853
#   pow_loss=0.974961494768
#   llh: 28404.1047322
# evaluating:
#   delta=0.342569419358
#   theta=5.16097988465
#   z_temp=1.00493182679
#   prelec_elevation=1.03221680159
#   prelec_gamma=1.10466578118
#   pow_gain=0.78489647778
#   pow_loss=0.962442242152
#   llh: 28380.0264152
# evaluating:
#   delta=0.33331273025
#   theta=5.02211884058
#   z_temp=0.978457910838
#   prelec_elevation=1.07111026779
#   prelec_gamma=1.0734426293
#   pow_gain=0.831874196525
#   pow_loss=1.02064470098
#   llh: 28399.2240453
# evaluating:
#   delta=0.329850611682
#   theta=4.96179960886
#   z_temp=1.04162830935
#   prelec_elevation=1.07809970706
#   prelec_gamma=1.08109845759
#   pow_gain=0.802497144803
#   pow_loss=0.990912199886
#   llh: 28388.3390773
# evaluating:
#   delta=0.351420961368
#   theta=4.86520662508
#   z_temp=1.01408318777
#   prelec_elevation=1.08327819182
#   prelec_gamma=1.08713372821
#   pow_gain=0.770057761769
#   pow_loss=0.992504416454
#   llh: 28377.6713881
# evaluating:
#   delta=0.367155222879
#   theta=4.71347007923
#   z_temp=1.02058334059
#   prelec_elevation=1.10804931606
#   prelec_gamma=1.11383262063
#   pow_gain=0.678701803003
#   pow_loss=0.992879906647
#   llh: 28376.9303564
# evaluating:
#   delta=0.342851468783
#   theta=4.81426554818
#   z_temp=0.993496003945
#   prelec_elevation=1.12033434793
#   prelec_gamma=1.12584225705
#   pow_gain=0.759599384784
#   pow_loss=0.954672519727
#   llh: 28370.007356
# evaluating:
#   delta=0.345723649715
#   theta=4.6678268937
#   z_temp=0.979529720203
#   prelec_elevation=1.16978723618
#   prelec_gamma=1.17804909986
#   pow_gain=0.689399077176
#   pow_loss=0.921294493877
#   llh: 28387.1838945
# evaluating:
#   delta=0.347086149188
#   theta=4.78487036779
#   z_temp=1.01050904727
#   prelec_elevation=1.09647619043
#   prelec_gamma=1.10355778787
#   pow_gain=0.702448654392
#   pow_loss=0.982624775465
#   llh: 28370.1624045
# evaluating:
#   delta=0.348656661415
#   theta=4.68100676428
#   z_temp=1.01221271486
#   prelec_elevation=1.08357454519
#   prelec_gamma=1.17533251741
#   pow_gain=0.674086763734
#   pow_loss=0.987552180751
#   llh: 28381.5171702
# evaluating:
#   delta=0.353652187901
#   theta=5.03569228722
#   z_temp=1.01557419978
#   prelec_elevation=1.10346958811
#   prelec_gamma=1.15715840953
#   pow_gain=0.586545454212
#   pow_loss=0.984969380614
#   llh: 28397.7459296
# evaluating:
#   delta=0.361493475809
#   theta=4.73561959948
#   z_temp=1.04980935847
#   prelec_elevation=1.10666701689
#   prelec_gamma=1.17269675105
#   pow_gain=0.593490284249
#   pow_loss=0.938227643374
#   llh: 28406.9645178
# evaluating:
#   delta=0.34035791664
#   theta=4.9504940303
#   z_temp=0.996295772746
#   prelec_elevation=1.07999945506
#   prelec_gamma=1.09825615974
#   pow_gain=0.772278218456
#   pow_loss=1.00004043658
#   llh: 28378.7261258
# evaluating:
#   delta=0.33735565494
#   theta=4.69770379372
#   z_temp=1.00718494751
#   prelec_elevation=1.06760194427
#   prelec_gamma=1.0721517566
#   pow_gain=0.891885530631
#   pow_loss=0.978208979731
#   llh: 28408.9523816
# evaluating:
#   delta=0.349578054661
#   theta=4.95119516385
#   z_temp=1.01347688672
#   prelec_elevation=1.09450267715
#   prelec_gamma=1.1359067463
#   pow_gain=0.662880473317
#   pow_loss=0.983279280393
#   llh: 28375.7996092
# evaluating:
#   delta=0.366793643438
#   theta=4.76856663065
#   z_temp=0.973087574334
#   prelec_elevation=1.09765838819
#   prelec_gamma=1.16387121961
#   pow_gain=0.636043362473
#   pow_loss=0.970085326318
#   llh: 28390.8932691
# evaluating:
#   delta=0.339086369621
#   theta=4.91349136431
#   z_temp=1.0244931256
#   prelec_elevation=1.08298937735
#   prelec_gamma=1.10179164809
#   pow_gain=0.76088369922
#   pow_loss=0.985705481494
#   llh: 28376.0992342
# evaluating:
#   delta=0.345253224622
#   theta=5.11578364667
#   z_temp=1.00601185761
#   prelec_elevation=1.09201635926
#   prelec_gamma=1.04862548284
#   pow_gain=0.789252867967
#   pow_loss=0.972917717094
#   llh: 28379.9239092
# evaluating:
#   delta=0.352107268183
#   theta=4.62289731545
#   z_temp=1.01360132592
#   prelec_elevation=1.16045969077
#   prelec_gamma=1.10328070526
#   pow_gain=0.679687836832
#   pow_loss=1.00102064853
#   llh: 28374.0052905
# evaluating:
#   delta=0.351381761079
#   theta=4.52726888736
#   z_temp=1.01468971461
#   prelec_elevation=1.12021537067
#   prelec_gamma=1.17493678143
#   pow_gain=0.644027152034
#   pow_loss=0.998574582574
#   llh: 28389.8252131
# evaluating:
#   delta=0.346785358736
#   theta=4.96865495684
#   z_temp=1.00818132186
#   prelec_elevation=1.09906611211
#   prelec_gamma=1.08020330749
#   pow_gain=0.752946438984
#   pow_loss=0.979331933464
#   llh: 28372.2431471
# evaluating:
#   delta=0.358113481089
#   theta=4.69774733988
#   z_temp=1.02780167065
#   prelec_elevation=1.13767989116
#   prelec_gamma=1.12014814674
#   pow_gain=0.655478435982
#   pow_loss=0.965535147914
#   llh: 28377.5880572
# evaluating:
#   delta=0.353674589977
#   theta=4.76093401249
#   z_temp=1.01992519618
#   prelec_elevation=1.12325978214
#   prelec_gamma=1.11467514999
#   pow_gain=0.6846783816
#   pow_loss=0.97416147008
#   llh: 28372.112359
# evaluating:
#   delta=0.327464565449
#   theta=4.94833241474
#   z_temp=1.00332606155
#   prelec_elevation=1.11397587762
#   prelec_gamma=1.10481240853
#   pow_gain=0.75076244532
#   pow_loss=0.967347553112
#   llh: 28370.0743478
# evaluating:
#   delta=0.352212903229
#   theta=4.7582657155
#   z_temp=0.993368543954
#   prelec_elevation=1.14788910213
#   prelec_gamma=1.11771645548
#   pow_gain=0.665688762274
#   pow_loss=0.96927685587
#   llh: 28373.3289876
# evaluating:
#   delta=0.342474032066
#   theta=4.66543921644
#   z_temp=0.998639542048
#   prelec_elevation=1.1516290666
#   prelec_gamma=1.07840413132
#   pow_gain=0.76449435645
#   pow_loss=0.96770236425
#   llh: 28369.2195857
# evaluating:
#   delta=0.338922020769
#   theta=4.52256124273
#   z_temp=0.991220869714
#   prelec_elevation=1.18019226133
#   prelec_gamma=1.04965282383
#   pow_gain=0.815301298017
#   pow_loss=0.959913906179
#   llh: 28374.9900631
# evaluating:
#   delta=0.337192465368
#   theta=5.00589189369
#   z_temp=0.994240307455
#   prelec_elevation=1.08314901751
#   prelec_gamma=1.1039225798
#   pow_gain=0.771917427112
#   pow_loss=0.940441486315
#   llh: 28370.1232235
# evaluating:
#   delta=0.332795276647
#   theta=4.94127383026
#   z_temp=1.0147221647
#   prelec_elevation=1.07722243912
#   prelec_gamma=1.08554572225
#   pow_gain=0.816267548767
#   pow_loss=0.963946601962
#   llh: 28383.9201155
# evaluating:
#   delta=0.347358496584
#   theta=4.80401774419
#   z_temp=0.998706949142
#   prelec_elevation=1.13022243637
#   prelec_gamma=1.10967377217
#   pow_gain=0.703333458897
#   pow_loss=0.967944292393
#   llh: 28368.4008999
# evaluating:
#   delta=0.338386574811
#   theta=4.6838453853
#   z_temp=0.997202423162
#   prelec_elevation=1.13494723606
#   prelec_gamma=1.13147900301
#   pow_gain=0.71483473489
#   pow_loss=0.950637912634
#   llh: 28368.8980712
# evaluating:
#   delta=0.327129339237
#   theta=4.86954100761
#   z_temp=0.978966327988
#   prelec_elevation=1.11409283858
#   prelec_gamma=1.10180826136
#   pow_gain=0.791718893213
#   pow_loss=0.949087359605
#   llh: 28372.5120284
# evaluating:
#   delta=0.347038277292
#   theta=4.78808576127
#   z_temp=1.00968547913
#   prelec_elevation=1.12096804625
#   prelec_gamma=1.11145842783
#   pow_gain=0.711438509504
#   pow_loss=0.967892942461
#   llh: 28368.8913374
# evaluating:
#   delta=0.333704102342
#   theta=4.84652333615
#   z_temp=0.988147171714
#   prelec_elevation=1.14787410338
#   prelec_gamma=1.11518294919
#   pow_gain=0.776517150453
#   pow_loss=0.936414959076
#   llh: 28369.5061541
# evaluating:
#   delta=0.342601111011
#   theta=4.57996793667
#   z_temp=1.0026750156
#   prelec_elevation=1.17969415798
#   prelec_gamma=1.11803540565
#   pow_gain=0.708362584401
#   pow_loss=0.977447811872
#   llh: 28371.6570103
# evaluating:
#   delta=0.338544626779
#   theta=4.89941090443
#   z_temp=0.996348984491
#   prelec_elevation=1.10728530263
#   prelec_gamma=1.10745078627
#   pow_gain=0.756028716435
#   pow_loss=0.949693067704
#   llh: 28368.3525898
# evaluating:
#   delta=0.355494742738
#   theta=4.62354984125
#   z_temp=0.991595810914
#   prelec_elevation=1.14695570501
#   prelec_gamma=1.11789939914
#   pow_gain=0.731022215084
#   pow_loss=0.945497606387
#   llh: 28369.6967939
# evaluating:
#   delta=0.343720203392
#   theta=4.70312650583
#   z_temp=1.00088295623
#   prelec_elevation=1.14820333673
#   prelec_gamma=1.09460016264
#   pow_gain=0.714020369991
#   pow_loss=0.95555123596
#   llh: 28366.181199
# evaluating:
#   delta=0.344154570696
#   theta=4.64755698465
#   z_temp=1.00457643237
#   prelec_elevation=1.16213783113
#   prelec_gamma=1.07897911544
#   pow_gain=0.691230862594
#   pow_loss=0.955990594076
#   llh: 28365.5093091
# evaluating:
#   delta=0.327836880282
#   theta=4.90070139659
#   z_temp=1.00649189824
#   prelec_elevation=1.12591972997
#   prelec_gamma=1.09142293949
#   pow_gain=0.731228581837
#   pow_loss=0.967724145783
#   llh: 28368.1698214
# evaluating:
#   delta=0.347951171518
#   theta=4.69320734752
#   z_temp=1.01518188788
#   prelec_elevation=1.11872865348
#   prelec_gamma=1.08735081525
#   pow_gain=0.672794055435
#   pow_loss=0.98575227501
#   llh: 28370.1164981
# evaluating:
#   delta=0.337265869636
#   theta=4.808194339
#   z_temp=0.994905850755
#   prelec_elevation=1.14058774091
#   prelec_gamma=1.1082249157
#   pow_gain=0.750586376698
#   pow_loss=0.94874928806
#   llh: 28367.649623
# evaluating:
#   delta=0.337693195385
#   theta=4.91507864512
#   z_temp=1.00362274861
#   prelec_elevation=1.11181902577
#   prelec_gamma=1.13264985723
#   pow_gain=0.680843140936
#   pow_loss=0.94904970521
#   llh: 28368.8021108
# evaluating:
#   delta=0.341582544233
#   theta=4.96273912191
#   z_temp=1.00689424619
#   prelec_elevation=1.12189279623
#   prelec_gamma=1.07990951532
#   pow_gain=0.720790878511
#   pow_loss=0.965660383277
#   llh: 28366.8105131
# evaluating:
#   delta=0.331372060878
#   theta=4.90839970613
#   z_temp=0.993613695098
#   prelec_elevation=1.13613620032
#   prelec_gamma=1.09091611548
#   pow_gain=0.726859209327
#   pow_loss=0.947767479397
#   llh: 28365.0369935
# evaluating:
#   delta=0.32353895267
#   theta=4.96855667856
#   z_temp=0.985577803084
#   prelec_elevation=1.14372027736
#   prelec_gamma=1.08064495931
#   pow_gain=0.734569559239
#   pow_loss=0.937704747865
#   llh: 28364.5624774
# evaluating:
#   delta=0.336673073438
#   theta=4.79668626041
#   z_temp=0.994520726901
#   prelec_elevation=1.15439986411
#   prelec_gamma=1.05486614383
#   pow_gain=0.772804983124
#   pow_loss=0.963369300264
#   llh: 28370.4087971
# evaluating:
#   delta=0.337438164898
#   theta=4.88548054894
#   z_temp=1.00134724318
#   prelec_elevation=1.12246423536
#   prelec_gamma=1.11320392888
#   pow_gain=0.703833601483
#   pow_loss=0.952629603974
#   llh: 28366.4951194
# evaluating:
#   delta=0.324173391757
#   theta=4.9310222484
#   z_temp=1.00019089609
#   prelec_elevation=1.13377982465
#   prelec_gamma=1.07885084509
#   pow_gain=0.750457563045
#   pow_loss=0.940099087818
#   llh: 28366.956185
# evaluating:
#   delta=0.328881194413
#   theta=4.84466090072
#   z_temp=1.00364654977
#   prelec_elevation=1.16428682183
#   prelec_gamma=1.07290241923
#   pow_gain=0.696170547396
#   pow_loss=0.955609175397
#   llh: 28364.6141618
# evaluating:
#   delta=0.339887316377
#   theta=4.82735883833
#   z_temp=0.992690679308
#   prelec_elevation=1.15661442073
#   prelec_gamma=1.08363868878
#   pow_gain=0.710954100724
#   pow_loss=0.934116677207
#   llh: 28363.5359373
# evaluating:
#   delta=0.345912534424
#   theta=4.79068755919
#   z_temp=0.985790069841
#   prelec_elevation=1.17196176612
#   prelec_gamma=1.07974656343
#   pow_gain=0.700816860168
#   pow_loss=0.917312942918
#   llh: 28363.5470314
# evaluating:
#   delta=0.331207311806
#   theta=4.92534146715
#   z_temp=1.00364382067
#   prelec_elevation=1.14652546117
#   prelec_gamma=1.05981207631
#   pow_gain=0.680272798442
#   pow_loss=0.948910788973
#   llh: 28363.1089295
# evaluating:
#   delta=0.328178032891
#   theta=4.98391503123
#   z_temp=1.00801280563
#   prelec_elevation=1.14949432131
#   prelec_gamma=1.03560565661
#   pow_gain=0.645116009314
#   pow_loss=0.948991539429
#   llh: 28363.4526501
# evaluating:
#   delta=0.346309481126
#   theta=4.80089047739
#   z_temp=0.999345325215
#   prelec_elevation=1.15697498787
#   prelec_gamma=1.0837464987
#   pow_gain=0.660348822209
#   pow_loss=0.960078618116
#   llh: 28367.5215661
# evaluating:
#   delta=0.3297074141
#   theta=4.89848930565
#   z_temp=0.999979503371
#   prelec_elevation=1.13957861545
#   prelec_gamma=1.08007475849
#   pow_gain=0.727930377836
#   pow_loss=0.945093970392
#   llh: 28364.8988575
# evaluating:
#   delta=0.325507434327
#   theta=4.75081651352
#   z_temp=0.990666334309
#   prelec_elevation=1.17391510749
#   prelec_gamma=1.08273504081
#   pow_gain=0.692055363694
#   pow_loss=0.92864120469
#   llh: 28363.0699443
# evaluating:
#   delta=0.317469879374
#   theta=4.64485520933
#   z_temp=0.982552378368
#   prelec_elevation=1.19992626312
#   prelec_gamma=1.08414780355
#   pow_gain=0.677687606285
#   pow_loss=0.910131615396
#   llh: 28363.7700457
# evaluating:
#   delta=0.326243033499
#   theta=4.7895996478
#   z_temp=0.993161649071
#   prelec_elevation=1.18804391755
#   prelec_gamma=1.04073523066
#   pow_gain=0.705647429924
#   pow_loss=0.934818155626
#   llh: 28362.4830595
# evaluating:
#   delta=0.320645467799
#   theta=4.74165919723
#   z_temp=0.989068852016
#   prelec_elevation=1.22083375864
#   prelec_gamma=1.00450088154
#   pow_gain=0.706554344144
#   pow_loss=0.925912431452
#   llh: 28363.2380807
# evaluating:
#   delta=0.314409045644
#   theta=5.06810683013
#   z_temp=0.986671093228
#   prelec_elevation=1.15577206075
#   prelec_gamma=1.06403321987
#   pow_gain=0.72236918805
#   pow_loss=0.925407897395
#   llh: 28363.4155669
# evaluating:
#   delta=0.324485239825
#   theta=4.86563665898
#   z_temp=0.987465619325
#   prelec_elevation=1.18295797509
#   prelec_gamma=1.05835428007
#   pow_gain=0.684080761441
#   pow_loss=0.930679928794
#   llh: 28361.8178617
# evaluating:
#   delta=0.321874152688
#   theta=4.84921033565
#   z_temp=0.981208677303
#   prelec_elevation=1.2046476549
#   prelec_gamma=1.04749404086
#   pow_gain=0.662155953244
#   pow_loss=0.923472907995
#   llh: 28361.7982798
# evaluating:
#   delta=0.32330944759
#   theta=4.92076490246
#   z_temp=0.977387752223
#   prelec_elevation=1.16978143531
#   prelec_gamma=1.05826708266
#   pow_gain=0.706122136409
#   pow_loss=0.910982933103
#   llh: 28360.5559945
# evaluating:
#   delta=0.320523574178
#   theta=4.95881690333
#   z_temp=0.964258353451
#   prelec_elevation=1.17252874205
#   prelec_gamma=1.05094941437
#   pow_gain=0.711097930916
#   pow_loss=0.888669811957
#   llh: 28359.6187109
# evaluating:
#   delta=0.32779015262
#   theta=4.79408633169
#   z_temp=0.989365227585
#   prelec_elevation=1.19857896969
#   prelec_gamma=1.04204010116
#   pow_gain=0.661016945045
#   pow_loss=0.914877378947
#   llh: 28361.0011549
# evaluating:
#   delta=0.307985456412
#   theta=4.92577774146
#   z_temp=0.981302222296
#   prelec_elevation=1.19767469744
#   prelec_gamma=1.02716106094
#   pow_gain=0.670364644794
#   pow_loss=0.912968507245
#   llh: 28361.146879
# evaluating:
#   delta=0.331628415936
#   theta=4.64436429576
#   z_temp=0.985787845252
#   prelec_elevation=1.21048923933
#   prelec_gamma=1.0362316273
#   pow_gain=0.644091116538
#   pow_loss=0.918123175586
#   llh: 28362.2162523
# evaluating:
#   delta=0.31495046524
#   theta=4.70685046691
#   z_temp=0.96371341055
#   prelec_elevation=1.2380112041
#   prelec_gamma=1.03371549972
#   pow_gain=0.675849882745
#   pow_loss=0.88582382304
#   llh: 28361.454822
# evaluating:
#   delta=0.317634065837
#   theta=4.86881369294
#   z_temp=0.96899006155
#   prelec_elevation=1.22893472824
#   prelec_gamma=0.996786952051
#   pow_gain=0.659437180079
#   pow_loss=0.893859869709
#   llh: 28359.6596029
# evaluating:
#   delta=0.314438761619
#   theta=4.85266314298
#   z_temp=0.959588578925
#   prelec_elevation=1.22648900695
#   prelec_gamma=1.02623011117
#   pow_gain=0.632642185322
#   pow_loss=0.875980551368
#   llh: 28360.8084765
# evaluating:
#   delta=0.304142049377
#   theta=5.05741245137
#   z_temp=0.959476878079
#   prelec_elevation=1.20861504734
#   prelec_gamma=1.02787613849
#   pow_gain=0.690927375504
#   pow_loss=0.880634781632
#   llh: 28360.618786
# evaluating:
#   delta=0.308829997393
#   theta=4.91205273026
#   z_temp=0.957846960536
#   prelec_elevation=1.21559017247
#   prelec_gamma=1.01100860997
#   pow_gain=0.681082945158
#   pow_loss=0.863045584547
#   llh: 28359.20931
# evaluating:
#   delta=0.302307919746
#   theta=4.94347392757
#   z_temp=0.946166102152
#   prelec_elevation=1.22106143125
#   prelec_gamma=0.99276589453
#   pow_gain=0.690546441114
#   pow_loss=0.832831922824
#   llh: 28360.286556
# evaluating:
#   delta=0.314004979742
#   theta=5.1130418171
#   z_temp=0.973666098714
#   prelec_elevation=1.17582061424
#   prelec_gamma=1.01829946833
#   pow_gain=0.668884176346
#   pow_loss=0.894186601361
#   llh: 28358.3628352
# evaluating:
#   delta=0.313532236992
#   theta=5.3161374922
#   z_temp=0.978642442795
#   prelec_elevation=1.14472531931
#   prelec_gamma=1.01059145263
#   pow_gain=0.665401323147
#   pow_loss=0.898367990521
#   llh: 28358.6063968
# evaluating:
#   delta=0.322689852377
#   theta=4.94761856416
#   z_temp=0.953895537373
#   prelec_elevation=1.20991309712
#   prelec_gamma=1.0223220235
#   pow_gain=0.673946423312
#   pow_loss=0.861675658332
#   llh: 28358.2893885
# evaluating:
#   delta=0.33004205036
#   theta=4.9585389755
#   z_temp=0.940192194911
#   prelec_elevation=1.21603229696
#   prelec_gamma=1.01990250478
#   pow_gain=0.67573731257
#   pow_loss=0.836029233876
#   llh: 28359.3536998
# evaluating:
#   delta=0.301427927529
#   theta=5.12317632606
#   z_temp=0.93569833488
#   prelec_elevation=1.212247147
#   prelec_gamma=1.00180924681
#   pow_gain=0.686988259708
#   pow_loss=0.844566295026
#   llh: 28360.111392
# evaluating:
#   delta=0.311061937362
#   theta=5.14188899565
#   z_temp=0.958649199527
#   prelec_elevation=1.18026800689
#   prelec_gamma=1.01064184697
#   pow_gain=0.730890469256
#   pow_loss=0.874487620794
#   llh: 28362.3228353
# evaluating:
#   delta=0.313594555554
#   theta=4.92496960615
#   z_temp=0.959353734076
#   prelec_elevation=1.21493375694
#   prelec_gamma=1.02233304512
#   pow_gain=0.657204256305
#   pow_loss=0.875607318724
#   llh: 28359.0444838
# evaluating:
#   delta=0.324059365655
#   theta=4.89929887434
#   z_temp=0.958725716373
#   prelec_elevation=1.1999473121
#   prelec_gamma=1.00741207869
#   pow_gain=0.66297010216
#   pow_loss=0.868396972556
#   llh: 28356.8704055
# evaluating:
#   delta=0.334018023793
#   theta=4.82024208583
#   z_temp=0.958350135519
#   prelec_elevation=1.19561344447
#   prelec_gamma=0.997180048796
#   pow_gain=0.648991465489
#   pow_loss=0.862278068018
#   llh: 28355.9269758
# evaluating:
#   delta=0.336084943578
#   theta=4.74698235959
#   z_temp=0.988976202611
#   prelec_elevation=1.19156272601
#   prelec_gamma=1.03215634238
#   pow_gain=0.656052991036
#   pow_loss=0.909525965731
#   llh: 28360.0162947
# evaluating:
#   delta=0.327420689566
#   theta=4.8410308512
#   z_temp=0.975656735678
#   prelec_elevation=1.19673383125
#   prelec_gamma=1.02456956849
#   pow_gain=0.663786808204
#   pow_loss=0.893286048054
#   llh: 28358.428625
# evaluating:
#   delta=0.322674983479
#   theta=4.99340703793
#   z_temp=0.957589239977
#   prelec_elevation=1.16567488849
#   prelec_gamma=1.04511652754
#   pow_gain=0.684846821558
#   pow_loss=0.860068442004
#   llh: 28357.1157438
# evaluating:
#   delta=0.320400163509
#   theta=4.91328672314
#   z_temp=0.960415487084
#   prelec_elevation=1.2201226308
#   prelec_gamma=0.989287526131
#   pow_gain=0.625685753762
#   pow_loss=0.857086679769
#   llh: 28357.8940762
# evaluating:
#   delta=0.335399502041
#   theta=4.9604034656
#   z_temp=0.967560744727
#   prelec_elevation=1.17835618848
#   prelec_gamma=1.02302230657
#   pow_gain=0.63987297055
#   pow_loss=0.881008362956
#   llh: 28357.5156556
# evaluating:
#   delta=0.33686492859
#   theta=4.95761054955
#   z_temp=0.968398831373
#   prelec_elevation=1.16856187017
#   prelec_gamma=1.01189480326
#   pow_gain=0.658799863472
#   pow_loss=0.869989784274
#   llh: 28355.3269193
# evaluating:
#   delta=0.348500115109
#   theta=4.97393102125
#   z_temp=0.972921380022
#   prelec_elevation=1.14537592678
#   prelec_gamma=1.00667568233
#   pow_gain=0.659597667055
#   pow_loss=0.867181017049
#   llh: 28354.2724373
# evaluating:
#   delta=0.329061487591
#   theta=5.07952078165
#   z_temp=0.951314299584
#   prelec_elevation=1.17208810886
#   prelec_gamma=1.004545741
#   pow_gain=0.651020414102
#   pow_loss=0.844852474657
#   llh: 28354.5460499
# evaluating:
#   delta=0.346779056801
#   theta=4.79793237706
#   z_temp=0.946918708226
#   prelec_elevation=1.19193489576
#   prelec_gamma=1.00688620478
#   pow_gain=0.64081911389
#   pow_loss=0.829856456578
#   llh: 28358.1750626
# evaluating:
#   delta=0.344976814001
#   theta=4.92058814797
#   z_temp=0.96469588981
#   prelec_elevation=1.15270578392
#   prelec_gamma=0.998453415686
#   pow_gain=0.626291921375
#   pow_loss=0.853276199105
#   llh: 28354.696559
# evaluating:
#   delta=0.320372683062
#   theta=5.10531884105
#   z_temp=0.976751913696
#   prelec_elevation=1.15947566761
#   prelec_gamma=1.0114798661
#   pow_gain=0.655268604364
#   pow_loss=0.891786755868
#   llh: 28357.0139973
# evaluating:
#   delta=0.346743724798
#   theta=5.04483081437
#   z_temp=0.967922685297
#   prelec_elevation=1.1139602288
#   prelec_gamma=1.03541921331
#   pow_gain=0.678854207522
#   pow_loss=0.874470840133
#   llh: 28354.9542691
# evaluating:
#   delta=0.334985592768
#   theta=5.02183617156
#   z_temp=0.960880839246
#   prelec_elevation=1.1373278255
#   prelec_gamma=1.00522640622
#   pow_gain=0.675804487011
#   pow_loss=0.848681293282
#   llh: 28353.4112498
# evaluating:
#   delta=0.334778638131
#   theta=5.05255252455
#   z_temp=0.957540886505
#   prelec_elevation=1.11681364401
#   prelec_gamma=0.996328456039
#   pow_gain=0.693770245242
#   pow_loss=0.832517758445
#   llh: 28353.7055065
# evaluating:
#   delta=0.351227428271
#   theta=4.99695520884
#   z_temp=0.97179280093
#   prelec_elevation=1.14190996464
#   prelec_gamma=0.971735007725
#   pow_gain=0.628247111847
#   pow_loss=0.866367743171
#   llh: 28354.2888328
# evaluating:
#   delta=0.362345370175
#   theta=4.85408236795
#   z_temp=0.95121323785
#   prelec_elevation=1.14309041324
#   prelec_gamma=0.994015995351
#   pow_gain=0.650104902607
#   pow_loss=0.827386854251
#   llh: 28354.139385
# evaluating:
#   delta=0.356793556982
#   theta=5.1488277752
#   z_temp=0.967575902406
#   prelec_elevation=1.09194605602
#   prelec_gamma=1.00741179738
#   pow_gain=0.656700166374
#   pow_loss=0.846926623882
#   llh: 28352.6378815
# evaluating:
#   delta=0.368181323576
#   theta=5.31312061989
#   z_temp=0.972188785849
#   prelec_elevation=1.0401123618
#   prelec_gamma=1.01252767167
#   pow_gain=0.660554516816
#   pow_loss=0.839250901813
#   llh: 28354.2940022
# evaluating:
#   delta=0.346939236601
#   theta=4.95395246404
#   z_temp=0.957904271802
#   prelec_elevation=1.16730950805
#   prelec_gamma=0.961170514036
#   pow_gain=0.620507698299
#   pow_loss=0.826864075695
#   llh: 28353.3582323
# evaluating:
#   delta=0.34926683957
#   theta=5.08772779217
#   z_temp=0.959190605001
#   prelec_elevation=1.13273644553
#   prelec_gamma=0.987484054041
#   pow_gain=0.671417349281
#   pow_loss=0.840512395748
#   llh: 28352.3576781
# evaluating:
#   delta=0.351411852354
#   theta=5.17129761426
#   z_temp=0.956437962597
#   prelec_elevation=1.12275177634
#   prelec_gamma=0.981999373218
#   pow_gain=0.693980063233
#   pow_loss=0.83413049407
#   llh: 28353.1536391
# evaluating:
#   delta=0.370955123687
#   theta=4.93114001863
#   z_temp=0.974822568204
#   prelec_elevation=1.10211078822
#   prelec_gamma=0.976516961022
#   pow_gain=0.652516552319
#   pow_loss=0.847696097652
#   llh: 28353.1930518
# evaluating:
#   delta=0.354425667412
#   theta=4.99490125139
#   z_temp=0.95520971465
#   prelec_elevation=1.12091773917
#   prelec_gamma=1.01069396667
#   pow_gain=0.682223980423
#   pow_loss=0.820846073274
#   llh: 28353.4353851
# evaluating:
#   delta=0.358845995518
#   theta=5.0239169333
#   z_temp=0.949020659737
#   prelec_elevation=1.11046372342
#   prelec_gamma=0.9769013733
#   pow_gain=0.657338086178
#   pow_loss=0.806794244032
#   llh: 28351.4230614
# evaluating:
#   delta=0.364018935723
#   theta=5.04890988932
#   z_temp=0.937070299595
#   prelec_elevation=1.09300762175
#   prelec_gamma=0.962014218784
#   pow_gain=0.65620829574
#   pow_loss=0.776600857523
#   llh: 28352.2075252
# evaluating:
#   delta=0.344000919122
#   theta=5.19228974814
#   z_temp=0.970102351021
#   prelec_elevation=1.10342732559
#   prelec_gamma=0.984671168268
#   pow_gain=0.668897474503
#   pow_loss=0.84070480391
#   llh: 28352.2924592
# evaluating:
#   delta=0.348942122373
#   theta=5.10786757805
#   z_temp=0.970360913183
#   prelec_elevation=1.12060273863
#   prelec_gamma=0.960558111692
#   pow_gain=0.632970823567
#   pow_loss=0.852919507926
#   llh: 28353.1849603
# evaluating:
#   delta=0.372369776904
#   theta=5.10551305973
#   z_temp=0.967398381141
#   prelec_elevation=1.09941405606
#   prelec_gamma=0.95326330228
#   pow_gain=0.627152127423
#   pow_loss=0.826295206388
#   llh: 28353.3627457
# evaluating:
#   delta=0.36302373087
#   theta=5.08459383769
#   z_temp=0.965768995667
#   prelec_elevation=1.10889249842
#   prelec_gamma=0.966254078264
#   pow_gain=0.63931521732
#   pow_loss=0.831891728111
#   llh: 28352.062488
# evaluating:
#   delta=0.365011702863
#   theta=5.21072287401
#   z_temp=0.972622012547
#   prelec_elevation=1.05274179934
#   prelec_gamma=0.998771641384
#   pow_gain=0.687822492999
#   pow_loss=0.849548896094
#   llh: 28354.9752349
# evaluating:
#   delta=0.351457353166
#   theta=5.01814506653
#   z_temp=0.961583706988
#   prelec_elevation=1.13866758087
#   prelec_gamma=0.970570795873
#   pow_gain=0.637336396974
#   pow_loss=0.832535280795
#   llh: 28352.0546778
# evaluating:
#   delta=0.335425024199
#   theta=5.25839390453
#   z_temp=0.951921184369
#   prelec_elevation=1.12838531707
#   prelec_gamma=0.981726290069
#   pow_gain=0.651476451736
#   pow_loss=0.824385212178
#   llh: 28351.5204197
# evaluating:
#   delta=0.353575997463
#   theta=5.12467386697
#   z_temp=0.951114345442
#   prelec_elevation=1.11211696049
#   prelec_gamma=1.00373319036
#   pow_gain=0.676309502823
#   pow_loss=0.811009145976
#   llh: 28352.6368467
# evaluating:
#   delta=0.344805260135
#   theta=5.07681255318
#   z_temp=0.94919605423
#   prelec_elevation=1.14653675866
#   prelec_gamma=0.955828474099
#   pow_gain=0.658182827573
#   pow_loss=0.806739893476
#   llh: 28351.7404638
# evaluating:
#   delta=0.345516894702
#   theta=5.08729180033
#   z_temp=0.96510952799
#   prelec_elevation=1.13620008225
#   prelec_gamma=0.945820019326
#   pow_gain=0.633394441052
#   pow_loss=0.841437584953
#   llh: 28352.866152
# evaluating:
#   delta=0.351561221773
#   theta=5.11532835031
#   z_temp=0.954613141079
#   prelec_elevation=1.11813774093
#   prelec_gamma=0.989254897604
#   pow_gain=0.66558073738
#   pow_loss=0.81861625572
#   llh: 28351.6412961
# evaluating:
#   delta=0.350481590368
#   theta=5.13212374888
#   z_temp=0.955725421596
#   prelec_elevation=1.11140953875
#   prelec_gamma=0.962575110953
#   pow_gain=0.636618991195
#   pow_loss=0.805678295172
#   llh: 28350.7614111
# evaluating:
#   delta=0.351088965767
#   theta=5.15432172724
#   z_temp=0.953992829894
#   prelec_elevation=1.10074608535
#   prelec_gamma=0.950120639409
#   pow_gain=0.619219812152
#   pow_loss=0.788261244884
#   llh: 28351.0225657
# evaluating:
#   delta=0.357599131172
#   theta=5.01037150741
#   z_temp=0.940705981456
#   prelec_elevation=1.14299929101
#   prelec_gamma=0.959074837493
#   pow_gain=0.629916442171
#   pow_loss=0.795478313085
#   llh: 28352.75113
# evaluating:
#   delta=0.347400472134
#   theta=5.14681018796
#   z_temp=0.96275325863
#   prelec_elevation=1.11332031695
#   prelec_gamma=0.978272085574
#   pow_gain=0.65915221642
#   pow_loss=0.829398181204
#   llh: 28351.3942446
# evaluating:
#   delta=0.334112531214
#   theta=5.13584351794
#   z_temp=0.944177697655
#   prelec_elevation=1.13879920919
#   prelec_gamma=0.980925643871
#   pow_gain=0.665166413382
#   pow_loss=0.803578946911
#   llh: 28352.1788322
# evaluating:
#   delta=0.355795930956
#   theta=5.09740625775
#   z_temp=0.960371171164
#   prelec_elevation=1.11636917611
#   prelec_gamma=0.969921969666
#   pow_gain=0.645778016335
#   pow_loss=0.824813532811
#   llh: 28351.3412745
# evaluating:
#   delta=0.346918502572
#   theta=5.22493834373
#   z_temp=0.948016547528
#   prelec_elevation=1.10265315396
#   prelec_gamma=0.976423547346
#   pow_gain=0.669557124974
#   pow_loss=0.800729180517
#   llh: 28351.2239659
# evaluating:
#   delta=0.354174379157
#   theta=5.20859251152
#   z_temp=0.960067198371
#   prelec_elevation=1.08224580339
#   prelec_gamma=0.997050175762
#   pow_gain=0.651960493632
#   pow_loss=0.824807221277
#   llh: 28351.3511491
# evaluating:
#   delta=0.348165033914
#   theta=5.1967236176
#   z_temp=0.956208413605
#   prelec_elevation=1.10038998183
#   prelec_gamma=0.965850974587
#   pow_gain=0.640671085611
#   pow_loss=0.814699706335
#   llh: 28350.7446778
# evaluating:
#   delta=0.346466939984
#   theta=5.23742125125
#   z_temp=0.957006049868
#   prelec_elevation=1.09151610228
#   prelec_gamma=0.954149013079
#   pow_gain=0.628216259727
#   pow_loss=0.812741431642
#   llh: 28351.1155239
# evaluating:
#   delta=0.367941234264
#   theta=5.03603798139
#   z_temp=0.960125292955
#   prelec_elevation=1.08214373848
#   prelec_gamma=0.968843777699
#   pow_gain=0.651688123791
#   pow_loss=0.806163462493
#   llh: 28351.7306998
# evaluating:
#   delta=0.343554076715
#   theta=5.20280492375
#   z_temp=0.953972211515
#   prelec_elevation=1.11682492242
#   prelec_gamma=0.978505661977
#   pow_gain=0.65152936975
#   pow_loss=0.819829774757
#   llh: 28351.0248731
# evaluating:
#   delta=0.340151143286
#   theta=5.32162580704
#   z_temp=0.964440546665
#   prelec_elevation=1.10188281755
#   prelec_gamma=0.974127062661
#   pow_gain=0.644166856084
#   pow_loss=0.827478867989
#   llh: 28351.1701456
# evaluating:
#   delta=0.349525429856
#   theta=5.24867987212
#   z_temp=0.951190030069
#   prelec_elevation=1.09575836705
#   prelec_gamma=0.971572058126
#   pow_gain=0.638071194318
#   pow_loss=0.804326555613
#   llh: 28350.5518602
# evaluating:
#   delta=0.350587908718
#   theta=5.2996147142
#   z_temp=0.945408415789
#   prelec_elevation=1.08697739211
#   prelec_gamma=0.968222044403
#   pow_gain=0.627530683268
#   pow_loss=0.791790742817
#   llh: 28350.7477468
# evaluating:
#   delta=0.341423251605
#   theta=5.19835108015
#   z_temp=0.951339756527
#   prelec_elevation=1.13069361309
#   prelec_gamma=0.945514505757
#   pow_gain=0.641294545873
#   pow_loss=0.803065896778
#   llh: 28351.2166437
# evaluating:
#   delta=0.335695219992
#   theta=5.33837871175
#   z_temp=0.948455379551
#   prelec_elevation=1.10066293664
#   prelec_gamma=0.965669150736
#   pow_gain=0.646196031609
#   pow_loss=0.796845974949
#   llh: 28350.4910602
# evaluating:
#   delta=0.32564486451
#   theta=5.45886493876
#   z_temp=0.942497483745
#   prelec_elevation=1.0928098169
#   prelec_gamma=0.963542741271
#   pow_gain=0.646405039246
#   pow_loss=0.782862196018
#   llh: 28350.8037902
# evaluating:
#   delta=0.34136599621
#   theta=5.2432581595
#   z_temp=0.960935383766
#   prelec_elevation=1.11381032528
#   prelec_gamma=0.95609488831
#   pow_gain=0.615742324866
#   pow_loss=0.819820839938
#   llh: 28351.5578055
# evaluating:
#   delta=0.345530375981
#   theta=5.22951829767
#   z_temp=0.951246256587
#   prelec_elevation=1.10544244679
#   prelec_gamma=0.971341382587
#   pow_gain=0.656103424947
#   pow_loss=0.805502095373
#   llh: 28350.7348613
# evaluating:
#   delta=0.348034711284
#   theta=5.27875034237
#   z_temp=0.957585460499
#   prelec_elevation=1.07855524721
#   prelec_gamma=0.994383037565
#   pow_gain=0.648236012274
#   pow_loss=0.818180180418
#   llh: 28350.7661944
# evaluating:
#   delta=0.351559267603
#   theta=5.14322548272
#   z_temp=0.942526074313
#   prelec_elevation=1.10070102265
#   prelec_gamma=0.971557902062
#   pow_gain=0.646526318117
#   pow_loss=0.79111044133
#   llh: 28350.8705151
# evaluating:
#   delta=0.35044353157
#   theta=5.24502366857
#   z_temp=0.949724084548
#   prelec_elevation=1.08115208927
#   prelec_gamma=0.965194228485
#   pow_gain=0.637734361128
#   pow_loss=0.790554010726
#   llh: 28350.4655588
# evaluating:
#   delta=0.353888258998
#   theta=5.26613304098
#   z_temp=0.947600021064
#   prelec_elevation=1.06331567269
#   prelec_gamma=0.95853851174
#   pow_gain=0.630836856817
#   pow_loss=0.775916128711
#   llh: 28351.153962
# evaluating:
#   delta=0.342119558959
#   theta=5.33368830556
#   z_temp=0.963226796103
#   prelec_elevation=1.09169057951
#   prelec_gamma=0.97032379595
#   pow_gain=0.640225425049
#   pow_loss=0.81911436398
#   llh: 28350.8220902
# evaluating:
#   delta=0.34447948612
#   theta=5.28607259985
#   z_temp=0.958051615656
#   prelec_elevation=1.09394319029
#   prelec_gamma=0.970632322478
#   pow_gain=0.641800648316
#   pow_loss=0.812113383318
#   llh: 28350.5278577
# evaluating:
#   delta=0.344628336659
#   theta=5.20025551948
#   z_temp=0.948300597105
#   prelec_elevation=1.11823291011
#   prelec_gamma=0.94071274185
#   pow_gain=0.636677055476
#   pow_loss=0.790311254292
#   llh: 28350.9318709
# evaluating:
#   delta=0.347183117628
#   theta=5.25912663664
#   z_temp=0.95526424465
#   prelec_elevation=1.08847466293
#   prelec_gamma=0.980965463636
#   pow_gain=0.645346273075
#   pow_loss=0.811212948887
#   llh: 28350.4968764
# evaluating:
#   delta=0.341239036792
#   theta=5.38316865232
#   z_temp=0.950028871165
#   prelec_elevation=1.07882579691
#   prelec_gamma=0.977775054943
#   pow_gain=0.650787585664
#   pow_loss=0.804394469171
#   llh: 28350.4012606
# evaluating:
#   delta=0.336617760004
#   theta=5.50869110404
#   z_temp=0.94718059595
#   prelec_elevation=1.062533926
#   prelec_gamma=0.985375026938
#   pow_gain=0.657871882898
#   pow_loss=0.80375255617
#   llh: 29022.4315059
# evaluating:
#   delta=0.341576736926
#   theta=5.37183879352
#   z_temp=0.947780295603
#   prelec_elevation=1.08368415814
#   prelec_gamma=0.977906071411
#   pow_gain=0.649625919834
#   pow_loss=0.792428704533
#   llh: 28350.2250062
# evaluating:
#   delta=0.338282588432
#   theta=5.45939638148
#   z_temp=0.943566236602
#   prelec_elevation=1.07533124629
#   prelec_gamma=0.983933619822
#   pow_gain=0.654103336945
#   pow_loss=0.781293203631
#   llh: 28350.3575935
# evaluating:
#   delta=0.3430817837
#   theta=5.37970711227
#   z_temp=0.951752178053
#   prelec_elevation=1.07241503928
#   prelec_gamma=0.974291288789
#   pow_gain=0.632342864751
#   pow_loss=0.797891060969
#   llh: 28350.1370231
# evaluating:
#   delta=0.341857487559
#   theta=5.45480151957
#   z_temp=0.952005138786
#   prelec_elevation=1.05590133553
#   prelec_gamma=0.97576624189
#   pow_gain=0.620462584653
#   pow_loss=0.794085543767
#   llh: 28350.3688769
# evaluating:
#   delta=0.337245688066
#   theta=5.39798189214
#   z_temp=0.951969018281
#   prelec_elevation=1.07542959679
#   prelec_gamma=0.974837536296
#   pow_gain=0.648738429789
#   pow_loss=0.797227887973
#   llh: 28350.263288
# evaluating:
#   delta=0.340224832358
#   theta=5.39256324793
#   z_temp=0.943369547731
#   prelec_elevation=1.07195517541
#   prelec_gamma=0.976978761607
#   pow_gain=0.646991199069
#   pow_loss=0.785188061599
#   llh: 28350.1532047
# evaluating:
#   delta=0.335533119345
#   theta=5.45763395721
#   z_temp=0.942758433902
#   prelec_elevation=1.07270384919
#   prelec_gamma=0.965506562726
#   pow_gain=0.643915553166
#   pow_loss=0.778652813948
#   llh: 28350.2586257
# evaluating:
#   delta=0.346974702511
#   theta=5.41245480938
#   z_temp=0.947939600244
#   prelec_elevation=1.05252726479
#   prelec_gamma=0.980756421909
#   pow_gain=0.642414229362
#   pow_loss=0.787821741884
#   llh: 28350.4273618
# evaluating:
#   delta=0.331235296915
#   theta=5.55364732137
#   z_temp=0.946161042589
#   prelec_elevation=1.06385959088
#   prelec_gamma=0.985677685137
#   pow_gain=0.652213005054
#   pow_loss=0.793333057867
#   llh: 29022.708725
# evaluating:
#   delta=0.345641472906
#   theta=5.32217958177
#   z_temp=0.948833324058
#   prelec_elevation=1.07682896467
#   prelec_gamma=0.970315092648
#   pow_gain=0.641354022109
#   pow_loss=0.791248772511
#   llh: 28350.2197283
# evaluating:
#   delta=0.334323203231
#   theta=5.36042325838
#   z_temp=0.948200876554
#   prelec_elevation=1.09942775818
#   prelec_gamma=0.967132254783
#   pow_gain=0.647230220461
#   pow_loss=0.797044478317
#   llh: 28350.5234143
# evaluating:
#   delta=0.343811827691
#   theta=5.39944692163
#   z_temp=0.948004919322
#   prelec_elevation=1.06425238814
#   prelec_gamma=0.977350380127
#   pow_gain=0.643618227137
#   pow_loss=0.790127425992
#   llh: 28350.1726649
# evaluating:
#   delta=0.340793952063
#   theta=5.39436034953
#   z_temp=0.945533333677
#   prelec_elevation=1.06896539498
#   prelec_gamma=0.969992286086
#   pow_gain=0.636808476009
#   pow_loss=0.776395452979
#   llh: 28350.048223
# evaluating:
#   delta=0.340571409698
#   theta=5.39995619814
#   z_temp=0.943285564933
#   prelec_elevation=1.06403519401
#   prelec_gamma=0.966100901658
#   pow_gain=0.629818921182
#   pow_loss=0.762395944884
#   llh: 28350.3135662
# evaluating:
#   delta=0.345801090502
#   theta=5.37851238325
#   z_temp=0.941754419532
#   prelec_elevation=1.0705146803
#   prelec_gamma=0.971545447531
#   pow_gain=0.635449073661
#   pow_loss=0.777609909893
#   llh: 28350.3744381
# evaluating:
#   delta=0.339384538675
#   theta=5.39311451492
#   z_temp=0.949415368594
#   prelec_elevation=1.07420086767
#   prelec_gamma=0.974014514105
#   pow_gain=0.645416090757
#   pow_loss=0.792323393453
#   llh: 28350.1060462
# evaluating:
#   delta=0.348614064746
#   theta=5.3004261918
#   z_temp=0.952866985252
#   prelec_elevation=1.07366814746
#   prelec_gamma=0.983307264353
#   pow_gain=0.64070067531
#   pow_loss=0.800090863777
#   llh: 28350.3922293
# evaluating:
#   delta=0.338803355695
#   theta=5.41833201586
#   z_temp=0.94528557174
#   prelec_elevation=1.07294492376
#   prelec_gamma=0.969956738132
#   pow_gain=0.643111833702
#   pow_loss=0.784012326405
#   llh: 28350.1024661
# evaluating:
#   delta=0.341778052528
#   theta=5.39950513331
#   z_temp=0.947132345304
#   prelec_elevation=1.05961948584
#   prelec_gamma=0.968636517588
#   pow_gain=0.633129141176
#   pow_loss=0.783910293727
#   llh: 28350.1621767
# evaluating:
#   delta=0.336609482153
#   theta=5.47125735979
#   z_temp=0.945593322919
#   prelec_elevation=1.06155768535
#   prelec_gamma=0.975747903476
#   pow_gain=0.63905107292
#   pow_loss=0.782993517524
#   llh: 28349.8958052
# evaluating:
#   delta=0.332093486777
#   theta=5.5457962488
#   z_temp=0.94397332235
#   prelec_elevation=1.05392204569
#   prelec_gamma=0.978464308889
#   pow_gain=0.637899598325
#   pow_loss=0.778865890031
#   llh: 29021.6929106
# evaluating:
#   delta=0.336381314359
#   theta=5.41450728797
#   z_temp=0.945732700112
#   prelec_elevation=1.0733643468
#   prelec_gamma=0.968254765525
#   pow_gain=0.635481966687
#   pow_loss=0.782076604481
#   llh: 28349.9178294
# evaluating:
#   delta=0.33687316433
#   theta=5.4187354062
#   z_temp=0.946205375503
#   prelec_elevation=1.08192435224
#   prelec_gamma=0.976859556046
#   pow_gain=0.646643288508
#   pow_loss=0.787769825533
#   llh: 28350.0855028
# evaluating:
#   delta=0.337468765063
#   theta=5.43315505108
#   z_temp=0.950778409583
#   prelec_elevation=1.0724369989
#   prelec_gamma=0.968483253296
#   pow_gain=0.632681827598
#   pow_loss=0.7872297045
#   llh: 28349.8947367
# evaluating:
#   delta=0.336090731415
#   theta=5.45345095266
#   z_temp=0.954482840509
#   prelec_elevation=1.07267791064
#   prelec_gamma=0.96423549914
#   pow_gain=0.625527141863
#   pow_loss=0.788250525951
#   llh: 28349.9549037
# evaluating:
#   delta=0.333008094111
#   theta=5.4612820264
#   z_temp=0.942117559698
#   prelec_elevation=1.07198340921
#   prelec_gamma=0.969511287402
#   pow_gain=0.647427008444
#   pow_loss=0.771480603281
#   llh: 28350.3200865
# evaluating:
#   delta=0.340563361303
#   theta=5.4001008408
#   z_temp=0.949343523464
#   prelec_elevation=1.07230713176
#   prelec_gamma=0.973096288442
#   pow_gain=0.636113900674
#   pow_loss=0.791288446547
#   llh: 28349.9746648
# evaluating:
#   delta=0.337042145601
#   theta=5.44987071686
#   z_temp=0.944433841977
#   prelec_elevation=1.06965651341
#   prelec_gamma=0.969525711896
#   pow_gain=0.631696013843
#   pow_loss=0.776752571681
#   llh: 28349.8749324
# evaluating:
#   delta=0.335870949064
#   theta=5.47824881783
#   z_temp=0.941943078669
#   prelec_elevation=1.06738433629
#   prelec_gamma=0.967281310792
#   pow_gain=0.624835975385
#   pow_loss=0.768967160795
#   llh: 28349.9364594
# evaluating:
#   delta=0.337120125697
#   theta=5.43366427335
#   z_temp=0.948320287471
#   prelec_elevation=1.06997291151
#   prelec_gamma=0.973460337516
#   pow_gain=0.630738608081
#   pow_loss=0.782989423094
#   llh: 28349.7737901
# evaluating:
#   delta=0.336278510698
#   theta=5.44133040209
#   z_temp=0.949837645337
#   prelec_elevation=1.06848690538
#   prelec_gamma=0.975212137207
#   pow_gain=0.62455199527
#   pow_loss=0.782477971438
#   llh: 28349.7307293
# evaluating:
#   delta=0.338880416024
#   theta=5.43971659612
#   z_temp=0.948438275088
#   prelec_elevation=1.0571542125
#   prelec_gamma=0.966086828505
#   pow_gain=0.620895355206
#   pow_loss=0.777719965653
#   llh: 28350.1084026
# evaluating:
#   delta=0.337374977254
#   theta=5.42398070368
#   z_temp=0.9467636004
#   prelec_elevation=1.0757318173
#   prelec_gamma=0.974166374161
#   pow_gain=0.640206305183
#   pow_loss=0.785257360563
#   llh: 28349.9162082
# evaluating:
#   delta=0.333982778346
#   theta=5.47255461112
#   z_temp=0.949461821692
#   prelec_elevation=1.07204643328
#   prelec_gamma=0.974146695057
#   pow_gain=0.63170097604
#   pow_loss=0.791626311802
#   llh: 28349.799452
# evaluating:
#   delta=0.332333202547
#   theta=5.48751519708
#   z_temp=0.945685431399
#   prelec_elevation=1.06863021122
#   prelec_gamma=0.971342808878
#   pow_gain=0.631134715766
#   pow_loss=0.776829851164
#   llh: 28349.7010576
# evaluating:
#   delta=0.328218123169
#   theta=5.53122237522
#   z_temp=0.943856385366
#   prelec_elevation=1.06679175095
#   prelec_gamma=0.970466069095
#   pow_gain=0.628645123312
#   pow_loss=0.769600553473
#   llh: 29021.8457012
# evaluating:
#   delta=0.335358646116
#   theta=5.49396815251
#   z_temp=0.949282749404
#   prelec_elevation=1.06622038601
#   prelec_gamma=0.977066629895
#   pow_gain=0.630524578061
#   pow_loss=0.784542620854
#   llh: 28349.6739443
# evaluating:
#   delta=0.334847311995
#   theta=5.53369858478
#   z_temp=0.951057774049
#   prelec_elevation=1.06264840561
#   prelec_gamma=0.98147256208
#   pow_gain=0.628045883748
#   pow_loss=0.785775629041
#   llh: 29014.5371416
# evaluating:
#   delta=0.33378888861
#   theta=5.50449115076
#   z_temp=0.948971605975
#   prelec_elevation=1.06113536371
#   prelec_gamma=0.971983665755
#   pow_gain=0.623034031817
#   pow_loss=0.781157653427
#   llh: 29016.5237321
# evaluating:
#   delta=0.336478455093
#   theta=5.44410831545
#   z_temp=0.947315601793
#   prelec_elevation=1.07208270391
#   prelec_gamma=0.973620697059
#   pow_gain=0.635913236841
#   pow_loss=0.784232433779
#   llh: 28349.8163225
# evaluating:
#   delta=0.334516947408
#   theta=5.44945762484
#   z_temp=0.950633963134
#   prelec_elevation=1.07831664382
#   prelec_gamma=0.969794363178
#   pow_gain=0.623292739486
#   pow_loss=0.783775472538
#   llh: 28349.7661383
# evaluating:
#   delta=0.332814288025
#   theta=5.49221781176
#   z_temp=0.945407606056
#   prelec_elevation=1.06911722883
#   prelec_gamma=0.977433616182
#   pow_gain=0.626979388204
#   pow_loss=0.778552362145
#   llh: 28349.6174378
# evaluating:
#   delta=0.330487049506
#   theta=5.5217491921
#   z_temp=0.942722204292
#   prelec_elevation=1.06745734379
#   prelec_gamma=0.981908797625
#   pow_gain=0.624128168507
#   pow_loss=0.774213690967
#   llh: 29020.6716723
# evaluating:
#   delta=0.332032948179
#   theta=5.48760131595
#   z_temp=0.95203039197
#   prelec_elevation=1.071743633
#   prelec_gamma=0.978650558806
#   pow_gain=0.626617594634
#   pow_loss=0.789543720811
#   llh: 28349.6151373
# evaluating:
#   delta=0.329528349469
#   theta=5.5064666155
#   z_temp=0.955828666966
#   prelec_elevation=1.07278719279
#   prelec_gamma=0.98321298226
#   pow_gain=0.62407838503
#   pow_loss=0.795939295375
#   llh: 29012.657302
# evaluating:
#   delta=0.331326493855
#   theta=5.50579028894
#   z_temp=0.950495715061
#   prelec_elevation=1.06922056511
#   prelec_gamma=0.975992676999
#   pow_gain=0.619744473862
#   pow_loss=0.783581369293
#   llh: 29015.4086281
# evaluating:
#   delta=0.335190464783
#   theta=5.45952880882
#   z_temp=0.94811063011
#   prelec_elevation=1.07136716921
#   prelec_gamma=0.974213692044
#   pow_gain=0.631871046096
#   pow_loss=0.784069667657
#   llh: 28349.7241888
# evaluating:
#   delta=0.33416722387
#   theta=5.47362233547
#   z_temp=0.947963440425
#   prelec_elevation=1.06906276028
#   prelec_gamma=0.975485820997
#   pow_gain=0.624005326107
#   pow_loss=0.774028450086
#   llh: 28349.6758808
# evaluating:
#   delta=0.333533133798
#   theta=5.50362352478
#   z_temp=0.946028292495
#   prelec_elevation=1.06014858301
#   prelec_gamma=0.981464283681
#   pow_gain=0.63261715884
#   pow_loss=0.779094425792
#   llh: 29018.6811683
# evaluating:
#   delta=0.334270994005
#   theta=5.46299909982
#   z_temp=0.949482545474
#   prelec_elevation=1.07377462862
#   prelec_gamma=0.972711843304
#   pow_gain=0.625623844324
#   pow_loss=0.782605210852
#   llh: 28349.6895539
# evaluating:
#   delta=0.33119799431
#   theta=5.51794180403
#   z_temp=0.946723153188
#   prelec_elevation=1.07148909952
#   prelec_gamma=0.975332139966
#   pow_gain=0.631664145642
#   pow_loss=0.78042828101
#   llh: 29019.4968933
# evaluating:
#   delta=0.335008381601
#   theta=5.46048325257
#   z_temp=0.9490590223
#   prelec_elevation=1.06923745392
#   prelec_gamma=0.975242137897
#   pow_gain=0.626330032863
#   pow_loss=0.781965548831
#   llh: 28349.6712997
# evaluating:
#   delta=0.332234016457
#   theta=5.50001609551
#   z_temp=0.948721137611
#   prelec_elevation=1.06800034562
#   prelec_gamma=0.976624426801
#   pow_gain=0.622761948178
#   pow_loss=0.778235407983
#   llh: 29016.3379406
# evaluating:
#   delta=0.334451352702
#   theta=5.46965063049
#   z_temp=0.948263256986
#   prelec_elevation=1.07052546331
#   prelec_gamma=0.974816375733
#   pow_gain=0.629593771617
#   pow_loss=0.782611102739
#   llh: 28349.6719073
# evaluating:
#   delta=0.335696464453
#   theta=5.46692554537
#   z_temp=0.951882857919
#   prelec_elevation=1.0712788042
#   prelec_gamma=0.980487757641
#   pow_gain=0.623058008751
#   pow_loss=0.787127010641
#   llh: 28349.7409808
# evaluating:
#   delta=0.333174018023
#   theta=5.48236778415
#   z_temp=0.947234788029
#   prelec_elevation=1.06929235946
#   prelec_gamma=0.973629046068
#   pow_gain=0.629115539012
#   pow_loss=0.779404141033
#   llh: 28349.6461876
# evaluating:
#   delta=0.333445251285
#   theta=5.49697555244
#   z_temp=0.947443527431
#   prelec_elevation=1.06485373847
#   prelec_gamma=0.979380781147
#   pow_gain=0.629566507247
#   pow_loss=0.780437059577
#   llh: 28349.5842313
# evaluating:
#   delta=0.333032379925
#   theta=5.51396377874
#   z_temp=0.94642401841
#   prelec_elevation=1.06039329339
#   prelec_gamma=0.982715250068
#   pow_gain=0.631537838708
#   pow_loss=0.779352983939
#   llh: 29018.2483179
# evaluating:
#   delta=0.333342743539
#   theta=5.4930246645
#   z_temp=0.948814085911
#   prelec_elevation=1.06836302914
#   prelec_gamma=0.977719649211
#   pow_gain=0.632773934361
#   pow_loss=0.790844851625
#   llh: 28349.7293042
# evaluating:
#   delta=0.333961103787
# ...
#   delta=0.271949554056
#   theta=5.31278410636
#   z_temp=0.957731308643
#   prelec_elevation=0.967020401946
#   prelec_gamma=1.04779203518
#   pow_gain=0.585411165873
#   pow_loss=0.726912965131
#   llh: 28347.9226839
# evaluating:
#   delta=0.271651924542
#   theta=5.31169469239
#   z_temp=0.957853381759
#   prelec_elevation=0.96700037892
#   prelec_gamma=1.04806909188
#   pow_gain=0.585212236545
#   pow_loss=0.727143555995
#   llh: 28347.9227573
# evaluating:
#   delta=0.271689004708
#   theta=5.31424563136
#   z_temp=0.957294656118
#   prelec_elevation=0.966588883068
#   prelec_gamma=1.04834733365
#   pow_gain=0.585401790191
#   pow_loss=0.726948246994
#   llh: 28347.9227467
# evaluating:
#   delta=0.27170620277
#   theta=5.31311334662
#   z_temp=0.95770717556
#   prelec_elevation=0.966351776936
#   prelec_gamma=1.04780759938
#   pow_gain=0.585389784184
#   pow_loss=0.726974665692
#   llh: 28347.9229871
# evaluating:
#   delta=0.27198821039
#   theta=5.3135093779
#   z_temp=0.957683793947
#   prelec_elevation=0.967207526758
#   prelec_gamma=1.04815713877
#   pow_gain=0.585370916476
#   pow_loss=0.727321751289
#   llh: 28347.9226341
# evaluating:
#   delta=0.271298578706
#   theta=5.31185430029
#   z_temp=0.957788085456
#   prelec_elevation=0.965952671593
#   prelec_gamma=1.04898793543
#   pow_gain=0.58488090192
#   pow_loss=0.726716670084
#   llh: 28347.9226853
# evaluating:
#   delta=0.271924062626
#   theta=5.31479652109
#   z_temp=0.957530849739
#   prelec_elevation=0.966392750811
#   prelec_gamma=1.04851109123
#   pow_gain=0.585335820504
#   pow_loss=0.72706354638
#   llh: 28347.9227522
# evaluating:
#   delta=0.271856028105
#   theta=5.31402106391
#   z_temp=0.957611482744
#   prelec_elevation=0.966544657839
#   prelec_gamma=1.04840059139
#   pow_gain=0.585304924514
#   pow_loss=0.727083548784
#   llh: 28347.9226078
# evaluating:
#   delta=0.271934703431
#   theta=5.31218141999
#   z_temp=0.958180097273
#   prelec_elevation=0.966791610884
#   prelec_gamma=1.04824806595
#   pow_gain=0.58511859095
#   pow_loss=0.727297513035
#   llh: 28347.9227958
# evaluating:
#   delta=0.271750429389
#   theta=5.31372957852
#   z_temp=0.957516016407
#   prelec_elevation=0.966639565022
#   prelec_gamma=1.04832251673
#   pow_gain=0.585330990381
#   pow_loss=0.727035563505
#   llh: 28347.9226013
# evaluating:
#   delta=0.271417251938
#   theta=5.31416931371
#   z_temp=0.957462217159
#   prelec_elevation=0.966283449046
#   prelec_gamma=1.04859546627
#   pow_gain=0.584812561386
#   pow_loss=0.726728641492
#   llh: 28347.9226044
# evaluating:
#   delta=0.272257696779
#   theta=5.31556125921
#   z_temp=0.957483224969
#   prelec_elevation=0.967420668006
#   prelec_gamma=1.04756701533
#   pow_gain=0.585536213493
#   pow_loss=0.727425498118
#   llh: 28347.9226819
# evaluating:
#   delta=0.271694762207
#   theta=5.31542492538
#   z_temp=0.957469120732
#   prelec_elevation=0.966467299386
#   prelec_gamma=1.04869862419
#   pow_gain=0.585041677432
#   pow_loss=0.727375641068
#   llh: 28347.9227046
# evaluating:
#   delta=0.271885856094
#   theta=5.31344431112
#   z_temp=0.957665761665
#   prelec_elevation=0.966882126306
#   prelec_gamma=1.04801868243
#   pow_gain=0.585318793763
#   pow_loss=0.727028634115
#   llh: 28347.922576
# evaluating:
#   delta=0.271280379288
#   theta=5.31204293022
#   z_temp=0.957769357748
#   prelec_elevation=0.965913164267
#   prelec_gamma=1.04905269179
#   pow_gain=0.584854509889
#   pow_loss=0.726749718365
#   llh: 28347.9227041
# evaluating:
#   delta=0.272013367406
#   theta=5.31468167696
#   z_temp=0.957554758163
#   prelec_elevation=0.967043792072
#   prelec_gamma=1.04793843444
#   pow_gain=0.585365787592
#   pow_loss=0.72725655318
#   llh: 28347.9225746
# evaluating:
#   delta=0.272132427079
#   theta=5.31388661025
#   z_temp=0.957571517151
#   prelec_elevation=0.967470037389
#   prelec_gamma=1.04758734166
#   pow_gain=0.585561851898
#   pow_loss=0.727077020616
#   llh: 28347.9227883
# evaluating:
#   delta=0.271688629914
#   theta=5.31392051991
#   z_temp=0.957632627228
#   prelec_elevation=0.966462021709
#   prelec_gamma=1.04848878767
#   pow_gain=0.585101602605
#   pow_loss=0.72711929494
#   llh: 28347.922561
# evaluating:
#   delta=0.271599319793
#   theta=5.31442652464
#   z_temp=0.957526101395
#   prelec_elevation=0.96617552567
#   prelec_gamma=1.04831422939
#   pow_gain=0.585062174777
#   pow_loss=0.726830811037
#   llh: 28347.9226007
# evaluating:
#   delta=0.271658156846
#   theta=5.31403068454
#   z_temp=0.957574017927
#   prelec_elevation=0.966732928255
#   prelec_gamma=1.04804610191
#   pow_gain=0.58505880967
#   pow_loss=0.726996802758
#   llh: 28347.9225744
# evaluating:
#   delta=0.272165762986
#   theta=5.31384282641
#   z_temp=0.957755226589
#   prelec_elevation=0.967122559679
#   prelec_gamma=1.04769426579
#   pow_gain=0.585621529451
#   pow_loss=0.727428327554
#   llh: 28347.9227179
# evaluating:
#   delta=0.2716043797
#   theta=5.31408769188
#   z_temp=0.957535469517
#   prelec_elevation=0.966493226704
#   prelec_gamma=1.04837016615
#   pow_gain=0.585014803402
#   pow_loss=0.726903563007
#   llh: 28347.9225427
# evaluating:
#   delta=0.271790857053
#   theta=5.31438487971
#   z_temp=0.957706985372
#   prelec_elevation=0.966724632755
#   prelec_gamma=1.04798082945
#   pow_gain=0.58501276132
#   pow_loss=0.727083691113
#   llh: 28347.9225638
# evaluating:
#   delta=0.271996691581
#   theta=5.31367603504
#   z_temp=0.957748581521
#   prelec_elevation=0.967345559846
#   prelec_gamma=1.04789385966
#   pow_gain=0.585267458793
#   pow_loss=0.727360695031
#   llh: 28347.9226131
# evaluating:
#   delta=0.27169866274
#   theta=5.31423890224
#   z_temp=0.957581721426
#   prelec_elevation=0.966468034214
#   prelec_gamma=1.04820913696
#   pow_gain=0.585113495781
#   pow_loss=0.726963282036
#   llh: 28347.9225483
# evaluating:
#   delta=0.271580895706
#   theta=5.31441613851
#   z_temp=0.957422898611
#   prelec_elevation=0.96638828907
#   prelec_gamma=1.04841530152
#   pow_gain=0.58500057061
#   pow_loss=0.726818788202
#   llh: 28347.9225715
# evaluating:
#   delta=0.271552700868
#   theta=5.3150586871
#   z_temp=0.957479517834
#   prelec_elevation=0.966350137917
#   prelec_gamma=1.04839524846
#   pow_gain=0.584872015089
#   pow_loss=0.727011930238
#   llh: 28347.9225955
# evaluating:
#   delta=0.271802567287
#   theta=5.31384790511
#   z_temp=0.957619200707
#   prelec_elevation=0.966749129208
#   prelec_gamma=1.04811282394
#   pow_gain=0.585207099094
#   pow_loss=0.727024458146
#   llh: 28347.9225405
# evaluating:
#   delta=0.27136496095
#   theta=5.31358310072
#   z_temp=0.957608933491
#   prelec_elevation=0.966104282762
#   prelec_gamma=1.04852532202
#   pow_gain=0.584779681689
#   pow_loss=0.726717698306
#   llh: 28347.9226015
# evaluating:
#   delta=0.271851265792
#   theta=5.3144070329
#   z_temp=0.957568301995
#   prelec_elevation=0.966808914744
#   prelec_gamma=1.04808515634
#   pow_gain=0.585219261116
#   pow_loss=0.727121839462
#   llh: 28347.9225395
# evaluating:
#   delta=0.271775345495
#   theta=5.31434162125
#   z_temp=0.957588040603
#   prelec_elevation=0.966436857003
#   prelec_gamma=1.04842881295
#   pow_gain=0.585132502881
#   pow_loss=0.727013173501
#   llh: 28347.9225893
# evaluating:
#   delta=0.271687454008
#   theta=5.31410841872
#   z_temp=0.957577523596
#   prelec_elevation=0.966658910442
#   prelec_gamma=1.04814177967
#   pow_gain=0.585077232973
#   pow_loss=0.727000895444
#   llh: 28347.9225406
# evaluating:
#   delta=0.271883051863
#   theta=5.31386824734
#   z_temp=0.957783338487
#   prelec_elevation=0.96685881658
#   prelec_gamma=1.04798146425
#   pow_gain=0.585212645473
#   pow_loss=0.727243218697
#   llh: 28347.9225671
# evaluating:
#   delta=0.271807512824
#   theta=5.31400522013
#   z_temp=0.957693228518
#   prelec_elevation=0.966741184703
#   prelec_gamma=1.04808992357
#   pow_gain=0.585159626758
#   pow_loss=0.727137111073
#   llh: 28347.9225392
# evaluating:
#   delta=0.271677849308
#   theta=5.31379103198
#   z_temp=0.957495321195
#   prelec_elevation=0.966527202023
#   prelec_gamma=1.04844710606
#   pow_gain=0.585242416317
#   pow_loss=0.726993578632
#   llh: 28347.9225896
# evaluating:
#   delta=0.271762605117
#   theta=5.31423641777
#   z_temp=0.957654069328
#   prelec_elevation=0.966675275072
#   prelec_gamma=1.04809739861
#   pow_gain=0.585070175069
#   pow_loss=0.727061162993
#   llh: 28347.9225364
# evaluating:
#   delta=0.27180121222
#   theta=5.31434564831
#   z_temp=0.957575805654
#   prelec_elevation=0.966850742602
#   prelec_gamma=1.04782732239
#   pow_gain=0.585144595736
#   pow_loss=0.726941365677
#   llh: 28347.9225823
# evaluating:
#   delta=0.27171677549
#   theta=5.31402680201
#   z_temp=0.957618421835
#   prelec_elevation=0.966559201932
#   prelec_gamma=1.04832342135
#   pow_gain=0.585112350888
#   pow_loss=0.727074812624
#   llh: 28347.9225363
# evaluating:
#   delta=0.271796354466
#   theta=5.31396666592
#   z_temp=0.957637197287
#   prelec_elevation=0.966870778016
#   prelec_gamma=1.04813962579
#   pow_gain=0.585132375448
#   pow_loss=0.727129244464
#   llh: 28347.922537
# evaluating:
#   delta=0.271945487438
#   theta=5.31408329742
#   z_temp=0.957712514274
#   prelec_elevation=0.966953457329
#   prelec_gamma=1.04791272792
#   pow_gain=0.585264659839
#   pow_loss=0.727253443908
#   llh: 28347.9225606
# evaluating:
#   delta=0.271689656635
#   theta=5.31408659327
#   z_temp=0.957579730706
#   prelec_elevation=0.966608284361
#   prelec_gamma=1.04825580659
#   pow_gain=0.585077267512
#   pow_loss=0.726991033233
#   llh: 28347.9225313
# evaluating:
#   delta=0.271863042452
#   theta=5.31405633474
#   z_temp=0.957671090797
#   prelec_elevation=0.966773308997
#   prelec_gamma=1.04817369352
#   pow_gain=0.585202240137
#   pow_loss=0.727153293698
#   llh: 28347.9225422
# evaluating:
#   delta=0.271731351119
#   theta=5.31409539772
#   z_temp=0.957600915396
#   prelec_elevation=0.966687510081
#   prelec_gamma=1.04814975814
#   pow_gain=0.585108484764
#   pow_loss=0.727038995007
#   llh: 28347.9225324
# evaluating:
#   delta=0.271727581697
#   theta=5.31438756052
#   z_temp=0.957624189311
#   prelec_elevation=0.966665484766
#   prelec_gamma=1.04821320188
#   pow_gain=0.585044198493
#   pow_loss=0.727133884384
#   llh: 28347.9225408
# evaluating:
#   delta=0.27178382089
#   theta=5.31398281897
#   z_temp=0.957620447858
#   prelec_elevation=0.966728218098
#   prelec_gamma=1.04813791842
#   pow_gain=0.585166373944
#   pow_loss=0.727051814706
#   llh: 28347.9225324
# evaluating:
#   delta=0.271659613219
#   theta=5.31370722875
#   z_temp=0.957689986841
#   prelec_elevation=0.966582643045
#   prelec_gamma=1.04825594437
#   pow_gain=0.58501692585
#   pow_loss=0.727016495996
#   llh: 28347.9225375
# evaluating:
#   delta=0.271661109158
#   theta=5.31402390113
#   z_temp=0.957564134125
#   prelec_elevation=0.96660507547
#   prelec_gamma=1.04829861165
#   pow_gain=0.585035788521
#   pow_loss=0.726966762933
#   llh: 28347.922535
# evaluating:
#   delta=0.271809436173
#   theta=5.31441237033
#   z_temp=0.957531417883
#   prelec_elevation=0.966770026392
#   prelec_gamma=1.0481447815
#   pow_gain=0.585183878763
#   pow_loss=0.727073168564
#   llh: 28347.9225393
# evaluating:
#   delta=0.271697068958
#   theta=5.31388351415
#   z_temp=0.957650344602
#   prelec_elevation=0.966629488882
#   prelec_gamma=1.04822815365
#   pow_gain=0.585058664078
#   pow_loss=0.727030664138
#   llh: 28347.9225309
# evaluating:
#   delta=0.271644327639
#   theta=5.31412917552
#   z_temp=0.957587963813
#   prelec_elevation=0.966412951668
#   prelec_gamma=1.04828639376
#   pow_gain=0.585047368774
#   pow_loss=0.726932254288
#   llh: 28347.9225437
# evaluating:
#   delta=0.271758347759
#   theta=5.31400729332
#   z_temp=0.957624888918
#   prelec_elevation=0.966756321429
#   prelec_gamma=1.04817631778
#   pow_gain=0.585111123779
#   pow_loss=0.72707999692
#   llh: 28347.9225303
# evaluating:
#   delta=0.2716768606
#   theta=5.31379395953
#   z_temp=0.957562754512
#   prelec_elevation=0.966631610714
#   prelec_gamma=1.04835116928
#   pow_gain=0.585121268784
#   pow_loss=0.727005716881
#   llh: 28347.9225447
# evaluating:
#   delta=0.271741168988
#   theta=5.31412580321
#   z_temp=0.957631240624
#   prelec_elevation=0.966664358983
#   prelec_gamma=1.04816084127
#   pow_gain=0.585082948498
#   pow_loss=0.727047301465
#   llh: 28347.9225301
# evaluating:
#   delta=0.271729659797
#   theta=5.31403186135
#   z_temp=0.957602064517
#   prelec_elevation=0.966777728726
#   prelec_gamma=1.04807869508
#   pow_gain=0.585070692282
#   pow_loss=0.726984206919
#   llh: 28347.9225372
# evaluating:
#   delta=0.271719996567
#   theta=5.31402806685
#   z_temp=0.957614332505
#   prelec_elevation=0.966613833631
#   prelec_gamma=1.04826223978
#   pow_gain=0.585101936237
#   pow_loss=0.727052161198
#   llh: 28347.9225308
# evaluating:
#   delta=0.271802151104
#   theta=5.31403595244
#   z_temp=0.95767069462
#   prelec_elevation=0.96673435752
#   prelec_gamma=1.04809311282
#   pow_gain=0.585166153997
#   pow_loss=0.727116656114
#   llh: 28347.922537
# evaluating:
#   delta=0.271696369644
#   theta=5.31402691396
#   z_temp=0.957590774249
#   prelec_elevation=0.966637395983
#   prelec_gamma=1.04824723694
#   pow_gain=0.58506837989
#   pow_loss=0.727004236228
#   llh: 28347.9225303
# evaluating:
#   delta=0.271654453302
#   theta=5.31408963317
#   z_temp=0.957605902713
#   prelec_elevation=0.966585265716
#   prelec_gamma=1.04828503991
#   pow_gain=0.585007570273
#   pow_loss=0.727018010491
#   llh: 28347.9225358
# evaluating:
#   delta=0.271751478993
#   theta=5.31400952252
#   z_temp=0.957616811572
#   prelec_elevation=0.966692480002
#   prelec_gamma=1.0481746988
#   pow_gain=0.585126673026
#   pow_loss=0.727043363652
#   llh: 28347.9225296
# evaluating:
#   delta=0.271712673893
#   theta=5.31395251864
#   z_temp=0.95762997694
#   prelec_elevation=0.966627393711
#   prelec_gamma=1.0482803261
#   pow_gain=0.585070656099
#   pow_loss=0.727032078374
#   llh: 28347.9225309
# evaluating:
#   delta=0.271760944737
#   theta=5.31392301605
#   z_temp=0.957665517697
#   prelec_elevation=0.966712079245
#   prelec_gamma=1.04818128322
#   pow_gain=0.585099984376
#   pow_loss=0.727091767332
#   llh: 28347.9225307
# evaluating:
#   delta=0.271771782637
#   theta=5.31413738144
#   z_temp=0.957599238971
#   prelec_elevation=0.96671447197
#   prelec_gamma=1.0481955446
#   pow_gain=0.585130393609
#   pow_loss=0.727069594482
#   llh: 28347.9225301
# evaluating:
#   delta=0.271773065914
#   theta=5.31412119489
#   z_temp=0.957610824357
#   prelec_elevation=0.966741446645
#   prelec_gamma=1.04811914887
#   pow_gain=0.585135469448
#   pow_loss=0.727078899134
#   llh: 28347.9225316
# evaluating:
#   delta=0.271727771898
#   theta=5.3139946877
#   z_temp=0.957625188794
#   prelec_elevation=0.966655906944
#   prelec_gamma=1.04824003179
#   pow_gain=0.585086859436
#   pow_loss=0.727043783564
#   llh: 28347.9225292
# evaluating:
#   delta=0.271767964763
#   theta=5.31403610978
#   z_temp=0.957629570588
#   prelec_elevation=0.966767027671
#   prelec_gamma=1.04813089005
#   pow_gain=0.585099881653
#   pow_loss=0.7270564227
#   llh: 28347.9225297
# evaluating:
#   delta=0.271729022315
#   theta=5.31417347306
#   z_temp=0.957568114793
#   prelec_elevation=0.966684481607
#   prelec_gamma=1.04819744857
#   pow_gain=0.585101804164
#   pow_loss=0.7270067181
#   llh: 28347.9225314
# evaluating:
#   delta=0.271752964132
#   theta=5.31398563031
#   z_temp=0.957641166971
#   prelec_elevation=0.966705179836
#   prelec_gamma=1.04818532455
#   pow_gain=0.585100439323
#   pow_loss=0.727070505024
#   llh: 28347.9225291
# evaluating:
#   delta=0.271730081114
#   theta=5.31408300637
#   z_temp=0.957613394444
#   prelec_elevation=0.966625627539
#   prelec_gamma=1.04820498736
#   pow_gain=0.585087612059
#   pow_loss=0.727015776541
#   llh: 28347.9225293
# evaluating:
#   delta=0.271801691077
#   theta=5.31407941214
#   z_temp=0.957653972027
#   prelec_elevation=0.966741190573
#   prelec_gamma=1.04812199689
#   pow_gain=0.585135850854
#   pow_loss=0.727094834465
#   llh: 28347.9225311
# evaluating:
#   delta=0.271722700002
#   theta=5.3140400385
#   z_temp=0.957606573694
#   prelec_elevation=0.96666334463
#   prelec_gamma=1.04821592693
#   pow_gain=0.585085247631
#   pow_loss=0.727026885788
#   llh: 28347.9225289
# evaluating:
#   delta=0.271712254474
#   theta=5.31394113239
#   z_temp=0.957647602939
#   prelec_elevation=0.966649506774
#   prelec_gamma=1.04817951276
#   pow_gain=0.585060938285
#   pow_loss=0.727017273728
#   llh: 28347.9225303
# evaluating:
#   delta=0.271756900596
#   theta=5.31408831917
#   z_temp=0.957611329963
#   prelec_elevation=0.966698230671
#   prelec_gamma=1.04819153664
#   pow_gain=0.585113029778
#   pow_loss=0.727056514293
#   llh: 28347.9225289
# evaluating:
#   delta=0.271747362869
#   theta=5.31394200089
#   z_temp=0.957609912526
#   prelec_elevation=0.966709297387
#   prelec_gamma=1.04822298619
#   pow_gain=0.585116978047
#   pow_loss=0.727042198981
#   llh: 28347.9225305
# evaluating:
#   delta=0.271742717458
#   theta=5.31407985263
#   z_temp=0.9576259086
#   prelec_elevation=0.966675593584
#   prelec_gamma=1.0481763775
#   pow_gain=0.585091455885
#   pow_loss=0.727046025844
#   llh: 28347.9225289

# %%
f
# Out:
#   status: 0
#     nfev: 749
#  success: True
#      fun: 28347.922528850402
#        x: array([ 0.27174272,  5.31407985,  0.95762591,  0.96667559,  1.04817638,
#         0.58509146,  0.72704603])
#  message: 'Optimization terminated successfully.'
#      nit: 488

# %%
ps = np.arange(0, 1, .01)
fig, ax = plt.subplots()
ax.plot(ps, ps, '--')
ax.plot(ps, [pweight_prelec(p, f['x'][3], f['x'][4]) for p in ps], label='best-fitting w_p')
ax.set_aspect(1)
ax.set_xlabel('true')
ax.set_ylabel('weighted')
ax.set_title('Probability weighting fcn')
ax.legend()
plt.show()

# %%
xs = np.arange(-30, 30, .05)
fig, ax = plt.subplots()
ax.plot(xs, xs, '--')
ax.plot(xs, [util(x, f['x'][5], f['x'][6], 1.) for x in xs], label='best-fitting pow_gain, pow_loss')
ax.set_aspect(1)
ax.set_xlabel('true')
ax.set_ylabel('weighted')
ax.set_title('Value weighting fcn')
ax.set_ylim([-20,20])
ax.legend()
plt.show()

# %%
p_resp = []
p_stop = []
prop_choices_predicted = []
for i, fd in enumerate(fitdata):
    pred_pars = {'data': fd['samplesize'],
                 'max_T': fd['max_t'],
                 'options': fd['options']}
    for par_i, par_name in enumerate(pars['fitting']):
        pred_pars[par_name] = f['x'][par_i]
    result = run(pred_pars)
    p_resp.append(result['resp_prob'][1])
    
    exp_tA = np.sum([t * pt for (t, pt) in enumerate(result['p_stop_t'][:,0])]) * result['resp_prob'][0]
    exp_tB = np.sum([t * pt for (t, pt) in enumerate(result['p_stop_t'][:,1])]) * result['resp_prob'][1]
    p_stop.append(exp_tA + exp_tB)
    
    matched = [choice==np.argmax(result['resp_prob_t'][t]) for (choice, t, grp) in pred_pars['data']]
    prop_choices_predicted.append(np.sum(1*matched)/float(len(matched)))

# %%
fig, ax = plt.subplots(figsize=(20,6))
ax.plot(np.array([data_by_gamble[data_by_gamble['gid']==gid]['prop_H_all'].values for gid in gamble_lab_srt]), '-o', label='observed')
ax.plot(p_resp, '-x', label='best fit model')
ax.set_ylim([0, 1])
ax.set_xlim([-1, 85])
add_problem_labels(ax, .2, [0, 10])
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax.plot(data_by_gamble['ss_all'].values, 'r-+')
ax.plot(p_stop, '-x', label='best fit model')
add_problem_labels(ax, 14, [0,50])
ax.legend()
ax.set_xlim(-1, 85)
ax.set_ylim(10, 45)
ax.set_xlabel('Problem')
ax.set_ylabel('Sample size')
ax.set_title('Observed mean sample size')
plt.show()

# %%
pars = {'data': fitdata,
        'fitting': ['delta', 'theta', 'z_temp', 'prelec_elevation', 'prelec_gamma'],
        'bounds': [[-np.inf, np.inf],
                   [1, np.inf],
                   [0, np.inf],
                   [0, np.inf],
                   [0, np.inf]],
        'verbose': True}
loglik_across_gambles([1., 5., 1., 1., 1.], pars)
# Out:
# evaluating:
#   delta=1.0
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   llh: 28905.3150933
# 28905.315093258785

# %%
init = [np.random.random(), 5., 1., 1., 1.]
f = minimize(loglik_across_gambles, init, (pars,), method='Nelder-Mead')
# Out:
# evaluating:
#   delta=0.0797971594862
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   llh: 28565.8104146
# evaluating:
#   delta=0.0837870174605
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   llh: 28564.0160041
# evaluating:
#   delta=0.0797971594862
#   theta=5.25
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   llh: 28565.8104146
# evaluating:
#   delta=0.0797971594862
#   theta=5.0
#   z_temp=1.05
#   prelec_elevation=1.0
#   prelec_gamma=1.0
#   llh: 28569.2784796
# evaluating:
#   delta=0.0797971594862
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.05
#   prelec_gamma=1.0
#   llh: 28560.6120388
# evaluating:
#   delta=0.0797971594862
#   theta=5.0
#   z_temp=1.0
#   prelec_elevation=1.0
#   prelec_gamma=1.05
#   llh: 28559.1874785
# evaluating:
#   delta=0.0813931026759
#   theta=5.1
#   z_temp=0.95
#   prelec_elevation=1.02
#   prelec_gamma=1.02
#   llh: 28559.2550225
# evaluating:
#   delta=0.0820314799518
#   theta=4.79
#   z_temp=0.98
#   prelec_elevation=1.028
#   prelec_gamma=1.028
#   llh: 28557.2147004
# evaluating:
#   delta=0.0831486401846
#   theta=4.56
#   z_temp=0.97
#   prelec_elevation=1.042
#   prelec_gamma=1.042
#   llh: 28553.0206718
# evaluating:
#   delta=0.0833720722312
#   theta=4.864
#   z_temp=0.968
#   prelec_elevation=1.0448
#   prelec_gamma=1.0448
#   llh: 28552.1907984
# evaluating:
#   delta=0.0851595286037
#   theta=4.796
#   z_temp=0.952
#   prelec_elevation=1.0672
#   prelec_gamma=1.0672
#   llh: 28545.6666449
# evaluating:
#   delta=0.0799312187141
#   theta=4.7824
#   z_temp=0.9488
#   prelec_elevation=1.07168
#   prelec_gamma=1.07168
#   llh: 28547.9920792
# evaluating:
#   delta=0.0839747003796
#   theta=4.69536
#   z_temp=0.92832
#   prelec_elevation=1.030352
#   prelec_gamma=1.100352
#   llh: 28546.3089205
# evaluating:
#   delta=0.0834113962714
#   theta=4.433504
#   z_temp=0.969648
#   prelec_elevation=1.0644928
#   prelec_gamma=1.1124928
#   llh: 29231.162761
# evaluating:
#   delta=0.0818976760748
#   theta=4.933376
#   z_temp=0.954912
#   prelec_elevation=1.0311232
#   prelec_gamma=1.0431232
#   llh: 28554.6421132
# evaluating:
#   delta=0.0858475460965
#   theta=4.5068544
#   z_temp=0.9016128
#   prelec_elevation=1.09694208
#   prelec_gamma=1.07974208
#   llh: 28542.5263535
# evaluating:
#   delta=0.0888727394017
#   theta=4.2602816
#   z_temp=0.8524192
#   prelec_elevation=1.14541312
#   prelec_gamma=1.09461312
#   llh: 29168.6894992
# evaluating:
#   delta=0.0853269775166
#   theta=4.40286976
#   z_temp=0.92538112
#   prelec_elevation=1.092146432
#   prelec_gamma=1.101266432
#   llh: 29207.8875618
# evaluating:
#   delta=0.0827550014352
#   theta=4.80074944
#   z_temp=0.94752928
#   prelec_elevation=1.046379008
#   prelec_gamma=1.057659008
#   llh: 28550.6471631
# evaluating:
#   delta=0.0839185579071
#   theta=4.872545536
#   z_temp=0.901304832
#   prelec_elevation=1.0830212352
#   prelec_gamma=1.1086532352
#   llh: 28541.2953951
# evaluating:
#   delta=0.0843035167683
#   theta=5.028818304
#   z_temp=0.866957248
#   prelec_elevation=1.1035318528
#   prelec_gamma=1.1419798528
#   llh: 28538.0870788
# evaluating:
#   delta=0.0849316027896
#   theta=4.7230236416
#   z_temp=0.8915467392
#   prelec_elevation=1.10150336512
#   prelec_gamma=1.12672256512
#   llh: 28537.1081018
# evaluating:
#   delta=0.0860199034668
#   theta=4.6841607424
#   z_temp=0.8635554688
#   prelec_elevation=1.12906554368
#   prelec_gamma=1.16125434368
#   llh: 28532.121928
# evaluating:
#   delta=0.0901908594118
#   theta=4.70207737856
#   z_temp=0.85617820672
#   prelec_elevation=1.09915659059
#   prelec_gamma=1.14853131059
#   llh: 28534.6922691
# evaluating:
#   delta=0.0886338413592
#   theta=4.79180432998
#   z_temp=0.847801489408
#   prelec_elevation=1.16800642683
#   prelec_gamma=1.13913103483
#   llh: 28531.8492443
# evaluating:
#   delta=0.0909634118491
#   theta=4.84002649498
#   z_temp=0.807542234112
#   prelec_elevation=1.23683364024
#   prelec_gamma=1.15852055224
#   llh: 28529.4761293
# evaluating:
#   delta=0.0897705664334
#   theta=4.70877492797
#   z_temp=0.766338383053
#   prelec_elevation=1.19901188293
#   prelec_gamma=1.20881125573
#   llh: 28539.1931297
# evaluating:
#   delta=0.0906517570752
#   theta=5.07868873916
#   z_temp=0.762615816274
#   prelec_elevation=1.2100977241
#   prelec_gamma=1.24789684602
#   llh: 28533.3290925
# evaluating:
#   delta=0.0870812129951
#   theta=5.02473373567
#   z_temp=0.89640120651
#   prelec_elevation=1.11246225764
#   prelec_gamma=1.13446190641
#   llh: 28532.9252032
# evaluating:
#   delta=0.093659341151
#   theta=4.70305653231
#   z_temp=0.807559924966
#   prelec_elevation=1.2115144497
#   prelec_gamma=1.19828613078
#   llh: 28523.6349546
# evaluating:
#   delta=0.0983372533423
#   theta=4.54017564646
#   z_temp=0.777861263449
#   prelec_elevation=1.26550574815
#   prelec_gamma=1.22643926976
#   llh: 28519.1693114
# evaluating:
#   delta=0.0910305560796
#   theta=4.96503676491
#   z_temp=0.787012188938
#   prelec_elevation=1.28242937493
#   prelec_gamma=1.22289785665
#   llh: 28522.2266184
# evaluating:
#   delta=0.0907211780179
#   theta=4.5429646146
#   z_temp=0.89033312845
#   prelec_elevation=1.20042090176
#   prelec_gamma=1.11353272548
#   llh: 28525.3666576
# evaluating:
#   delta=0.0957477081072
#   theta=4.40421196967
#   z_temp=0.75412050699
#   prelec_elevation=1.33323982587
#   prelec_gamma=1.21859599272
#   llh: 29098.0717836
# evaluating:
#   delta=0.0892478367731
#   theta=4.86960329417
#   z_temp=0.86083103163
#   prelec_elevation=1.1676566497
#   prelec_gamma=1.15549542799
#   llh: 28527.0394504
# evaluating:
#   delta=0.098100190958
#   theta=4.81896198364
#   z_temp=0.785876469831
#   prelec_elevation=1.33207298223
#   prelec_gamma=1.18949998917
#   llh: 28516.8582498
# evaluating:
#   delta=0.104140334704
#   theta=4.88636260426
#   z_temp=0.747036970347
#   prelec_elevation=1.43357670151
#   prelec_gamma=1.20362281191
#   llh: 28515.7332419
# evaluating:
#   delta=0.0984274517176
#   theta=4.68163067478
#   z_temp=0.817687599013
#   prelec_elevation=1.30300211018
#   prelec_gamma=1.21027468448
#   llh: 28507.3655634
# evaluating:
#   delta=0.102159471652
#   theta=4.60243276469
#   z_temp=0.822760281464
#   prelec_elevation=1.33608634514
#   prelec_gamma=1.23615175059
#   llh: 28496.4573658
# evaluating:
#   delta=0.105307680745
#   theta=4.5451856638
#   z_temp=0.74917050143
#   prelec_elevation=1.4395509789
#   prelec_gamma=1.24556233778
#   llh: 28507.3788706
# evaluating:
#   delta=0.109668940591
#   theta=4.87271276305
#   z_temp=0.663203353802
#   prelec_elevation=1.50243875769
#   prelec_gamma=1.3403368852
#   llh: 28534.1998226
# evaluating:
#   delta=0.0954581186612
#   theta=4.62540165171
#   z_temp=0.833550684788
#   prelec_elevation=1.27592536574
#   prelec_gamma=1.17023376541
#   llh: 28514.7275907
# evaluating:
#   delta=0.111130587562
#   theta=4.31478656746
#   z_temp=0.785139691653
#   prelec_elevation=1.41782868085
#   prelec_gamma=1.20990611753
#   llh: 29097.0116376
# evaluating:
#   delta=0.0960555639502
#   theta=4.80247421554
#   z_temp=0.786544064617
#   prelec_elevation=1.31627920141
#   prelec_gamma=1.21964992187
#   llh: 28515.4033363
# evaluating:
#   delta=0.102911214542
#   theta=4.84456711354
#   z_temp=0.797763737609
#   prelec_elevation=1.45506168893
#   prelec_gamma=1.20364896526
#   llh: 28498.3198499
# evaluating:
#   delta=0.0966164851166
#   theta=4.48166195945
#   z_temp=0.848878737616
#   prelec_elevation=1.29558473054
#   prelec_gamma=1.22647588445
#   llh: 29138.1559181
# evaluating:
#   delta=0.102259372307
#   theta=4.78518744306
#   z_temp=0.772497412164
#   prelec_elevation=1.39907870877
#   prelec_gamma=1.20933608005
#   llh: 28509.4929623
# evaluating:
#   delta=0.107182779213
#   theta=4.55863563917
#   z_temp=0.803752982365
#   prelec_elevation=1.44600203358
#   prelec_gamma=1.20632323776
#   llh: 28493.0052672
# evaluating:
#   delta=0.112746386844
#   theta=4.43671635099
#   z_temp=0.812357441239
#   prelec_elevation=1.51086344967
#   prelec_gamma=1.19965989571
#   llh: 29104.6255852
# evaluating:
#   delta=0.112470088722
#   theta=4.70900179799
#   z_temp=0.744827281225
#   prelec_elevation=1.55438653639
#   prelec_gamma=1.27017518317
#   llh: 28493.1249468
# evaluating:
#   delta=0.109753121643
#   theta=4.51874174862
#   z_temp=0.794812501473
#   prelec_elevation=1.49335632441
#   prelec_gamma=1.25540850978
#   llh: 28483.3240321
# evaluating:
#   delta=0.113499996311
#   theta=4.3855189014
#   z_temp=0.805970046127
#   prelec_elevation=1.54049513223
#   prelec_gamma=1.27844472464
#   llh: 29094.2229369
# evaluating:
#   delta=0.108482989564
#   theta=4.74816596181
#   z_temp=0.836396212225
#   prelec_elevation=1.47440619248
#   prelec_gamma=1.22312072085
#   llh: 28480.3570333
# evaluating:
#   delta=0.110070643973
#   theta=4.84965611081
#   z_temp=0.880009067622
#   prelec_elevation=1.49183379927
#   prelec_gamma=1.21189991238
#   llh: 28473.0975226
# evaluating:
#   delta=0.113743227539
#   theta=4.45082011097
#   z_temp=0.820701108051
#   prelec_elevation=1.47360432659
#   prelec_gamma=1.26833447221
#   llh: 29103.0427639
# evaluating:
#   delta=0.105619217791
#   theta=4.7461303629
#   z_temp=0.803498080219
#   prelec_elevation=1.45969734835
#   prelec_gamma=1.219820342
#   llh: 28491.6708755
# evaluating:
#   delta=0.115878868885
#   theta=4.75043349911
#   z_temp=0.787999683698
#   prelec_elevation=1.64202407166
#   prelec_gamma=1.22929912344
#   llh: 28476.6298853
# evaluating:
#   delta=0.10693176388
#   theta=4.66043714625
#   z_temp=0.883201644926
#   prelec_elevation=1.45877889452
#   prelec_gamma=1.17892526698
#   llh: 28482.3927546
# evaluating:
#   delta=0.112118667256
#   theta=4.8515239079
#   z_temp=0.85605540881
#   prelec_elevation=1.5722741417
#   prelec_gamma=1.23181802407
#   llh: 28467.4109514
# evaluating:
#   delta=0.114586611278
#   theta=4.99796804227
#   z_temp=0.882206622033
#   prelec_elevation=1.63541019576
#   prelec_gamma=1.24456541722
#   llh: 28457.715861
# evaluating:
#   delta=0.117269186072
#   theta=4.76476425592
#   z_temp=0.887793727681
#   prelec_elevation=1.6288639659
#   prelec_gamma=1.22821894992
#   llh: 28457.3201568
# evaluating:
#   delta=0.123094170213
#   theta=4.77408120244
#   z_temp=0.929941551412
#   prelec_elevation=1.71344727468
#   prelec_gamma=1.23241825388
#   llh: 28447.0309725
# evaluating:
#   delta=0.118471701649
#   theta=5.09428865173
#   z_temp=0.950530926403
#   prelec_elevation=1.68324136994
#   prelec_gamma=1.18343467979
#   llh: 28457.1878774
# evaluating:
#   delta=0.125909034519
#   theta=5.12613385629
#   z_temp=0.889073495541
#   prelec_elevation=1.80760379
#   prelec_gamma=1.26172168771
#   llh: 28443.1059191
# evaluating:
#   delta=0.135397669839
#   theta=5.35898221131
#   z_temp=0.892009420849
#   prelec_elevation=1.98201623774
#   prelec_gamma=1.30311989807
#   llh: 28438.0849036
# evaluating:
#   delta=0.124769449896
#   theta=5.27955698831
#   z_temp=1.02587935163
#   prelec_elevation=1.7603554793
#   prelec_gamma=1.2408761411
#   llh: 28446.3413048
# evaluating:
#   delta=0.136457197177
#   theta=5.35229472761
#   z_temp=0.992218081309
#   prelec_elevation=2.0179544237
#   prelec_gamma=1.26986584364
#   llh: 28437.3700392
# evaluating:
#   delta=0.149650473778
#   theta=5.60361403601
#   z_temp=1.04832258815
#   prelec_elevation=2.28101473591
#   prelec_gamma=1.29884880927
#   llh: 29081.7723747
# evaluating:
#   delta=0.140689464231
#   theta=5.34571347029
#   z_temp=1.03402511061
#   prelec_elevation=2.02739571839
#   prelec_gamma=1.24732050938
#   llh: 28439.6490345
# evaluating:
#   delta=0.145691478893
#   theta=5.34996278825
#   z_temp=0.99909847992
#   prelec_elevation=2.11722628358
#   prelec_gamma=1.33400557864
#   llh: 28442.6170846
# evaluating:
#   delta=0.150107933801
#   theta=5.90052287188
#   z_temp=1.04735062631
#   prelec_elevation=2.2485319824
#   prelec_gamma=1.32565693445
#   llh: 29081.5811306
# evaluating:
#   delta=0.12984761111
#   theta=5.0556916198
#   z_temp=0.959293820138
#   prelec_elevation=1.84721845161
#   prelec_gamma=1.25572792403
#   llh: 28438.2751952
# evaluating:
#   delta=0.150463918604
#   theta=5.3055009386
#   z_temp=0.9247786135
#   prelec_elevation=2.23636896671
#   prelec_gamma=1.32313976041
#   llh: 28449.7161669
# evaluating:
#   delta=0.131193067073
#   theta=5.28604297588
#   z_temp=1.0006041671
#   prelec_elevation=1.87935885115
#   prelec_gamma=1.26144204593
#   llh: 28438.3780663
# evaluating:
#   delta=0.123742524879
#   theta=5.20952721371
#   z_temp=0.952161760081
#   prelec_elevation=1.78435118946
#   prelec_gamma=1.20098490978
#   llh: 28448.1222754
# evaluating:
#   delta=0.140204240389
#   theta=5.31485389462
#   z_temp=0.98736429996
#   prelec_elevation=2.03400751005
#   prelec_gamma=1.30075041142
#   llh: 28436.7704286
# evaluating:
#   delta=0.128550450004
#   theta=5.20143270139
#   z_temp=0.898570805133
#   prelec_elevation=1.87682647131
#   prelec_gamma=1.30904193986
#   llh: 28437.7091036
# evaluating:
#   delta=0.136989800335
#   theta=5.22725908601
#   z_temp=0.891178403858
#   prelec_elevation=2.02385038661
#   prelec_gamma=1.31396036089
#   llh: 28439.0605587
# evaluating:
#   delta=0.132642250388
#   theta=5.27134700341
#   z_temp=0.973247726288
#   prelec_elevation=1.91548173502
#   prelec_gamma=1.27457162467
#   llh: 28436.2156178
# evaluating:
#   delta=0.139453112009
#   theta=5.54387259554
#   z_temp=0.938070313278
#   prelec_elevation=2.08329609952
#   prelec_gamma=1.32721196304
#   llh: 29148.6128316
# evaluating:
#   delta=0.132248986335
#   theta=5.17773686373
#   z_temp=0.953987943423
#   prelec_elevation=1.90623786359
#   prelec_gamma=1.27359893378
#   llh: 28436.1425081
# evaluating:
#   delta=0.132643579878
#   theta=5.16808386499
#   z_temp=1.0301461216
#   prelec_elevation=1.91818696372
#   prelec_gamma=1.26801160328
#   llh: 28439.484745
# evaluating:
#   delta=0.134709147349
#   theta=5.31125762473
#   z_temp=0.926543596036
#   prelec_elevation=1.96605891924
#   prelec_gamma=1.29434282438
#   llh: 28435.894167
# evaluating:
#   delta=0.141954278651
#   theta=5.36956334425
#   z_temp=1.03477385367
#   prelec_elevation=2.05906970932
#   prelec_gamma=1.25620991529
#   llh: 28440.0777928
# evaluating:
#   delta=0.131901407166
#   theta=5.24346536211
#   z_temp=0.932621567268
#   prelec_elevation=1.92238728081
#   prelec_gamma=1.29583393372
#   llh: 28435.748372
# evaluating:
#   delta=0.132225215474
#   theta=5.17516957183
#   z_temp=0.917287971881
#   prelec_elevation=1.87971489979
#   prelec_gamma=1.30577324754
#   llh: 28435.2956564
# evaluating:
#   delta=0.130109224623
#   theta=5.08660699394
#   z_temp=0.879822917167
#   prelec_elevation=1.81059513783
#   prelec_gamma=1.32372694949
#   llh: 28437.6179114
# evaluating:
#   delta=0.125286562295
#   theta=5.15673667571
#   z_temp=0.894111221998
#   prelec_elevation=1.80194476933
#   prelec_gamma=1.27689781421
#   llh: 28441.7840184
# evaluating:
#   delta=0.136474820866
#   theta=5.27532458989
#   z_temp=0.96405103047
#   prelec_elevation=1.97599182487
#   prelec_gamma=1.29478726212
#   llh: 28435.1906455
# evaluating:
#   delta=0.134381580488
#   theta=5.2018346015
#   z_temp=0.904549117343
#   prelec_elevation=1.9446745803
#   prelec_gamma=1.31116285595
#   llh: 28436.3345359
# evaluating:
#   delta=0.133077082913
#   theta=5.25396890294
#   z_temp=0.956073074052
#   prelec_elevation=1.92277994634
#   prelec_gamma=1.28371943249
#   llh: 28435.5162463
# evaluating:
#   delta=0.135106083173
#   theta=5.32593755686
#   z_temp=0.92464295246
#   prelec_elevation=1.96053528483
#   prelec_gamma=1.31618374632
#   llh: 28435.3742065
# evaluating:
#   delta=0.132804696488
#   theta=5.19828876872
#   z_temp=0.951327042416
#   prelec_elevation=1.89850477542
#   prelec_gamma=1.3041762245
#   llh: 28434.4844106
# evaluating:
#   delta=0.131852471057
#   theta=5.14180434071
#   z_temp=0.963718765606
#   prelec_elevation=1.86472770351
#   prelec_gamma=1.30909292456
#   llh: 28434.24523
# evaluating:
#   delta=0.135592862227
#   theta=5.22541662278
#   z_temp=0.957687950519
#   prelec_elevation=1.91911258292
#   prelec_gamma=1.30798871149
#   llh: 28433.8801852
# evaluating:
#   delta=0.137438589758
#   theta=5.21639225312
#   z_temp=0.970221142145
#   prelec_elevation=1.91747523397
#   prelec_gamma=1.31406610038
#   llh: 28433.4154719
# evaluating:
#   delta=0.136161789218
#   theta=5.19988242203
#   z_temp=0.939895670973
#   prelec_elevation=1.91659803245
#   prelec_gamma=1.33224187988
#   llh: 28433.4642966
# evaluating:
#   delta=0.134555071377
#   theta=5.07749171417
#   z_temp=0.97742687997
#   prelec_elevation=1.861267793
#   prelec_gamma=1.30620081948
#   llh: 28433.6166961
# evaluating:
#   delta=0.138367881436
#   theta=5.18918855614
#   z_temp=1.00883742378
#   prelec_elevation=1.93470933533
#   prelec_gamma=1.31678234702
#   llh: 28435.1054942
# evaluating:
#   delta=0.134875500273
#   theta=5.05457912458
#   z_temp=0.979988922522
#   prelec_elevation=1.82191941443
#   prelec_gamma=1.33656636641
#   llh: 28432.0053868
# evaluating:
#   delta=0.134075839977
#   theta=4.94420639192
#   z_temp=0.987957868549
#   prelec_elevation=1.74488320921
#   prelec_gamma=1.35745591855
#   llh: 28430.9308371
# evaluating:
#   delta=0.131265623119
#   theta=5.04272229264
#   z_temp=0.926850707113
#   prelec_elevation=1.78727145352
#   prelec_gamma=1.33084071011
#   llh: 28433.3142021
# evaluating:
#   delta=0.137546294322
#   theta=5.05047368884
#   z_temp=0.957222141894
#   prelec_elevation=1.82627058535
#   prelec_gamma=1.3472292468
#   llh: 28430.7710862
# evaluating:
#   delta=0.140393205955
#   theta=5.00480836291
#   z_temp=0.953973830038
#   prelec_elevation=1.80704202627
#   prelec_gamma=1.36629740792
#   llh: 28429.6270613
# evaluating:
#   delta=0.137178947833
#   theta=5.08571297488
#   z_temp=0.934132807556
#   prelec_elevation=1.80804018917
#   prelec_gamma=1.37415998726
#   llh: 28430.4369201
# evaluating:
#   delta=0.135979093438
#   theta=4.91765448816
#   z_temp=0.969358871187
#   prelec_elevation=1.70928681241
#   prelec_gamma=1.36488616981
#   llh: 28429.2182711
# evaluating:
#   delta=0.135887745548
#   theta=4.77654052123
#   z_temp=0.984090471294
#   prelec_elevation=1.6056312024
#   prelec_gamma=1.38120831477
#   llh: 28428.824524
# evaluating:
#   delta=0.134081955214
#   theta=4.72520396431
#   z_temp=0.944581131674
#   prelec_elevation=1.58367199826
#   prelec_gamma=1.40991883507
#   llh: 28427.8021177
# evaluating:
#   delta=0.132403637942
#   theta=4.47960981991
#   z_temp=0.931761126439
#   prelec_elevation=1.41677038041
#   prelec_gamma=1.45784520241
#   llh: 29139.9788397
# evaluating:
#   delta=0.141381454692
#   theta=4.77186659346
#   z_temp=0.995043736532
#   prelec_elevation=1.6324359966
#   prelec_gamma=1.42477547531
#   llh: 28426.2109918
# evaluating:
#   delta=0.146439370479
#   theta=4.63643874388
#   z_temp=1.02914025124
#   prelec_elevation=1.55501826814
#   prelec_gamma=1.47174285791
#   llh: 28426.0106844
# evaluating:
#   delta=0.143516650035
#   theta=4.74727543496
#   z_temp=0.950409528173
#   prelec_elevation=1.59887826449
#   prelec_gamma=1.44387504262
#   llh: 28424.2438967
# evaluating:
#   delta=0.148237055065
#   theta=4.64880995648
#   z_temp=0.931635357985
#   prelec_elevation=1.52587579212
#   prelec_gamma=1.48708460465
#   llh: 28422.8106493
# evaluating:
#   delta=0.144836785071
#   theta=4.43100764464
#   z_temp=1.00323560934
#   prelec_elevation=1.42285552571
#   prelec_gamma=1.47234082086
#   llh: 29174.5545726
# evaluating:
#   delta=0.139093407143
#   theta=4.92203664232
#   z_temp=0.951408508001
#   prelec_elevation=1.71174402331
#   prelec_gamma=1.39870519566
#   llh: 28427.4776184
# evaluating:
#   delta=0.141102607425
#   theta=4.47880356838
#   z_temp=0.982368458041
#   prelec_elevation=1.38573448742
#   prelec_gamma=1.49316651531
#   llh: 29164.1568676
# evaluating:
#   delta=0.140570556322
#   theta=4.87330716428
#   z_temp=0.961072487038
#   prelec_elevation=1.70171514156
#   prelec_gamma=1.39801468476
#   llh: 28427.0050538
# evaluating:
#   delta=0.147481192141
#   theta=4.74577806728
#   z_temp=0.943044623082
#   prelec_elevation=1.62557888696
#   prelec_gamma=1.48497815645
#   llh: 28425.9234698
# evaluating:
#   delta=0.154646677246
#   theta=4.80534426538
#   z_temp=0.981939359265
#   prelec_elevation=1.66430084658
#   prelec_gamma=1.48629136471
#   llh: 28429.8627487
# evaluating:
#   delta=0.139223135722
#   theta=4.74523903958
#   z_temp=0.953920688572
#   prelec_elevation=1.60382921034
#   prelec_gamma=1.42901196748
#   llh: 28425.3702217
# evaluating:
#   delta=0.149687116749
#   theta=4.53779254628
#   z_temp=0.976116855166
#   prelec_elevation=1.49306289635
#   prelec_gamma=1.50962771284
#   llh: 28422.2202299
# evaluating:
#   delta=0.154983971552
#   theta=4.34567049825
#   z_temp=0.988471028749
#   prelec_elevation=1.38372233287
#   prelec_gamma=1.56508897143
#   llh: 29175.4319754
# evaluating:
#   delta=0.15185659174
#   theta=4.45231617712
#   z_temp=0.97247062338
#   prelec_elevation=1.41963088001
#   prelec_gamma=1.55496343497
#   llh: 29167.5527508
# evaluating:
#   delta=0.143392065177
#   theta=4.76805941749
#   z_temp=0.963922021124
#   prelec_elevation=1.63119407617
#   prelec_gamma=1.43725187231
#   llh: 28424.9543435
# evaluating:
#   delta=0.144768855462
#   theta=4.74183286697
#   z_temp=0.87831556713
#   prelec_elevation=1.59679807664
#   prelec_gamma=1.46743886758
#   llh: 28428.3001927
# evaluating:
#   delta=0.146021741725
#   theta=4.66278727465
#   z_temp=0.991434080214
#   prelec_elevation=1.56546322027
#   prelec_gamma=1.47066686033
#   llh: 28424.0606888
# evaluating:
#   delta=0.143143253634
#   theta=4.59929722651
#   z_temp=0.983766978142
#   prelec_elevation=1.50219119114
#   prelec_gamma=1.44847905059
#   llh: 28423.8804338
# evaluating:
#   delta=0.152969357218
#   theta=4.54145952898
#   z_temp=0.98482942848
#   prelec_elevation=1.48328566008
#   prelec_gamma=1.51223207281
#   llh: 28422.249557
# evaluating:
#   delta=0.152631344579
#   theta=4.42799919567
#   z_temp=0.983191058871
#   prelec_elevation=1.39675742781
#   prelec_gamma=1.53398424817
#   llh: 29169.5312869
# evaluating:
#   delta=0.145701885027
#   theta=4.68304436204
#   z_temp=0.968739280561
#   prelec_elevation=1.57258491408
#   prelec_gamma=1.46143496628
#   llh: 28423.5406941
# evaluating:
#   delta=0.149873725352
#   theta=4.54137417347
#   z_temp=0.94660107992
#   prelec_elevation=1.46533696124
#   prelec_gamma=1.49687650254
#   llh: 28421.3095009
# evaluating:
#   delta=0.151799717166
#   theta=4.48066762288
#   z_temp=0.924184579773
#   prelec_elevation=1.41527383173
#   prelec_gamma=1.50998132365
#   llh: 29139.9617215
# evaluating:
#   delta=0.15544440213
#   theta=4.58169500039
#   z_temp=0.939401822703
#   prelec_elevation=1.51386729841
#   prelec_gamma=1.53842329306
#   llh: 28424.8993745
# evaluating:
#   delta=0.146218540758
#   theta=4.59489666998
#   z_temp=0.972675689282
#   prelec_elevation=1.50511021796
#   prelec_gamma=1.47096511121
#   llh: 28422.4518708
# evaluating:
#   delta=0.153092433029
#   theta=4.46268878804
#   z_temp=0.956004083773
#   prelec_elevation=1.41648369702
#   prelec_gamma=1.52927943534
#   llh: 29157.3201555
# evaluating:
#   delta=0.147549522028
#   theta=4.62795546854
#   z_temp=0.965555481364
#   prelec_elevation=1.53355960982
#   prelec_gamma=1.47839608354
#   llh: 28422.6081262
# evaluating:
#   delta=0.150282249777
#   theta=4.48858139841
#   z_temp=1.0066760557
#   prelec_elevation=1.46626634605
#   prelec_gamma=1.50015438853
#   llh: 29180.7647999
# evaluating:
#   delta=0.148748353743
#   theta=4.60875281697
#   z_temp=0.950395532414
#   prelec_elevation=1.51097343061
#   prelec_gamma=1.49035205062
#   llh: 28422.1276527
# evaluating:
#   delta=0.1514493155
#   theta=4.50175482573
#   z_temp=0.966691952741
#   prelec_elevation=1.44954805668
#   prelec_gamma=1.51362529646
#   llh: 28421.1054336
# evaluating:
#   delta=0.153399212236
#   theta=4.43865450433
#   z_temp=0.96726018843
#   prelec_elevation=1.40754228011
#   prelec_gamma=1.53123990292
#   llh: 29162.5033426
# evaluating:
#   delta=0.154872606666
#   theta=4.49755688659
#   z_temp=0.957178250206
#   prelec_elevation=1.45577258402
#   prelec_gamma=1.5381203429
#   llh: 29162.3614693
# evaluating:
#   delta=0.148382057235
#   theta=4.57056172413
#   z_temp=0.968801329513
#   prelec_elevation=1.49277580947
#   prelec_gamma=1.48775391913
#   llh: 28421.8780898
# evaluating:
#   delta=0.146286870214
#   theta=4.56263490565
#   z_temp=0.938613271422
#   prelec_elevation=1.48139320166
#   prelec_gamma=1.48706211982
#   llh: 28422.12069
# evaluating:
#   delta=0.148209012069
#   theta=4.5762388321
#   z_temp=0.932324411238
#   prelec_elevation=1.46694808752
#   prelec_gamma=1.48064024259
#   llh: 28421.8918308
# evaluating:
#   delta=0.148932038405
#   theta=4.49227296747
#   z_temp=0.95081728552
#   prelec_elevation=1.43142741602
#   prelec_gamma=1.4960311816
#   llh: 29151.5406745
# evaluating:
#   delta=0.148794274908
#   theta=4.57963285459
#   z_temp=0.95050097069
#   prelec_elevation=1.49108692696
#   prelec_gamma=1.49177183336
#   llh: 28421.7496466
# evaluating:
#   delta=0.152396483812
#   theta=4.54519005836
#   z_temp=0.967354626219
#   prelec_elevation=1.46488513509
#   prelec_gamma=1.50120499781
#   llh: 28421.1549238
# evaluating:
#   delta=0.152149330654
#   theta=4.51916662241
#   z_temp=0.987655572396
#   prelec_elevation=1.47850506826
#   prelec_gamma=1.51585277713
#   llh: 28422.3061462
# evaluating:
#   delta=0.149194091715
#   theta=4.56197077968
#   z_temp=0.946157201527
#   prelec_elevation=1.4698373327
#   prelec_gamma=1.48944337623
#   llh: 28421.4338633
# evaluating:
#   delta=0.15230109928
#   theta=4.5214073526
#   z_temp=0.942121002926
#   prelec_elevation=1.44350195559
#   prelec_gamma=1.50941488343
#   llh: 28420.947762
# evaluating:
#   delta=0.154260620302
#   theta=4.49683016683
#   z_temp=0.928780839632
#   prelec_elevation=1.41886502865
#   prelec_gamma=1.52024536558
#   llh: 29144.072494
# evaluating:
#   delta=0.153291611355
#   theta=4.48904602135
#   z_temp=0.957069374643
#   prelec_elevation=1.42615684956
#   prelec_gamma=1.51245418922
#   llh: 29156.8650866
# evaluating:
#   delta=0.14991860902
#   theta=4.55698614628
#   z_temp=0.952143071678
#   prelec_elevation=1.47485440761
#   prelec_gamma=1.49694242233
#   llh: 28421.4023882
# evaluating:
#   delta=0.15318160147
#   theta=4.5047142429
#   z_temp=0.963807491867
#   prelec_elevation=1.44941327378
#   prelec_gamma=1.5177822648
#   llh: 28421.0774112
# evaluating:
#   delta=0.153762281145
#   theta=4.48879011494
#   z_temp=0.962487389791
#   prelec_elevation=1.43421974534
#   prelec_gamma=1.51861915569
#   llh: 29160.6844902
# evaluating:
#   delta=0.150879527051
#   theta=4.53993713845
#   z_temp=0.954729151207
#   prelec_elevation=1.46469574204
#   prelec_gamma=1.50236160567
#   llh: 28421.1962906
# evaluating:
#   delta=0.154209485493
#   theta=4.50382727375
#   z_temp=0.971280610064
#   prelec_elevation=1.44348070403
#   prelec_gamma=1.52087911673
#   llh: 28421.103261
# evaluating:
#   delta=0.15453566717
#   theta=4.49082036289
#   z_temp=0.96977312232
#   prelec_elevation=1.43563590803
#   prelec_gamma=1.52280101803
#   llh: 29165.0134248
# evaluating:
#   delta=0.151793562081
#   theta=4.52765794456
#   z_temp=0.958490143985
#   prelec_elevation=1.45743078354
#   prelec_gamma=1.50747145876
#   llh: 28421.0729191
# evaluating:
#   delta=0.152777541718
#   theta=4.47855459745
#   z_temp=0.953601854414
#   prelec_elevation=1.43246477436
#   prelec_gamma=1.52646421026
#   llh: 29156.7205396
# evaluating:
#   delta=0.152491748288
#   theta=4.52853119314
#   z_temp=0.963916433268
#   prelec_elevation=1.45678004491
#   prelec_gamma=1.50751980092
#   llh: 28421.0552159
# evaluating:
#   delta=0.154141683145
#   theta=4.53270037704
#   z_temp=0.953154320103
#   prelec_elevation=1.45069464806
#   prelec_gamma=1.5116017134
#   llh: 28420.9177435
# evaluating:
#   delta=0.155487866968
#   theta=4.5481731527
#   z_temp=0.946385503783
#   prelec_elevation=1.45126794376
#   prelec_gamma=1.51058992186
#   llh: 28420.9427701
# evaluating:
#   delta=0.151354392213
#   theta=4.54217717034
#   z_temp=0.941315146795
#   prelec_elevation=1.45964757832
#   prelec_gamma=1.50063693179
#   llh: 28421.1910162
# evaluating:
#   delta=0.153495712173
#   theta=4.5134147479
#   z_temp=0.963789244247
#   prelec_elevation=1.44752242261
#   prelec_gamma=1.5158185705
#   llh: 28420.9854874
# evaluating:
#   delta=0.152507920517
#   theta=4.5447704032
#   z_temp=0.948780965945
#   prelec_elevation=1.4529586681
#   prelec_gamma=1.502948306
#   llh: 28420.9166651
# evaluating:
#   delta=0.15217108004
#   theta=4.56479848335
#   z_temp=0.941267702984
#   prelec_elevation=1.45473136526
#   prelec_gamma=1.4955313266
#   llh: 28421.0016174
# evaluating:
#   delta=0.15418170328
#   theta=4.52867168499
#   z_temp=0.95021464261
#   prelec_elevation=1.44315231217
#   prelec_gamma=1.51144985094
#   llh: 28420.7734746
# evaluating:
#   delta=0.155375773879
#   theta=4.52917855521
#   z_temp=0.946076891923
#   prelec_elevation=1.43601307648
#   prelec_gamma=1.51343904703
#   llh: 28420.6784394
# evaluating:
#   delta=0.154637127309
#   theta=4.52805738124
#   z_temp=0.937652536789
#   prelec_elevation=1.43549626343
#   prelec_gamma=1.51376920722
#   llh: 28420.8489073
# evaluating:
#   delta=0.154089729479
#   theta=4.54903087982
#   z_temp=0.927325042827
#   prelec_elevation=1.43994342207
#   prelec_gamma=1.50465069233
#   llh: 28421.114763
# evaluating:
#   delta=0.153644216499
#   theta=4.52231878088
#   z_temp=0.954673193892
#   prelec_elevation=1.44562767247
#   prelec_gamma=1.51302660096
#   llh: 28420.8515645
# evaluating:
#   delta=0.15582158926
#   theta=4.54140284643
#   z_temp=0.954014160535
#   prelec_elevation=1.44481417583
#   prelec_gamma=1.51249906641
#   llh: 28420.7801633
# evaluating:
#   delta=0.154652967841
#   theta=4.53359080974
#   z_temp=0.943324779531
#   prelec_elevation=1.43526929446
#   prelec_gamma=1.51067117765
#   llh: 28420.6743844
# evaluating:
#   delta=0.154908610189
#   theta=4.53403602609
#   z_temp=0.938410009245
#   prelec_elevation=1.42755661766
#   prelec_gamma=1.51020590978
#   llh: 28420.6211912
# evaluating:
#   delta=0.157247006338
#   theta=4.51722703274
#   z_temp=0.943549751009
#   prelec_elevation=1.42284445425
#   prelec_gamma=1.52222762656
#   llh: 28420.6400884
# evaluating:
#   delta=0.157551826291
#   theta=4.53764195581
#   z_temp=0.933208145908
#   prelec_elevation=1.42106216259
#   prelec_gamma=1.51582974184
#   llh: 28420.6675423
# evaluating:
#   delta=0.157724795074
#   theta=4.53573718526
#   z_temp=0.948451046658
#   prelec_elevation=1.42541993129
#   prelec_gamma=1.51591134943
#   llh: 28420.4620316
# evaluating:
#   delta=0.159268628956
#   theta=4.53957708728
#   z_temp=0.953850301593
#   prelec_elevation=1.42038176522
#   prelec_gamma=1.51698242053
#   llh: 28420.3581776
# evaluating:
#   delta=0.157919149001
#   theta=4.52166141642
#   z_temp=0.932023879336
#   prelec_elevation=1.40632905465
#   prelec_gamma=1.51897483189
#   llh: 28420.4967468
# evaluating:
#   delta=0.15938231443
#   theta=4.53087885212
#   z_temp=0.934339942913
#   prelec_elevation=1.40325654527
#   prelec_gamma=1.52024916521
#   llh: 28420.389448
# evaluating:
#   delta=0.157938457275
#   theta=4.51971021005
#   z_temp=0.94766140773
#   prelec_elevation=1.41108521223
#   prelec_gamma=1.51962623974
#   llh: 28420.2709356
# evaluating:
#   delta=0.158131772767
#   theta=4.51074433718
#   z_temp=0.954888038641
#   prelec_elevation=1.40609673705
#   prelec_gamma=1.52152448869
#   llh: 28420.1763571
# evaluating:
#   delta=0.158597183799
#   theta=4.53753205489
#   z_temp=0.941855117682
#   prelec_elevation=1.40260383369
#   prelec_gamma=1.51294709988
#   llh: 28420.0548342
# evaluating:
#   delta=0.159272272529
#   theta=4.54768456596
#   z_temp=0.941007801019
#   prelec_elevation=1.39248352341
#   prelec_gamma=1.50830683654
#   llh: 28419.8379319
# evaluating:
#   delta=0.162681044884
#   theta=4.5261824775
#   z_temp=0.948033976156
#   prelec_elevation=1.38386243258
#   prelec_gamma=1.52420918737
#   llh: 28419.9070444
# evaluating:
#   delta=0.161575264426
#   theta=4.54036551159
#   z_temp=0.960824144793
#   prelec_elevation=1.39610334676
#   prelec_gamma=1.51753400745
#   llh: 28419.8940039
# evaluating:
#   delta=0.160989278994
#   theta=4.53494273968
#   z_temp=0.969101761968
#   prelec_elevation=1.39631457674
#   prelec_gamma=1.51517361103
#   llh: 28419.9184322
# evaluating:
#   delta=0.161791224485
#   theta=4.52439076549
#   z_temp=0.955691987438
#   prelec_elevation=1.36956248139
#   prelec_gamma=1.5177168319
#   llh: 28419.4933218
# evaluating:
#   delta=0.163052522249
#   theta=4.5167976046
#   z_temp=0.956612830361
#   prelec_elevation=1.34415283948
#   prelec_gamma=1.51808403759
#   llh: 28419.2768052
# evaluating:
#   delta=0.164896380466
#   theta=4.55564482256
#   z_temp=0.955344167078
#   prelec_elevation=1.35906995054
#   prelec_gamma=1.5117985833
#   llh: 28419.1893909
# evaluating:
#   delta=0.168278684316
#   theta=4.57809506525
#   z_temp=0.955572231296
#   prelec_elevation=1.33555655729
#   prelec_gamma=1.5069356306
#   llh: 28418.8469887
# evaluating:
#   delta=0.164954636367
#   theta=4.54870735028
#   z_temp=0.935718631483
#   prelec_elevation=1.34454890307
#   prelec_gamma=1.51485426879
#   llh: 28419.4085774
# evaluating:
#   delta=0.16417230707
#   theta=4.56647756157
#   z_temp=0.951860279425
#   prelec_elevation=1.34127563542
#   prelec_gamma=1.50207672502
#   llh: 28419.0739133
# evaluating:
#   delta=0.166316904587
#   theta=4.56273934747
#   z_temp=0.935484564641
#   prelec_elevation=1.30710363671
#   prelec_gamma=1.50256899197
#   llh: 28419.3668013
# evaluating:
#   delta=0.171437749307
#   theta=4.5614422057
#   z_temp=0.953091613863
#   prelec_elevation=1.27657150537
#   prelec_gamma=1.50950102504
#   llh: 28419.0211513
# evaluating:
#   delta=0.168348630644
#   theta=4.56551336356
#   z_temp=0.965329976352
#   prelec_elevation=1.29731516664
#   prelec_gamma=1.5008122953
#   llh: 28419.0486945
# evaluating:
#   delta=0.167799052848
#   theta=4.5525909728
#   z_temp=0.977502207878
#   prelec_elevation=1.33084504497
#   prelec_gamma=1.51239489345
#   llh: 28419.20078
# evaluating:
#   delta=0.172962047425
#   theta=4.61285006296
#   z_temp=0.964729693164
#   prelec_elevation=1.2884727244
#   prelec_gamma=1.49460419018
#   llh: 28418.7038288
# evaluating:
#   delta=0.177916810013
#   theta=4.66087629214
#   z_temp=0.968788124566
#   prelec_elevation=1.26063266685
#   prelec_gamma=1.48286426648
#   llh: 28418.7866828
# evaluating:
#   delta=0.170280714658
#   theta=4.60116033081
#   z_temp=0.938731309762
#   prelec_elevation=1.28483159068
#   prelec_gamma=1.493177053
#   llh: 28419.2025695
# evaluating:
#   delta=0.1684194683
#   theta=4.5647333123
#   z_temp=0.967809483349
#   prelec_elevation=1.3193416814
#   prelec_gamma=1.50759043334
#   llh: 28418.9179447
# evaluating:
#   delta=0.175606324927
#   theta=4.58657604233
#   z_temp=0.970752919785
#   prelec_elevation=1.26562741862
#   prelec_gamma=1.50570070476
#   llh: 28418.9825287
# evaluating:
#   delta=0.174333079066
#   theta=4.59596531186
#   z_temp=0.959452400231
#   prelec_elevation=1.29691278819
#   prelec_gamma=1.50892049828
#   llh: 28418.6960621
# evaluating:
#   delta=0.177325303276
#   theta=4.61119128601
#   z_temp=0.956513612171
#   prelec_elevation=1.29671159896
#   prelec_gamma=1.51297459977
#   llh: 28418.8194755
# evaluating:
#   delta=0.172402092307
#   theta=4.61384571218
#   z_temp=0.974235077267
#   prelec_elevation=1.32579296258
#   prelec_gamma=1.49999955782
#   llh: 28418.754329
# evaluating:
#   delta=0.166951823639
#   theta=4.59961974348
#   z_temp=0.957966634338
#   prelec_elevation=1.36080326692
#   prelec_gamma=1.50151941933
#   llh: 28418.9490579
# evaluating:
#   delta=0.169115448961
#   theta=4.5963588182
#   z_temp=0.9611632057
#   prelec_elevation=1.33700930484
#   prelec_gamma=1.50256474069
#   llh: 28418.761113
# evaluating:
#   delta=0.17441707253
#   theta=4.63411267587
#   z_temp=0.958251559715
#   prelec_elevation=1.31415605352
#   prelec_gamma=1.49761941369
#   llh: 28418.4567675
# evaluating:
#   delta=0.177415874644
#   theta=4.66880235765
#   z_temp=0.953472597898
#   prelec_elevation=1.31156323958
#   prelec_gamma=1.49263390386
#   llh: 28418.3104451
# evaluating:
#   delta=0.178212732645
#   theta=4.65703383989
#   z_temp=0.969648958408
#   prelec_elevation=1.28834385055
#   prelec_gamma=1.49255352573
#   llh: 28418.4349559
# evaluating:
#   delta=0.181014881474
#   theta=4.66304009562
#   z_temp=0.967452285087
#   prelec_elevation=1.26742492127
#   prelec_gamma=1.49291992966
#   llh: 28418.5092838
# evaluating:
#   delta=0.181173353795
#   theta=4.66523095501
#   z_temp=0.951667296648
#   prelec_elevation=1.25529404701
#   prelec_gamma=1.49265326126
#   llh: 28418.6188043
# evaluating:
#   delta=0.183897921224
#   theta=4.68717896106
#   z_temp=0.955947722145
#   prelec_elevation=1.27934281425
#   prelec_gamma=1.49726825733
#   llh: 28418.4841284
# evaluating:
#   delta=0.186352826447
#   theta=4.74054917183
#   z_temp=0.959823143843
#   prelec_elevation=1.26387476088
#   prelec_gamma=1.47829105286
#   llh: 28418.0972257
# evaluating:
#   delta=0.192362700138
#   theta=4.81284110182
#   z_temp=0.960008515649
#   prelec_elevation=1.24735574723
#   prelec_gamma=1.46297633015
#   llh: 28417.9224436
# evaluating:
#   delta=0.183988290255
#   theta=4.7303275874
#   z_temp=0.970944735026
#   prelec_elevation=1.30231818214
#   prelec_gamma=1.48268751743
#   llh: 28418.1887105
# evaluating:
#   delta=0.185336126089
#   theta=4.75943344351
#   z_temp=0.956556726563
#   prelec_elevation=1.30414461222
#   prelec_gamma=1.47832788414
#   llh: 28417.9755522
# evaluating:
#   delta=0.183028368284
#   theta=4.76419637105
#   z_temp=0.968304891273
#   prelec_elevation=1.30214743844
#   prelec_gamma=1.46640340719
#   llh: 28417.7400778
# evaluating:
#   delta=0.182593591814
#   theta=4.80270507605
#   z_temp=0.974483475837
#   prelec_elevation=1.31354975054
#   prelec_gamma=1.45097098212
#   llh: 28417.5883469
# evaluating:
#   delta=0.190465900531
#   theta=4.85260998668
#   z_temp=0.956537461981
#   prelec_elevation=1.30322876213
#   prelec_gamma=1.45448512135
#   llh: 28417.3143552
# evaluating:
#   delta=0.196592484475
#   theta=4.95039806008
#   z_temp=0.949981713768
#   prelec_elevation=1.31067121793
#   prelec_gamma=1.43545091916
#   llh: 28416.8771454
# evaluating:
#   delta=0.198933402464
#   theta=4.95347974989
#   z_temp=0.971317468839
#   prelec_elevation=1.27965256444
#   prelec_gamma=1.43153154934
#   llh: 28416.8763166
# evaluating:
#   delta=0.209692166374
#   theta=5.09581844601
#   z_temp=0.98023990431
#   prelec_elevation=1.26369722687
#   prelec_gamma=1.40098037208
#   llh: 28416.3752577
# evaluating:
#   delta=0.202642537301
#   theta=5.03815086359
#   z_temp=0.957563399424
#   prelec_elevation=1.27344923978
#   prelec_gamma=1.40879507763
#   llh: 28416.2497415
# evaluating:
#   delta=0.211969660824
#   theta=5.19206250168
#   z_temp=0.950872731622
#   prelec_elevation=1.2590147686
#   prelec_gamma=1.37184885773
#   llh: 28415.6522714
# evaluating:
#   delta=0.211948115361
#   theta=5.18209663075
#   z_temp=0.969677809911
#   prelec_elevation=1.25357087224
#   prelec_gamma=1.37056310036
#   llh: 28415.8880976
# evaluating:
#   delta=0.212755707401
#   theta=5.27639118401
#   z_temp=0.970093738531
#   prelec_elevation=1.31284578724
#   prelec_gamma=1.34894936243
#   llh: 28414.4930236
# evaluating:
#   delta=0.222952211033
#   theta=5.5081662251
#   z_temp=0.975136349972
#   prelec_elevation=1.34559080725
#   prelec_gamma=1.29193587858
#   llh: 29090.0164242
# evaluating:
#   delta=0.23458966196
#   theta=5.47600165296
#   z_temp=0.95386288342
#   prelec_elevation=1.24637019861
#   prelec_gamma=1.32014606259
#   llh: 28414.2107569
# evaluating:
#   delta=0.260587697032
#   theta=5.81264994141
#   z_temp=0.943552587212
#   prelec_elevation=1.21278042264
#   prelec_gamma=1.25473360282
#   llh: 29115.2224916
# evaluating:
#   delta=0.235789640293
#   theta=5.53855010608
#   z_temp=0.97991711335
#   prelec_elevation=1.22352832349
#   prelec_gamma=1.28954418291
#   llh: 29092.2111118
# evaluating:
#   delta=0.206391773429
#   theta=5.09743607158
#   z_temp=0.957465563663
#   prelec_elevation=1.28888549432
#   prelec_gamma=1.3989742351
#   llh: 28415.7862832
# evaluating:
#   delta=0.221369801216
#   theta=5.39377677038
#   z_temp=0.940549186549
#   prelec_elevation=1.28057762153
#   prelec_gamma=1.3232122752
#   llh: 28414.3639187
# evaluating:
#   delta=0.222882526571
#   theta=5.3921706415
#   z_temp=0.939459831603
#   prelec_elevation=1.30150667588
#   prelec_gamma=1.33468921686
#   llh: 28413.980847
# evaluating:
#   delta=0.228349732175
#   theta=5.49720764687
#   z_temp=0.924350842449
#   prelec_elevation=1.3254745777
#   prelec_gamma=1.31675227511
#   llh: 28413.7509677
# evaluating:
#   delta=0.237222052001
#   theta=5.63673983078
#   z_temp=0.938426189365
#   prelec_elevation=1.28082768715
#   prelec_gamma=1.27338929812
#   llh: 29118.338536
# evaluating:
#   delta=0.214099343072
#   theta=5.23226201138
#   z_temp=0.952705720089
#   prelec_elevation=1.28687104253
#   prelec_gamma=1.36757800086
#   llh: 28414.9280567
# evaluating:
#   delta=0.232496037506
#   theta=5.55819320456
#   z_temp=0.945752216793
#   prelec_elevation=1.32184092245
#   prelec_gamma=1.29880633275
#   llh: 29109.0987214
# evaluating:
#   delta=0.217101254994
#   theta=5.2835951774
#   z_temp=0.949592602915
#   prelec_elevation=1.27472130706
#   prelec_gamma=1.35358822648
#   llh: 28414.8087426
# evaluating:
#   delta=0.231567120026
#   theta=5.53852696127
#   z_temp=0.942673981457
#   prelec_elevation=1.28912475433
#   prelec_gamma=1.29748127987
#   llh: 29114.0246213
# evaluating:
#   delta=0.218466287311
#   theta=5.30882824885
#   z_temp=0.950197785431
#   prelec_elevation=1.28743447048
#   prelec_gamma=1.35005382061
#   llh: 28414.4542388
# evaluating:
#   delta=0.229111221031
#   theta=5.49728702383
#   z_temp=0.946029171637
#   prelec_elevation=1.30635975516
#   prelec_gamma=1.31005729189
#   llh: 28413.0990773
# evaluating:
#   delta=0.235116204049
#   theta=5.60413294704
#   z_temp=0.944247455998
#   prelec_elevation=1.32217897922
#   prelec_gamma=1.2882918246
#   llh: 29110.194911
# evaluating:
#   delta=0.239998974076
#   theta=5.59284935315
#   z_temp=0.915902209264
#   prelec_elevation=1.26564086215
#   prelec_gamma=1.29913932773
#   llh: 29134.6180946
# evaluating:
#   delta=0.21956652407
#   theta=5.35550572629
#   z_temp=0.956545856214
#   prelec_elevation=1.30104455597
#   prelec_gamma=1.33649685376
#   llh: 28413.9784232
# evaluating:
#   delta=0.23472848887
#   theta=5.57908327928
#   z_temp=0.938337390677
#   prelec_elevation=1.29649621311
#   prelec_gamma=1.29261208281
#   llh: 29116.2268583
# evaluating:
#   delta=0.2225318377
#   theta=5.37639200646
#   z_temp=0.947232686742
#   prelec_elevation=1.28969990614
#   prelec_gamma=1.33569338616
#   llh: 28414.0372448
# evaluating:
#   delta=0.232289789559
#   theta=5.48718085219
#   z_temp=0.950659389636
#   prelec_elevation=1.3070019759
#   prelec_gamma=1.3244460726
#   llh: 28413.3945302
# evaluating:
#   delta=0.218149979854
#   theta=5.4094276493
#   z_temp=0.936064295251
#   prelec_elevation=1.36546210974
#   prelec_gamma=1.32923228922
#   llh: 28414.0185713
# evaluating:
#   delta=0.228455060975
#   theta=5.52225155293
#   z_temp=0.938227135332
#   prelec_elevation=1.35243728365
#   prelec_gamma=1.31110052688
#   llh: 29113.9344207
# evaluating:
#   delta=0.224012643519
#   theta=5.41285689308
#   z_temp=0.94498129889
#   prelec_elevation=1.30538425051
#   prelec_gamma=1.32954517134
#   llh: 28413.6963621
# evaluating:
#   delta=0.235181984287
#   theta=5.49058760761
#   z_temp=0.952962328279
#   prelec_elevation=1.25264393636
#   prelec_gamma=1.31768677666
#   llh: 28413.9637496
# evaluating:
#   delta=0.240011624158
#   theta=5.59854228313
#   z_temp=0.931047356142
#   prelec_elevation=1.29770124228
#   prelec_gamma=1.30289818129
#   llh: 29119.5982992
# evaluating:
#   delta=0.224677799092
#   theta=5.4162648655
#   z_temp=0.950171231196
#   prelec_elevation=1.30020872755
#   prelec_gamma=1.32809718564
#   llh: 28413.6394929
# evaluating:
#   delta=0.220194489863
#   theta=5.43373130498
#   z_temp=0.933514445243
#   prelec_elevation=1.36512777837
#   prelec_gamma=1.32587242198
#   llh: 28413.9717267
# evaluating:
#   delta=0.231435110681
#   theta=5.47637353195
#   z_temp=0.94810035752
#   prelec_elevation=1.28076489686
#   prelec_gamma=1.31973318799
#   llh: 28413.5314592
# evaluating:
#   delta=0.228260893377
#   theta=5.41877761975
#   z_temp=0.971625737103
#   prelec_elevation=1.27441326469
#   prelec_gamma=1.32799928868
#   llh: 28414.0068912
# evaluating:
#   delta=0.228327522476
#   theta=5.47760014009
#   z_temp=0.936169566112
#   prelec_elevation=1.31270924945
#   prelec_gamma=1.3195640285
#   llh: 28413.4676814
# evaluating:
#   delta=0.234323933616
#   theta=5.52902567235
#   z_temp=0.947470587551
#   prelec_elevation=1.29743359145
#   prelec_gamma=1.31121393531
#   llh: 29107.7914325
# evaluating:
#   delta=0.226590466043
#   theta=5.44189908789
#   z_temp=0.945603621055
#   prelec_elevation=1.30339658575
#   prelec_gamma=1.32496236233
#   llh: 28413.5245705
# evaluating:
#   delta=0.234423844824
#   theta=5.53587138888
#   z_temp=0.940453611188
#   prelec_elevation=1.3038842577
#   prelec_gamma=1.31140799169
#   llh: 29112.7944113
# evaluating:
#   delta=0.227114310525
#   theta=5.44616649635
#   z_temp=0.947741826194
#   prelec_elevation=1.30112761009
#   prelec_gamma=1.32392488715
#   llh: 28413.4814596
# evaluating:
#   delta=0.225938213172
#   theta=5.46367990819
#   z_temp=0.942381072333
#   prelec_elevation=1.33147317368
#   prelec_gamma=1.32144866901
#   llh: 28413.3819272
# evaluating:
#   delta=0.230521956662
#   theta=5.50686668036
#   z_temp=0.94358878931
#   prelec_elevation=1.32007211996
#   prelec_gamma=1.31481401733
#   llh: 29110.3894187
# evaluating:
#   delta=0.227573338698
#   theta=5.45814098601
#   z_temp=0.945099913119
#   prelec_elevation=1.3075654693
#   prelec_gamma=1.32242527608
#   llh: 28413.4097955
# evaluating:
#   delta=0.230181723449
#   theta=5.50738906777
#   z_temp=0.940393818941
#   prelec_elevation=1.32491623931
#   prelec_gamma=1.31525164808
#   llh: 29112.7059435
# evaluating:
#   delta=0.227881163756
#   theta=5.4614721392
#   z_temp=0.945904824381
#   prelec_elevation=1.30707476739
#   prelec_gamma=1.32175657739
#   llh: 28413.378168
# evaluating:
#   delta=0.22878996801
#   theta=5.46950422368
#   z_temp=0.95586018233
#   prelec_elevation=1.31108080712
#   prelec_gamma=1.32048952629
#   llh: 28413.2276632
# evaluating:
#   delta=0.230030803513
#   theta=5.49350867282
#   z_temp=0.951233943008
#   prelec_elevation=1.3176307224
#   prelec_gamma=1.31685397879
#   llh: 28413.0985904
# evaluating:
#   delta=0.231259535921
#   theta=5.51119251623
#   z_temp=0.954300957952
#   prelec_elevation=1.32266334895
#   prelec_gamma=1.31406833014
#   llh: 29101.9510202
# evaluating:
#   delta=0.224410758235
#   theta=5.4669999349
#   z_temp=0.94590428784
#   prelec_elevation=1.3224457144
#   prelec_gamma=1.31179634474
#   llh: 28413.189374
# evaluating:
#   delta=0.230151352646
#   theta=5.49182888958
#   z_temp=0.955591891345
#   prelec_elevation=1.29436353292
#   prelec_gamma=1.31093281863
#   llh: 28413.1687698
# evaluating:
#   delta=0.229116477618
#   theta=5.50617935872
#   z_temp=0.955942966083
#   prelec_elevation=1.31367744541
#   prelec_gamma=1.30629540675
#   llh: 29102.3877853
# evaluating:
#   delta=0.228189992222
#   theta=5.47264894408
#   z_temp=0.948414359806
#   prelec_elevation=1.3087254369
#   prelec_gamma=1.31789128473
#   llh: 28413.2344792
# evaluating:
#   delta=0.228807649152
#   theta=5.49500255384
#   z_temp=0.953433430657
#   prelec_elevation=1.31202677591
#   prelec_gamma=1.31016069941
#   llh: 28412.9858128
# evaluating:
#   delta=0.229116477618
#   theta=5.50617935872
#   z_temp=0.955942966083
#   prelec_elevation=1.31367744541
#   prelec_gamma=1.30629540675
#   llh: 29102.3877853
# evaluating:
#   delta=0.22821474582
#   theta=5.50834660631
#   z_temp=0.945016907465
#   prelec_elevation=1.31004979319
#   prelec_gamma=1.3034309271
#   llh: 29111.4038086
# evaluating:
#   delta=0.228646162463
#   theta=5.47921481934
#   z_temp=0.953149363614
#   prelec_elevation=1.31082305364
#   prelec_gamma=1.31622487649
#   llh: 28413.1305205
# evaluating:
#   delta=0.234288117287
#   theta=5.51573684886
#   z_temp=0.957870832264
#   prelec_elevation=1.29403582161
#   prelec_gamma=1.31389552135
#   llh: 29100.0168033
# evaluating:
#   delta=0.226880097998
#   theta=5.47918416339
#   z_temp=0.948895923946
#   prelec_elevation=1.31534324121
#   prelec_gamma=1.31232113889
#   llh: 28413.1072028
# evaluating:
#   delta=0.227239021017
#   theta=5.4858500037
#   z_temp=0.9455048418
#   prelec_elevation=1.33050988641
#   prelec_gamma=1.31531437556
#   llh: 28413.1274803
# evaluating:
#   delta=0.228181354622
#   theta=5.5011181477
#   z_temp=0.944889560806
#   prelec_elevation=1.32192509879
#   prelec_gamma=1.30965811733
#   llh: 29110.3305124
# evaluating:
#   delta=0.228529960503
#   theta=5.48469065143
#   z_temp=0.951084412912
#   prelec_elevation=1.31359856493
#   prelec_gamma=1.3145831867
#   llh: 28413.0865352
# evaluating:
#   delta=0.230104871862
#   theta=5.49401922242
#   z_temp=0.954765911064
#   prelec_elevation=1.29547373743
#   prelec_gamma=1.31027614272
#   llh: 28413.1452182
# evaluating:
#   delta=0.227955483728
#   theta=5.48789230838
#   z_temp=0.947820109116
#   prelec_elevation=1.32175084916
#   prelec_gamma=1.31405481735
#   llh: 28413.0707949
# evaluating:
#   delta=0.230893949173
#   theta=5.50416832073
#   z_temp=0.950944502986
#   prelec_elevation=1.31320342582
#   prelec_gamma=1.31396285076
#   llh: 29105.0715305
# evaluating:
#   delta=0.227883560792
#   theta=5.48543020273
#   z_temp=0.949408068706
#   prelec_elevation=1.31480828736
#   prelec_gamma=1.31273156686
#   llh: 28413.072644
# evaluating:
#   delta=0.228171762045
#   theta=5.48132273185
#   z_temp=0.955162814122
#   prelec_elevation=1.32556632474
#   prelec_gamma=1.31729640775
#   llh: 28413.1008438
# evaluating:
#   delta=0.228876356284
#   theta=5.49329595083
#   z_temp=0.948312582258
#   prelec_elevation=1.31116139756
#   prelec_gamma=1.31186707086
#   llh: 28413.0612464
# evaluating:
#   delta=0.22679040067
#   theta=5.48501599406
#   z_temp=0.948789498452
#   prelec_elevation=1.31170762757
#   prelec_gamma=1.30850495768
#   llh: 28413.1010217
# evaluating:
#   delta=0.229220702803
#   theta=5.49138550313
#   z_temp=0.950622831869
#   prelec_elevation=1.31614994869
#   prelec_gamma=1.31476672351
#   llh: 28413.0602491
# evaluating:
#   delta=0.228567540601
#   theta=5.49651195614
#   z_temp=0.948754396131
#   prelec_elevation=1.31676033854
#   prelec_gamma=1.3108491645
#   llh: 28412.998442
# evaluating:
#   delta=0.229487532236
#   theta=5.50020510621
#   z_temp=0.950169271307
#   prelec_elevation=1.31633143659
#   prelec_gamma=1.31194782339
#   llh: 29106.0419195
# evaluating:
#   delta=0.228284553653
#   theta=5.4891239286
#   z_temp=0.949598369356
#   prelec_elevation=1.31518907467
#   prelec_gamma=1.31253563099
#   llh: 28413.0488571
# evaluating:
#   delta=0.229547237269
#   theta=5.49823564863
#   z_temp=0.952468534993
#   prelec_elevation=1.30676416498
#   prelec_gamma=1.31001689836
#   llh: 28413.0141675
# evaluating:
#   delta=0.228894717107
#   theta=5.4948078853
#   z_temp=0.953638442944
#   prelec_elevation=1.31559472356
#   prelec_gamma=1.31146457585
#   llh: 28412.9760457
# evaluating:
# ...
#   theta=5.49978288888
#   z_temp=0.959112094592
#   prelec_elevation=1.34782000884
#   prelec_gamma=1.30169656968
#   llh: 28412.8016718
# evaluating:
#   delta=0.224711749769
#   theta=5.49976357199
#   z_temp=0.958605467474
#   prelec_elevation=1.34416771153
#   prelec_gamma=1.3019524069
#   llh: 28412.8010718
# evaluating:
#   delta=0.224800902299
#   theta=5.49976371688
#   z_temp=0.960570414667
#   prelec_elevation=1.34418203451
#   prelec_gamma=1.30189054867
#   llh: 28412.8024592
# evaluating:
#   delta=0.224625609704
#   theta=5.49983459703
#   z_temp=0.958427545344
#   prelec_elevation=1.34605089891
#   prelec_gamma=1.30217325321
#   llh: 28412.8013056
# evaluating:
#   delta=0.224709541931
#   theta=5.49996278603
#   z_temp=0.959044162828
#   prelec_elevation=1.34454179507
#   prelec_gamma=1.3018774669
#   llh: 28412.7995243
# evaluating:
#   delta=0.224739747507
#   theta=5.50008953854
#   z_temp=0.959062485119
#   prelec_elevation=1.34369324522
#   prelec_gamma=1.30169124639
#   llh: 29100.2058021
# evaluating:
#   delta=0.225118648185
#   theta=5.49996113702
#   z_temp=0.958912413779
#   prelec_elevation=1.34164939552
#   prelec_gamma=1.30250316404
#   llh: 28412.8012676
# evaluating:
#   delta=0.224694693428
#   theta=5.49998160532
#   z_temp=0.957499650553
#   prelec_elevation=1.34483170199
#   prelec_gamma=1.30218704155
#   llh: 28412.8010665
# evaluating:
#   delta=0.224986421775
#   theta=5.50002500831
#   z_temp=0.958765106813
#   prelec_elevation=1.34207702473
#   prelec_gamma=1.30217213067
#   llh: 29100.3891582
# evaluating:
#   delta=0.224715812722
#   theta=5.49988219985
#   z_temp=0.958511935711
#   prelec_elevation=1.34505743036
#   prelec_gamma=1.30217297258
#   llh: 28412.8006105
# evaluating:
#   delta=0.224332249108
#   theta=5.49986689345
#   z_temp=0.958120047152
#   prelec_elevation=1.34784174205
#   prelec_gamma=1.30171014325
#   llh: 28412.801525
# evaluating:
#   delta=0.224922048416
#   theta=5.49993757613
#   z_temp=0.958714322122
#   prelec_elevation=1.34319748215
#   prelec_gamma=1.30230490884
#   llh: 28412.8004656
# evaluating:
#   delta=0.224823266984
#   theta=5.50013406014
#   z_temp=0.958470535315
#   prelec_elevation=1.34493533429
#   prelec_gamma=1.30240190117
#   llh: 29100.4974744
# evaluating:
#   delta=0.224739629072
#   theta=5.49985619403
#   z_temp=0.958571734434
#   prelec_elevation=1.34435961722
#   prelec_gamma=1.30206478047
#   llh: 28412.8005434
# evaluating:
#   delta=0.224858297582
#   theta=5.49986586229
#   z_temp=0.960005185789
#   prelec_elevation=1.34408250992
#   prelec_gamma=1.30211836209
#   llh: 28412.8011581
# evaluating:
#   delta=0.224735594467
#   theta=5.49995266956
#   z_temp=0.958126034362
#   prelec_elevation=1.34464440398
#   prelec_gamma=1.30216987169
#   llh: 28412.8003687
# evaluating:
#   delta=0.224845090986
#   theta=5.49999345564
#   z_temp=0.958838540091
#   prelec_elevation=1.343691571
#   prelec_gamma=1.30213119071
#   llh: 28412.7997177
# evaluating:
#   delta=0.224863459401
#   theta=5.50007436612
#   z_temp=0.95888546363
#   prelec_elevation=1.34412216565
#   prelec_gamma=1.30226594691
#   llh: 29100.2298504
# evaluating:
#   delta=0.224770586655
#   theta=5.49991073705
#   z_temp=0.958650166733
#   prelec_elevation=1.34430025433
#   prelec_gamma=1.30211507208
#   llh: 28412.8002148
# evaluating:
#   delta=0.224620455353
#   theta=5.49998224838
#   z_temp=0.958717213787
#   prelec_elevation=1.34572540959
#   prelec_gamma=1.30194988383
#   llh: 28412.7996523
# evaluating:
#   delta=0.224760853657
#   theta=5.49997898647
#   z_temp=0.959541973317
#   prelec_elevation=1.34471089001
#   prelec_gamma=1.30199692584
#   llh: 28412.7997577
# evaluating:
#   delta=0.224687166048
#   theta=5.49995137244
#   z_temp=0.958996886944
#   prelec_elevation=1.34405876302
#   prelec_gamma=1.30168483544
#   llh: 28412.7996162
# evaluating:
#   delta=0.224678656535
#   theta=5.50003680254
#   z_temp=0.959405344054
#   prelec_elevation=1.34479111715
#   prelec_gamma=1.30174104901
#   llh: 29099.914472
# evaluating:
#   delta=0.224747604125
#   theta=5.49994225342
#   z_temp=0.958838961064
#   prelec_elevation=1.34442297003
#   prelec_gamma=1.30202156631
#   llh: 28412.7998301
# evaluating:
#   delta=0.224701639065
#   theta=5.50000528617
#   z_temp=0.959216549724
#   prelec_elevation=1.34466840144
#   prelec_gamma=1.30183455478
#   llh: 29100.0447197
# evaluating:
#   delta=0.22473611286
#   theta=5.49995801161
#   z_temp=0.958933358229
#   prelec_elevation=1.34448432789
#   prelec_gamma=1.30197481343
#   llh: 28412.7996584
# evaluating:
#   delta=0.224678493214
#   theta=5.49996016317
#   z_temp=0.958270091434
#   prelec_elevation=1.34428985662
#   prelec_gamma=1.30185035028
#   llh: 28412.7998704
# evaluating:
#   delta=0.224740263546
#   theta=5.49997428065
#   z_temp=0.959224002847
#   prelec_elevation=1.34460563166
#   prelec_gamma=1.30196028195
#   llh: 28412.7995709
# evaluating:
#   delta=0.224552324909
#   theta=5.499938024
#   z_temp=0.959127709763
#   prelec_elevation=1.34567479989
#   prelec_gamma=1.30164772191
#   llh: 28412.7995581
# evaluating:
#   delta=0.224587787855
#   theta=5.49996547299
#   z_temp=0.959110632239
#   prelec_elevation=1.34535823181
#   prelec_gamma=1.30167326258
#   llh: 28412.7993533
# evaluating:
#   delta=0.224513625353
#   theta=5.49996920368
#   z_temp=0.959199269245
#   prelec_elevation=1.34579518377
#   prelec_gamma=1.30152248716
#   llh: 28412.7993032
# evaluating:
#   delta=0.224660713362
#   theta=5.49993601834
#   z_temp=0.959519598863
#   prelec_elevation=1.34414505978
#   prelec_gamma=1.30152723352
#   llh: 28412.799851
# evaluating:
#   delta=0.224630519855
#   theta=5.49997069087
#   z_temp=0.958917810056
#   prelec_elevation=1.34533032214
#   prelec_gamma=1.30184422125
#   llh: 28412.7994625
# evaluating:
#   delta=0.224571344189
#   theta=5.49997462165
#   z_temp=0.959208294952
#   prelec_elevation=1.34632032999
#   prelec_gamma=1.30185603624
#   llh: 28412.7997849
# evaluating:
#   delta=0.224658210584
#   theta=5.49995718474
#   z_temp=0.959049738946
#   prelec_elevation=1.34462415477
#   prelec_gamma=1.30172763564
#   llh: 28412.7994575
# evaluating:
#   delta=0.224485425506
#   theta=5.49994487508
#   z_temp=0.958911473489
#   prelec_elevation=1.3457808706
#   prelec_gamma=1.30148753119
#   llh: 28412.7994412
# evaluating:
#   delta=0.224646604382
#   theta=5.49998387216
#   z_temp=0.958921272062
#   prelec_elevation=1.34475413064
#   prelec_gamma=1.30173601495
#   llh: 28412.7992665
# evaluating:
#   delta=0.224693744119
#   theta=5.50000679625
#   z_temp=0.958818053212
#   prelec_elevation=1.34429379602
#   prelec_gamma=1.30178016146
#   llh: 29100.3635237
# evaluating:
#   delta=0.224464212341
#   theta=5.49996754459
#   z_temp=0.958955662691
#   prelec_elevation=1.34597206969
#   prelec_gamma=1.30144968917
#   llh: 28412.7992963
# evaluating:
#   delta=0.224476711411
#   theta=5.49995838123
#   z_temp=0.959097156517
#   prelec_elevation=1.34544024165
#   prelec_gamma=1.301325122
#   llh: 28412.7993538
# evaluating:
#   delta=0.224376421014
#   theta=5.49997236595
#   z_temp=0.958984194656
#   prelec_elevation=1.34647284378
#   prelec_gamma=1.30128070215
#   llh: 28412.7993241
# evaluating:
#   delta=0.224505604294
#   theta=5.49999567197
#   z_temp=0.959151548579
#   prelec_elevation=1.34559291722
#   prelec_gamma=1.30143807498
#   llh: 28412.7990774
# evaluating:
#   delta=0.224515693688
#   theta=5.50002107041
#   z_temp=0.959271586125
#   prelec_elevation=1.34549894053
#   prelec_gamma=1.30141334687
#   llh: 29100.0558475
# evaluating:
#   delta=0.224525875542
#   theta=5.49999708211
#   z_temp=0.958987622377
#   prelec_elevation=1.34599461639
#   prelec_gamma=1.30164566537
#   llh: 28412.7992069
# evaluating:
#   delta=0.224685947751
#   theta=5.49999298385
#   z_temp=0.959101955326
#   prelec_elevation=1.34477072331
#   prelec_gamma=1.3018360705
#   llh: 28412.7992831
# evaluating:
#   delta=0.224617672372
#   theta=5.50000565819
#   z_temp=0.95884795517
#   prelec_elevation=1.34503859913
#   prelec_gamma=1.30171971883
#   llh: 29100.333552
# evaluating:
#   delta=0.224539637107
#   theta=5.49997831731
#   z_temp=0.959111440726
#   prelec_elevation=1.34560603761
#   prelec_gamma=1.30157179508
#   llh: 28412.7992277
# evaluating:
#   delta=0.22469725529
#   theta=5.50001162637
#   z_temp=0.959153872937
#   prelec_elevation=1.34471530038
#   prelec_gamma=1.30184135918
#   llh: 29100.0893505
# evaluating:
#   delta=0.224522473078
#   theta=5.49997856503
#   z_temp=0.959005215253
#   prelec_elevation=1.34565787736
#   prelec_gamma=1.30154760668
#   llh: 28412.7992143
# evaluating:
#   delta=0.224410130011
#   theta=5.49998041958
#   z_temp=0.958968884273
#   prelec_elevation=1.34627150838
#   prelec_gamma=1.30133959232
#   llh: 28412.7992328
# evaluating:
#   delta=0.224354883631
#   theta=5.49998815024
#   z_temp=0.95916861242
#   prelec_elevation=1.34689505214
#   prelec_gamma=1.30128107882
#   llh: 28412.7993402
# evaluating:
#   delta=0.224573674194
#   theta=5.49998494168
#   z_temp=0.958983107152
#   prelec_elevation=1.34528936102
#   prelec_gamma=1.30162228092
#   llh: 28412.7991816
# evaluating:
#   delta=0.224656775676
#   theta=5.49999341166
#   z_temp=0.959126689362
#   prelec_elevation=1.34498481546
#   prelec_gamma=1.30179057689
#   llh: 28412.7992434
# evaluating:
#   delta=0.224471791427
#   theta=5.4999836676
#   z_temp=0.959008335545
#   prelec_elevation=1.34594983515
#   prelec_gamma=1.30145233846
#   llh: 28412.7991786
# evaluating:
#   delta=0.224500130307
#   theta=5.49999765405
#   z_temp=0.958942890836
#   prelec_elevation=1.34578780524
#   prelec_gamma=1.30151059148
#   llh: 28412.7990846
# evaluating:
#   delta=0.224508357228
#   theta=5.50000504193
#   z_temp=0.959024186543
#   prelec_elevation=1.34578793664
#   prelec_gamma=1.30151997381
#   llh: 29100.2174613
# evaluating:
#   delta=0.224518944116
#   theta=5.49998518426
#   z_temp=0.959009958075
#   prelec_elevation=1.34569039218
#   prelec_gamma=1.30154069846
#   llh: 28412.7991688
# evaluating:
#   delta=0.224502182193
#   theta=5.49998176571
#   z_temp=0.959050713699
#   prelec_elevation=1.34532950794
#   prelec_gamma=1.30137992835
#   llh: 28412.7991809
# evaluating:
#   delta=0.22442578674
#   theta=5.49999263575
#   z_temp=0.959082271542
#   prelec_elevation=1.34605082207
#   prelec_gamma=1.30130637178
#   llh: 28412.799122
# evaluating:
#   delta=0.224466720561
#   theta=5.50000015974
#   z_temp=0.959027288133
#   prelec_elevation=1.34629920081
#   prelec_gamma=1.30151930172
#   llh: 29100.203321
# evaluating:
#   delta=0.224493316785
#   theta=5.49998636422
#   z_temp=0.959044857307
#   prelec_elevation=1.34557193115
#   prelec_gamma=1.30141477169
#   llh: 28412.7991323
# evaluating:
#   delta=0.22450572147
#   theta=5.4999993365
#   z_temp=0.959084274991
#   prelec_elevation=1.345527712
#   prelec_gamma=1.30143186489
#   llh: 28412.799045
# evaluating:
#   delta=0.224522686491
#   theta=5.50000717094
#   z_temp=0.959122244714
#   prelec_elevation=1.34531665042
#   prelec_gamma=1.30142162811
#   llh: 29100.1718931
# evaluating:
#   delta=0.224453279723
#   theta=5.50000348074
#   z_temp=0.959112379227
#   prelec_elevation=1.34572208289
#   prelec_gamma=1.30129997147
#   llh: 29100.1909646
# evaluating:
#   delta=0.224502528017
#   theta=5.49998975838
#   z_temp=0.959035563363
#   prelec_elevation=1.34569831486
#   prelec_gamma=1.30148051671
#   llh: 28412.7991195
# evaluating:
#   delta=0.224482591547
#   theta=5.50000365844
#   z_temp=0.959073762418
#   prelec_elevation=1.3458910974
#   prelec_gamma=1.30145219625
#   llh: 29100.1894992
# evaluating:
#   delta=0.224490635475
#   theta=5.49999068777
#   z_temp=0.959052083585
#   prelec_elevation=1.34565172272
#   prelec_gamma=1.30142412783
#   llh: 28412.7991039
# evaluating:
#   delta=0.224576061085
#   theta=5.49999660771
#   z_temp=0.959024273
#   prelec_elevation=1.34525256674
#   prelec_gamma=1.30160769858
#   llh: 28412.7990962
# evaluating:
#   delta=0.224528733035
#   theta=5.50000222482
#   z_temp=0.959066465033
#   prelec_elevation=1.34542677471
#   prelec_gamma=1.3014844264
#   llh: 29100.2005451
# evaluating:
#   delta=0.224509079272
#   theta=5.49999287499
#   z_temp=0.959043288781
#   prelec_elevation=1.34563042982
#   prelec_gamma=1.30148149413
#   llh: 28412.7990944
# evaluating:
#   delta=0.224548003096
#   theta=5.50000217031
#   z_temp=0.95904642689
#   prelec_elevation=1.34546484969
#   prelec_gamma=1.3015637618
#   llh: 29100.2009353
# evaluating:
#   delta=0.224504977381
#   theta=5.49999355841
#   z_temp=0.959050669411
#   prelec_elevation=1.34560500446
#   prelec_gamma=1.30145903632
#   llh: 28412.7990852
# evaluating:
#   delta=0.224434144004
#   theta=5.49999503065
#   z_temp=0.959084796039
#   prelec_elevation=1.34600498076
#   prelec_gamma=1.30132072614
#   llh: 28412.7990998
# evaluating:
#   delta=0.224540581815
#   theta=5.49999621345
#   z_temp=0.95903940376
#   prelec_elevation=1.34544067024
#   prelec_gamma=1.30153595547
#   llh: 28412.7990772
# evaluating:
#   delta=0.224513726835
#   theta=5.50000009876
#   z_temp=0.95906422625
#   prelec_elevation=1.34555121384
#   prelec_gamma=1.30146871513
#   llh: 29100.2020772
# evaluating:
#   delta=0.224510241163
#   theta=5.49999468093
#   z_temp=0.959048523148
#   prelec_elevation=1.34561062583
#   prelec_gamma=1.30147829938
#   llh: 28412.7990806
# evaluating:
#   delta=0.224519934239
#   theta=5.49999986435
#   z_temp=0.959055987115
#   prelec_elevation=1.34557888775
#   prelec_gamma=1.30149887816
#   llh: 28412.7990483
# evaluating:
#   delta=0.224532702885
#   theta=5.49999665283
#   z_temp=0.959209004201
#   prelec_elevation=1.34531251997
#   prelec_gamma=1.30144263767
#   llh: 28412.7990866
# evaluating:
#   delta=0.224508273452
#   theta=5.49999740374
#   z_temp=0.959009419177
#   prelec_elevation=1.34566898393
#   prelec_gamma=1.30149360303
#   llh: 28412.7990679
# evaluating:
#   delta=0.224521804945
#   theta=5.50000071507
#   z_temp=0.959087730301
#   prelec_elevation=1.34551304263
#   prelec_gamma=1.30148105123
#   llh: 29100.1831042
# evaluating:
#   delta=0.224513132108
#   theta=5.49999618947
#   z_temp=0.959058324936
#   prelec_elevation=1.34558623003
#   prelec_gamma=1.30147898734
#   llh: 28412.7990698
# evaluating:
#   delta=0.224529452939
#   theta=5.49999993103
#   z_temp=0.958947415412
#   prelec_elevation=1.34552807636
#   prelec_gamma=1.30153764058
#   llh: 28412.7990581
# evaluating:
#   delta=0.224490023868
#   theta=5.50000087659
#   z_temp=0.959022764893
#   prelec_elevation=1.34571528578
#   prelec_gamma=1.30144043413
#   llh: 29100.2342984
# evaluating:
#   delta=0.224527942328
#   theta=5.49999737923
#   z_temp=0.959035244043
#   prelec_elevation=1.34550932413
#   prelec_gamma=1.30151207514
#   llh: 28412.799065
# evaluating:
#   delta=0.224523397663
#   theta=5.50000137648
#   z_temp=0.958994611359
#   prelec_elevation=1.34553896364
#   prelec_gamma=1.30151063738
#   llh: 29100.2474955
# evaluating:
#   delta=0.224515698497
#   theta=5.49999748622
#   z_temp=0.959042396542
#   prelec_elevation=1.34557441343
#   prelec_gamma=1.30148689985
#   llh: 28412.7990614
# evaluating:
#   delta=0.224531226338
#   theta=5.50000019519
#   z_temp=0.959056708064
#   prelec_elevation=1.34541838154
#   prelec_gamma=1.30149334042
#   llh: 29100.2066394
# evaluating:
#   delta=0.224514011673
#   theta=5.4999981016
#   z_temp=0.959021241399
#   prelec_elevation=1.34560633333
#   prelec_gamma=1.30149353738
#   llh: 28412.7990596
# evaluating:
#   delta=0.224505985199
#   theta=5.50000050865
#   z_temp=0.959025282141
#   prelec_elevation=1.34561684502
#   prelec_gamma=1.30146745321
#   llh: 29100.2300656
# evaluating:
#   delta=0.224522453046
#   theta=5.49999816159
#   z_temp=0.959032753567
#   prelec_elevation=1.34553620435
#   prelec_gamma=1.30150091965
#   llh: 28412.7990581
# evaluating:
#   delta=0.22452093085
#   theta=5.50000067181
#   z_temp=0.959014272452
#   prelec_elevation=1.34553647209
#   prelec_gamma=1.30149823641
#   llh: 29100.2349222
# evaluating:
#   delta=0.224517006585
#   theta=5.49999828262
#   z_temp=0.959035365519
#   prelec_elevation=1.34556492809
#   prelec_gamma=1.30148973399
#   llh: 28412.7990561
# evaluating:
#   delta=0.224523815639
#   theta=5.50000012883
#   z_temp=0.959041077243
#   prelec_elevation=1.34548799009
#   prelec_gamma=1.30149007754
#   llh: 29100.2173223
# evaluating:
#   delta=0.224516462665
#   theta=5.49999860841
#   z_temp=0.95902620036
#   prelec_elevation=1.34557674752
#   prelec_gamma=1.30149267242
#   llh: 28412.7990547
# evaluating:
#   delta=0.224512978113
#   theta=5.50000024757
#   z_temp=0.959026943792
#   prelec_elevation=1.34557433634
#   prelec_gamma=1.30147939636
#   llh: 29100.2277619
# evaluating:
#   delta=0.224520084313
#   theta=5.49999868308
#   z_temp=0.959031301123
#   prelec_elevation=1.34554573735
#   prelec_gamma=1.30149553883
#   llh: 28412.7990538
# evaluating:
#   delta=0.224502230769
#   theta=5.49999797895
#   z_temp=0.959145836231
#   prelec_elevation=1.34558952872
#   prelec_gamma=1.30142583474
#   llh: 28412.7990603
# evaluating:
#   delta=0.224522647397
#   theta=5.49999944301
#   z_temp=0.958997020617
#   prelec_elevation=1.34554343945
#   prelec_gamma=1.30150968912
#   llh: 28412.7990518

# %%
f
# Out:
#   status: 0
#     nfev: 472
#  success: True
#      fun: 28412.799045014293
#        x: array([ 0.22450572,  5.49999934,  0.95908427,  1.34552771,  1.30143186])
#  message: 'Optimization terminated successfully.'
#      nit: 287

# %%
ps = np.arange(0, 1, .01)
fig, ax = plt.subplots()
ax.plot(ps, ps, '--')
ax.plot(ps, [pweight_prelec(p, f['x'][3], f['x'][4]) for p in ps], label='best-fitting w_p')
ax.set_aspect(1)
ax.set_xlabel('true')
ax.set_ylabel('weighted')
ax.set_title('Probability weighting fcn')
ax.legend()
plt.show()

# %%
p_resp = []
p_stop = []
prop_choices_predicted = []
for i, fd in enumerate(fitdata):
    pred_pars = {'data': fd['samplesize'],
                 'max_T': fd['max_t'],
                 'options': fd['options']}
    for par_i, par_name in enumerate(pars['fitting']):
        pred_pars[par_name] = f['x'][par_i]
    result = run(pred_pars)
    p_resp.append(result['resp_prob'][1])
    
    exp_tA = np.sum([t * pt for (t, pt) in enumerate(result['p_stop_t'][:,0])]) * result['resp_prob'][0]
    exp_tB = np.sum([t * pt for (t, pt) in enumerate(result['p_stop_t'][:,1])]) * result['resp_prob'][1]
    p_stop.append(exp_tA + exp_tB)
    
    matched = [choice==np.argmax(result['resp_prob_t'][t]) for (choice, t, grp) in pred_pars['data']]
    prop_choices_predicted.append(np.sum(1*matched)/float(len(matched)))

# %%
fig, ax = plt.subplots(figsize=(20,6))
ax.plot(np.array([data_by_gamble[data_by_gamble['gid']==gid]['prop_H_all'].values for gid in gamble_lab_srt]), '-o', label='observed')
ax.plot(p_resp, '-x', label='best fit model')
ax.set_ylim([0, 1])
ax.set_xlim([-1, 85])
add_problem_labels(ax, .2, [0, 10])
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax.plot(data_by_gamble['ss_all'].values, 'r-+')
ax.plot(p_stop, '-x', label='best fit model')
add_problem_labels(ax, 14, [0,50])
ax.legend()
ax.set_xlim(-1, 85)
ax.set_ylim(10, 45)
ax.set_xlabel('Problem')
ax.set_ylabel('Sample size')
ax.set_title('Observed mean sample size')
plt.show()
