# %%
import pandas as pd
import sys
sys.path.append('../')
from hau2008 import *

# %%
df = load_study1()

# %%
df[df['problem']==1]
# Out:
#       subject  problem  trial  option  outcome
# 144         1        1      1       1        3
# 145         1        1      2       1        3
# 146         1        1      3       1        3
# 147         1        1      4       1        3
# 148         1        1      5       1        3
# 149         1        1      6       1        3
# 150         1        1      7       1        3
# 151         1        1      8       1        3
# 152         1        1      9       1        3
# 153         1        1     10       0        4
# 154         1        1     11       0        0
# 155         1        1     12       0        0
# 156         1        1     13       0        4
# 157         1        1     14       0        4
# 158         1        1     15       0        4
# 159         1        1     16       0        0
# 160         1        1     17       0        4
# 161         1        1     18       0        4
# 162         1        1     19       0        4
# ...

# %%
df[df['problem']==1].groupby('subject').apply(lambda x: len(x))
# Out:
# subject
# 1          19
# 2           2
# 6           3
# 7           6
# 8           2
# 9           7
# 10          3
# 11         36
# 12         12
# 13          8
# 14          6
# 15          8
# 16         22
# 17          8
# 18          6
# 19         11
# 20          9
# 21         11
# 22         12
# 23          4
# 25          2
# 26         22
# 27          4
# 28         25
# 29         20
# 30         13
# 31         21
# 32          7
# 33          4
# 35          4
# 36         21
# 37          4
# 38         16
# 39          3
# 40          2
# 41          4
# 42          5
# dtype: int64
